# %% [markdown]
# # Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import re
import pickle
from time import sleep
from datetime import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, losses, Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from IPython import display
import math

# Configuração de caminhos relativos
BASE_PATH = os.getcwd()
DATASET_DIR = os.path.join(BASE_PATH, 'datasets')
MODELS_DIR = os.path.join(BASE_PATH, 'models')
RESULTS_DIR = os.path.join(BASE_PATH, 'results')

# Diretório de históricos (opcional)
HISTORY_DIR = os.path.join(BASE_PATH, 'history') if os.path.exists(os.path.join(BASE_PATH, 'history')) else RESULTS_DIR

# Dicionário de grupos funcionais e SMARTS
func_grp_smarts = {
    'alkane':'[CX4;H0,H1,H2,H4]',
    'methyl':'[CH3]',
    'alkene':'[CX3]=[CX3]',
    'alkyne':'[CX2]#C',
    'alcohols':'[#6][OX2H]',
    'amines':'[NX3;H2,H1;!$(NC=O)]',
    'nitriles':'[NX1]#[CX2]',
    'aromatics':'[$([cX3](:*):*),$([cX2+](:*):*)]',
    'alkyl halides':'[#6][F,Cl,Br,I]',
    'esters':'[#6][CX3](=O)[OX2H0][#6]',
    'ketones':'[#6][CX3](=O)[#6]',
    'aldehydes':'[CX3H1](=O)[#6]',
    'carboxylic acids':'[CX3](=O)[OX2H1]',
    'ether': '[OD2]([#6])[#6]',
    'acyl halides':'[CX3](=[OX1])[F,Cl,Br,I]',
    'amides':'[NX3][CX3](=[OX1])[#6]',
    'nitro':'[$([NX3](=O)=O),$([NX3+](=O)[O-])][!#8]'
}

column_names = list(func_grp_smarts.keys())

# Caminhos dos arquivos de dados e modelos
DATASET_PATH = os.path.join(DATASET_DIR, 'spectras')
ENRICH_CSV = os.path.join(DATASET_DIR, 'df_enrich.csv')
SPECTRA_CSV = os.path.join(DATASET_DIR, 'df_spectra_all_mixture_interpolate.csv')
AUTOENCODER_MODEL_PATH = os.path.join(MODELS_DIR, 'autoencoder_model_2025_04_07.keras')

# %%
autoencoder_load = keras.models.load_model(AUTOENCODER_MODEL_PATH)
autoencoder_load.summary()
encoder_model_load = keras.Model(inputs=autoencoder_load.input, outputs=autoencoder_load.layers[4].output)  # Supondo que o encoder são as 4 primeiras camadas
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 1030)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 512)            │       527,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 25)             │         3,225 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 128)            │         3,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 1030)           │       528,390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,174,943 (15.93 MB)
#  Trainable params: 1,391,647 (5.31 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,783,296 (10.62 MB)

# %%
df_enrich = pd.read_csv(ENRICH_CSV)
dataset_y = df_enrich.copy()
dataset_y.index = dataset_y['CAS']

len(dataset_y.CAS.unique())
# Out:
# 8241

# %%
df_spectra_all = pd.read_csv(SPECTRA_CSV)
mean_cols = [x for x in df_spectra_all.columns if 'mean' in x]
min_cols = [x for x in df_spectra_all.columns if 'min' in x]
max_cols = [x for x in df_spectra_all.columns if 'max' in x]
all_cols = mean_cols + min_cols + max_cols

df_spectra_all.shape
# Out:
# (1030, 24636)

# %% [markdown]
# # Functions

# %%
def get_dataset(df_spectra_all, dataset_y, agg_func):

  if agg_func == 'mean':
    dataset_x = df_spectra_all[mean_cols].copy()
  elif agg_func == 'min':
    dataset_x = df_spectra_all[min_cols].copy()

  elif agg_func == 'max':
    dataset_x = df_spectra_all[max_cols].copy()

  # dataset_x = df_spectra_all.copy()
  dataset_x = dataset_x.T
  dataset_x.columns = ['bin_' + str(x) for x in dataset_x.columns]
  dataset_x.reset_index(inplace=True)
  dataset_x.index = dataset_x['index'].apply(lambda x: x.split('_')[0])

  dataset_y = dataset_y[dataset_y['yunits'] == 'ABSORBANCE']

  dataset_final = pd.merge(dataset_y, dataset_x, left_index = True, right_index = True, how='inner')

  return dataset_final

def find_best_epoch(history):
    """
    Finds the epoch with the lowest validation loss.

    Args:
        history: Training history object from Keras model.fit().

    Returns:
        A tuple containing the best epoch number and its corresponding validation loss.
        Returns None if history object is invalid or empty.
    """
    if not history or 'val_loss' not in history.history:
        return None

    val_losses = history.history['val_loss']
    best_epoch = np.argmin(val_losses)  # Index of the minimum validation loss
    best_val_loss = val_losses[best_epoch]

    return best_epoch, best_val_loss

# %%
agg_func = 'max'
current_date = datetime.now().strftime('%Y_%m_%d')

dataset_final = get_dataset(df_spectra_all, dataset_y, agg_func)

X = dataset_final[[col for col in dataset_final.columns if 'bin' in col]]
X = X.apply(pd.to_numeric, errors='coerce').fillna(0)

Y = dataset_final[column_names].apply(lambda x: x.astype(int))
X_train, X_test_temp, Y_train, Y_test_temp = train_test_split(X, Y, test_size=0.25, random_state=42)

X_validation, X_test, Y_validation, Y_test = train_test_split(X_test_temp, Y_test_temp, test_size=0.45, random_state=42)

# Reshape input data for LSTM
X_train = np.array(X_train).reshape((X_train.shape[0], X_train.shape[1], 1))
X_validation = np.array(X_validation).reshape((X_validation.shape[0], X_validation.shape[1], 1))
X_test = np.array(X_test).reshape((X_test.shape[0], X_test.shape[1], 1))
X_test_temp = np.array(X_test_temp).reshape((X_test_temp.shape[0], X_test_temp.shape[1], 1))

# %%
def compute_model_analysis(agg_func, data_prep, current_date, batch_size=380, epochs=100, callbacks=False, save_history=True, save_figure=False):
    dataset_final = get_dataset(df_spectra_all, dataset_y, agg_func)

    X = dataset_final[[col for col in dataset_final.columns if 'bin' in col]]
    X = X.apply(pd.to_numeric, errors='coerce').fillna(0)

    if data_prep == 'encoder':
        X = encoder_model_load.predict(X)

    Y = dataset_final[column_names].apply(lambda x: x.astype(int))
    X_train, X_test_temp, Y_train, Y_test_temp = train_test_split(X, Y, test_size=0.20, random_state=42, stratify=Y[column_names].sum(axis=1))

    X_validation, X_test, Y_validation, Y_test = train_test_split(X_test_temp, Y_test_temp, test_size=0.30, random_state=42, stratify=Y_test_temp[column_names].sum(axis=1))
    data_type = np.float32

    # Reshape input data for Conv1D
    X_train_reshaped = np.expand_dims(np.array(X_train, dtype=data_type), axis=2)
    X_validation_reshaped = np.expand_dims(np.array(X_validation, dtype=data_type), axis=2)
    X_test_reshaped = np.expand_dims(np.array(X_test, dtype=data_type), axis=2)
    X_test_temp_reshaped = np.expand_dims(np.array(X_test_temp, dtype=data_type), axis=2)

    model = Sequential([
        layers.Input(shape=(X_train_reshaped.shape[1], 1)),
        layers.Conv1D(filters=36, kernel_size=6, activation='relu', padding='same'),
        layers.MaxPooling1D(pool_size=3),
        layers.Conv1D(filters=36, kernel_size=6, activation='relu', padding='same'),
        layers.MaxPooling1D(pool_size=3),
        layers.Conv1D(filters=128, kernel_size=6, activation='relu', padding='same'),
        layers.MaxPooling1D(pool_size=2),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(Y_train.shape[1], activation='sigmoid')
    ])

    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy', 'binary_accuracy', 'precision', 'recall', 'binary_crossentropy'])

    # Callbacks
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='min', start_from_epoch=50, restore_best_weights=True)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-8, verbose=0, mode='min')
    callbacks_list = [early_stopping, reduce_lr] if callbacks else []

    history = model.fit(X_train_reshaped, Y_train,
                        validation_data=(X_validation_reshaped, Y_validation),
                        callbacks=callbacks_list,
                        epochs=epochs, verbose=1, shuffle=True, batch_size=batch_size)

    # Avaliação e salvamento
    val_loss = history.history['val_loss'][-1]

    y_pred = model.predict(X_validation_reshaped)
    y_pred = (y_pred > 0.5).astype(int)

    compose_name = f'conv1d_{agg_func}_{data_prep}_{current_date}_call_{callbacks}'
    model_save_path = os.path.join(MODELS_DIR, f'{compose_name}.keras')
    model.save(model_save_path)

    if save_history:
        history_save_path = os.path.join(HISTORY_DIR if 'HISTORY_DIR' in globals() else RESULTS_DIR, f'{compose_name}_history.pkl')
        with open(history_save_path, 'wb') as f:
            pickle.dump(history.history, f)

    best_epoch, best_val_loss = find_best_epoch(history)

    if save_figure:
        plt.figure(figsize=(16, 10))
        plt.suptitle(f'Métricas Treinamento - Época Escolhida {best_epoch} - {best_val_loss:.3f} Validação Loss Function')

        plt.subplot(3, 1, 1)
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.axvline(x=best_epoch, color='red', linestyle='--')
        plt.ylabel('Acurácia')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.3f}".format(x)))

        plt.subplot(3, 1, 2)
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.axvline(x=best_epoch, color='red', linestyle='--')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.3f}".format(x)))

        plt.subplot(3, 1, 3)
        plt.plot(history.history['binary_accuracy'])
        plt.plot(history.history['val_binary_accuracy'])
        plt.axvline(x=best_epoch, color='red', linestyle='--')
        plt.ylabel('Acurácia Binarizada')
        plt.xlabel('Epoch')
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.3f}".format(x)))
        fig_save_path = os.path.join(RESULTS_DIR, f'{compose_name}.png')
        plt.savefig(fig_save_path)
        plt.show()

    return history

# %%
callbacks = False
epochs = 100
batch_size = 600
compute_model_analysis('min', 'normal', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
compute_model_analysis('min', 'encoder', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
compute_model_analysis('max', 'normal', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
compute_model_analysis('max', 'encoder', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
compute_model_analysis('mean', 'normal', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
compute_model_analysis('mean', 'encoder', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.5265 - binary_accuracy: 0.7339 - binary_crossentropy: 0.6245 - f1_score: 0.0568 - loss: 0.6245 - precision: 0.3922 - recall: 0.4688 - val_accuracy: 0.7119 - val_binary_accuracy: 0.8575 - val_binary_crossentropy: 0.3873 - val_f1_score: 0.0544 - val_loss: 0.3873 - val_precision: 0.6664 - val_recall: 0.5670
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.5836 - binary_accuracy: 0.8632 - binary_crossentropy: 0.3707 - f1_score: 0.0856 - loss: 0.3707 - precision: 0.6961 - recall: 0.5468 - val_accuracy: 0.5883 - val_binary_accuracy: 0.8727 - val_binary_crossentropy: 0.3262 - val_f1_score: 0.0999 - val_loss: 0.3262 - val_precision: 0.7551 - val_recall: 0.5322
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5736 - binary_accuracy: 0.8724 - binary_crossentropy: 0.3197 - f1_score: 0.0972 - loss: 0.3197 - precision: 0.7457 - recall: 0.5481 - val_accuracy: 0.5361 - val_binary_accuracy: 0.8868 - val_binary_crossentropy: 0.2910 - val_f1_score: 0.0998 - val_loss: 0.2910 - val_precision: 0.8257 - val_recall: 0.5456
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5105 - binary_accuracy: 0.8911 - binary_crossentropy: 0.2842 - f1_score: 0.1056 - loss: 0.2842 - precision: 0.8338 - recall: 0.5674 - val_accuracy: 0.5570 - val_binary_accuracy: 0.9010 - val_binary_crossentropy: 0.2611 - val_f1_score: 0.1207 - val_loss: 0.2611 - val_precision: 0.8211 - val_recall: 0.6419
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5326 - binary_accuracy: 0.9022 - binary_crossentropy: 0.2565 - f1_score: 0.1167 - loss: 0.2565 - precision: 0.8232 - recall: 0.6464 - val_accuracy: 0.5544 - val_binary_accuracy: 0.9069 - val_binary_crossentropy: 0.2373 - val_f1_score: 0.1229 - val_loss: 0.2373 - val_precision: 0.8263 - val_recall: 0.6728
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5246 - binary_accuracy: 0.9116 - binary_crossentropy: 0.2297 - f1_score: 0.1245 - loss: 0.2297 - precision: 0.8384 - recall: 0.6836 - val_accuracy: 0.5265 - val_binary_accuracy: 0.9139 - val_binary_crossentropy: 0.2200 - val_f1_score: 0.1392 - val_loss: 0.2200 - val_precision: 0.8444 - val_recall: 0.6950
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4927 - binary_accuracy: 0.9171 - binary_crossentropy: 0.2133 - f1_score: 0.1393 - loss: 0.2133 - precision: 0.8470 - recall: 0.7124 - val_accuracy: 0.5004 - val_binary_accuracy: 0.9205 - val_binary_crossentropy: 0.2064 - val_f1_score: 0.1643 - val_loss: 0.2064 - val_precision: 0.8567 - val_recall: 0.7205
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4588 - binary_accuracy: 0.9218 - binary_crossentropy: 0.2004 - f1_score: 0.1608 - loss: 0.2004 - precision: 0.8527 - recall: 0.7343 - val_accuracy: 0.4656 - val_binary_accuracy: 0.9230 - val_binary_crossentropy: 0.1957 - val_f1_score: 0.1828 - val_loss: 0.1957 - val_precision: 0.8532 - val_recall: 0.7396
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4435 - binary_accuracy: 0.9265 - binary_crossentropy: 0.1915 - f1_score: 0.1879 - loss: 0.1915 - precision: 0.8611 - recall: 0.7526 - val_accuracy: 0.4726 - val_binary_accuracy: 0.9284 - val_binary_crossentropy: 0.1865 - val_f1_score: 0.1847 - val_loss: 0.1865 - val_precision: 0.8534 - val_recall: 0.7723
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4387 - binary_accuracy: 0.9302 - binary_crossentropy: 0.1815 - f1_score: 0.1969 - loss: 0.1815 - precision: 0.8640 - recall: 0.7711 - val_accuracy: 0.4282 - val_binary_accuracy: 0.9330 - val_binary_crossentropy: 0.1772 - val_f1_score: 0.2357 - val_loss: 0.1772 - val_precision: 0.8737 - val_recall: 0.7749
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4282 - binary_accuracy: 0.9350 - binary_crossentropy: 0.1694 - f1_score: 0.2163 - loss: 0.1694 - precision: 0.8734 - recall: 0.7872 - val_accuracy: 0.4839 - val_binary_accuracy: 0.9345 - val_binary_crossentropy: 0.1700 - val_f1_score: 0.1985 - val_loss: 0.1700 - val_precision: 0.8743 - val_recall: 0.7831
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4409 - binary_accuracy: 0.9382 - binary_crossentropy: 0.1616 - f1_score: 0.2185 - loss: 0.1616 - precision: 0.8804 - recall: 0.7973 - val_accuracy: 0.4326 - val_binary_accuracy: 0.9374 - val_binary_crossentropy: 0.1617 - val_f1_score: 0.2717 - val_loss: 0.1617 - val_precision: 0.8851 - val_recall: 0.7875
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4211 - binary_accuracy: 0.9408 - binary_crossentropy: 0.1549 - f1_score: 0.2536 - loss: 0.1549 - precision: 0.8848 - recall: 0.8090 - val_accuracy: 0.4386 - val_binary_accuracy: 0.9405 - val_binary_crossentropy: 0.1538 - val_f1_score: 0.2550 - val_loss: 0.1538 - val_precision: 0.8988 - val_recall: 0.7893
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4280 - binary_accuracy: 0.9453 - binary_crossentropy: 0.1451 - f1_score: 0.2428 - loss: 0.1451 - precision: 0.8941 - recall: 0.8200 - val_accuracy: 0.4369 - val_binary_accuracy: 0.9445 - val_binary_crossentropy: 0.1463 - val_f1_score: 0.2338 - val_loss: 0.1463 - val_precision: 0.8880 - val_recall: 0.8248
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4314 - binary_accuracy: 0.9479 - binary_crossentropy: 0.1356 - f1_score: 0.2529 - loss: 0.1356 - precision: 0.8986 - recall: 0.8308 - val_accuracy: 0.4221 - val_binary_accuracy: 0.9468 - val_binary_crossentropy: 0.1411 - val_f1_score: 0.2494 - val_loss: 0.1411 - val_precision: 0.8945 - val_recall: 0.8300
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4127 - binary_accuracy: 0.9514 - binary_crossentropy: 0.1296 - f1_score: 0.2523 - loss: 0.1296 - precision: 0.9039 - recall: 0.8444 - val_accuracy: 0.3960 - val_binary_accuracy: 0.9493 - val_binary_crossentropy: 0.1370 - val_f1_score: 0.2226 - val_loss: 0.1370 - val_precision: 0.8999 - val_recall: 0.8382
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4092 - binary_accuracy: 0.9530 - binary_crossentropy: 0.1278 - f1_score: 0.2596 - loss: 0.1278 - precision: 0.9086 - recall: 0.8500 - val_accuracy: 0.4604 - val_binary_accuracy: 0.9479 - val_binary_crossentropy: 0.1360 - val_f1_score: 0.2976 - val_loss: 0.1360 - val_precision: 0.8967 - val_recall: 0.8341
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4133 - binary_accuracy: 0.9529 - binary_crossentropy: 0.1262 - f1_score: 0.2650 - loss: 0.1262 - precision: 0.9051 - recall: 0.8537 - val_accuracy: 0.4082 - val_binary_accuracy: 0.9522 - val_binary_crossentropy: 0.1304 - val_f1_score: 0.2372 - val_loss: 0.1304 - val_precision: 0.8944 - val_recall: 0.8614
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4257 - binary_accuracy: 0.9562 - binary_crossentropy: 0.1172 - f1_score: 0.2547 - loss: 0.1172 - precision: 0.9110 - recall: 0.8648 - val_accuracy: 0.4073 - val_binary_accuracy: 0.9533 - val_binary_crossentropy: 0.1265 - val_f1_score: 0.2684 - val_loss: 0.1265 - val_precision: 0.9127 - val_recall: 0.8457
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4127 - binary_accuracy: 0.9572 - binary_crossentropy: 0.1154 - f1_score: 0.2698 - loss: 0.1154 - precision: 0.9185 - recall: 0.8622 - val_accuracy: 0.4326 - val_binary_accuracy: 0.9534 - val_binary_crossentropy: 0.1246 - val_f1_score: 0.2735 - val_loss: 0.1246 - val_precision: 0.9100 - val_recall: 0.8496
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4150 - binary_accuracy: 0.9579 - binary_crossentropy: 0.1141 - f1_score: 0.2662 - loss: 0.1141 - precision: 0.9176 - recall: 0.8656 - val_accuracy: 0.4204 - val_binary_accuracy: 0.9559 - val_binary_crossentropy: 0.1197 - val_f1_score: 0.2588 - val_loss: 0.1197 - val_precision: 0.9079 - val_recall: 0.8660
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4366 - binary_accuracy: 0.9599 - binary_crossentropy: 0.1093 - f1_score: 0.2610 - loss: 0.1093 - precision: 0.9191 - recall: 0.8760 - val_accuracy: 0.4238 - val_binary_accuracy: 0.9574 - val_binary_crossentropy: 0.1174 - val_f1_score: 0.2553 - val_loss: 0.1174 - val_precision: 0.9097 - val_recall: 0.8720
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4235 - binary_accuracy: 0.9606 - binary_crossentropy: 0.1069 - f1_score: 0.2665 - loss: 0.1069 - precision: 0.9207 - recall: 0.8775 - val_accuracy: 0.4099 - val_binary_accuracy: 0.9556 - val_binary_crossentropy: 0.1218 - val_f1_score: 0.2352 - val_loss: 0.1218 - val_precision: 0.8831 - val_recall: 0.8949
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4251 - binary_accuracy: 0.9608 - binary_crossentropy: 0.1079 - f1_score: 0.2685 - loss: 0.1079 - precision: 0.9138 - recall: 0.8862 - val_accuracy: 0.4386 - val_binary_accuracy: 0.9581 - val_binary_crossentropy: 0.1137 - val_f1_score: 0.2620 - val_loss: 0.1137 - val_precision: 0.9090 - val_recall: 0.8771
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4233 - binary_accuracy: 0.9631 - binary_crossentropy: 0.1012 - f1_score: 0.2704 - loss: 0.1012 - precision: 0.9278 - recall: 0.8840 - val_accuracy: 0.4282 - val_binary_accuracy: 0.9583 - val_binary_crossentropy: 0.1121 - val_f1_score: 0.2619 - val_loss: 0.1121 - val_precision: 0.9153 - val_recall: 0.8709
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4298 - binary_accuracy: 0.9629 - binary_crossentropy: 0.1014 - f1_score: 0.2699 - loss: 0.1014 - precision: 0.9295 - recall: 0.8812 - val_accuracy: 0.4038 - val_binary_accuracy: 0.9604 - val_binary_crossentropy: 0.1120 - val_f1_score: 0.2611 - val_loss: 0.1120 - val_precision: 0.9109 - val_recall: 0.8877
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4076 - binary_accuracy: 0.9645 - binary_crossentropy: 0.0977 - f1_score: 0.2808 - loss: 0.0977 - precision: 0.9274 - recall: 0.8913 - val_accuracy: 0.4369 - val_binary_accuracy: 0.9609 - val_binary_crossentropy: 0.1091 - val_f1_score: 0.2411 - val_loss: 0.1091 - val_precision: 0.9079 - val_recall: 0.8939
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4221 - binary_accuracy: 0.9656 - binary_crossentropy: 0.0953 - f1_score: 0.2870 - loss: 0.0953 - precision: 0.9320 - recall: 0.8922 - val_accuracy: 0.4326 - val_binary_accuracy: 0.9611 - val_binary_crossentropy: 0.1082 - val_f1_score: 0.2477 - val_loss: 0.1082 - val_precision: 0.9147 - val_recall: 0.8869
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4260 - binary_accuracy: 0.9669 - binary_crossentropy: 0.0920 - f1_score: 0.2681 - loss: 0.0920 - precision: 0.9352 - recall: 0.8950 - val_accuracy: 0.4134 - val_binary_accuracy: 0.9613 - val_binary_crossentropy: 0.1065 - val_f1_score: 0.2528 - val_loss: 0.1065 - val_precision: 0.9182 - val_recall: 0.8843
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4289 - binary_accuracy: 0.9664 - binary_crossentropy: 0.0934 - f1_score: 0.2735 - loss: 0.0934 - precision: 0.9319 - recall: 0.8959 - val_accuracy: 0.4404 - val_binary_accuracy: 0.9615 - val_binary_crossentropy: 0.1062 - val_f1_score: 0.2478 - val_loss: 0.1062 - val_precision: 0.9086 - val_recall: 0.8964
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4206 - binary_accuracy: 0.9669 - binary_crossentropy: 0.0905 - f1_score: 0.2740 - loss: 0.0905 - precision: 0.9303 - recall: 0.9007 - val_accuracy: 0.4178 - val_binary_accuracy: 0.9622 - val_binary_crossentropy: 0.1046 - val_f1_score: 0.2699 - val_loss: 0.1046 - val_precision: 0.9235 - val_recall: 0.8830
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4293 - binary_accuracy: 0.9682 - binary_crossentropy: 0.0883 - f1_score: 0.2714 - loss: 0.0883 - precision: 0.9375 - recall: 0.8999 - val_accuracy: 0.4064 - val_binary_accuracy: 0.9621 - val_binary_crossentropy: 0.1050 - val_f1_score: 0.2602 - val_loss: 0.1050 - val_precision: 0.9180 - val_recall: 0.8887
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4183 - binary_accuracy: 0.9688 - binary_crossentropy: 0.0871 - f1_score: 0.2788 - loss: 0.0871 - precision: 0.9380 - recall: 0.9026 - val_accuracy: 0.4265 - val_binary_accuracy: 0.9620 - val_binary_crossentropy: 0.1036 - val_f1_score: 0.2824 - val_loss: 0.1036 - val_precision: 0.9230 - val_recall: 0.8825
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4366 - binary_accuracy: 0.9690 - binary_crossentropy: 0.0859 - f1_score: 0.2831 - loss: 0.0859 - precision: 0.9387 - recall: 0.9031 - val_accuracy: 0.4038 - val_binary_accuracy: 0.9641 - val_binary_crossentropy: 0.1018 - val_f1_score: 0.2546 - val_loss: 0.1018 - val_precision: 0.9281 - val_recall: 0.8879
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4335 - binary_accuracy: 0.9711 - binary_crossentropy: 0.0816 - f1_score: 0.2780 - loss: 0.0816 - precision: 0.9430 - recall: 0.9091 - val_accuracy: 0.4447 - val_binary_accuracy: 0.9655 - val_binary_crossentropy: 0.0990 - val_f1_score: 0.2548 - val_loss: 0.0990 - val_precision: 0.9291 - val_recall: 0.8946
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4397 - binary_accuracy: 0.9719 - binary_crossentropy: 0.0801 - f1_score: 0.2690 - loss: 0.0801 - precision: 0.9447 - recall: 0.9126 - val_accuracy: 0.4108 - val_binary_accuracy: 0.9641 - val_binary_crossentropy: 0.1006 - val_f1_score: 0.2518 - val_loss: 0.1006 - val_precision: 0.9152 - val_recall: 0.9031
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4298 - binary_accuracy: 0.9714 - binary_crossentropy: 0.0795 - f1_score: 0.2791 - loss: 0.0795 - precision: 0.9433 - recall: 0.9116 - val_accuracy: 0.4404 - val_binary_accuracy: 0.9656 - val_binary_crossentropy: 0.0981 - val_f1_score: 0.2333 - val_loss: 0.0981 - val_precision: 0.9219 - val_recall: 0.9034
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4312 - binary_accuracy: 0.9713 - binary_crossentropy: 0.0810 - f1_score: 0.2803 - loss: 0.0810 - precision: 0.9445 - recall: 0.9091 - val_accuracy: 0.4160 - val_binary_accuracy: 0.9644 - val_binary_crossentropy: 0.0999 - val_f1_score: 0.2411 - val_loss: 0.0999 - val_precision: 0.9255 - val_recall: 0.8928
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4322 - binary_accuracy: 0.9724 - binary_crossentropy: 0.0770 - f1_score: 0.2749 - loss: 0.0770 - precision: 0.9456 - recall: 0.9129 - val_accuracy: 0.4282 - val_binary_accuracy: 0.9653 - val_binary_crossentropy: 0.0976 - val_f1_score: 0.2586 - val_loss: 0.0976 - val_precision: 0.9286 - val_recall: 0.8944
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4413 - binary_accuracy: 0.9724 - binary_crossentropy: 0.0780 - f1_score: 0.2792 - loss: 0.0780 - precision: 0.9462 - recall: 0.9133 - val_accuracy: 0.4830 - val_binary_accuracy: 0.9656 - val_binary_crossentropy: 0.0972 - val_f1_score: 0.2493 - val_loss: 0.0972 - val_precision: 0.9319 - val_recall: 0.8923
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4441 - binary_accuracy: 0.9731 - binary_crossentropy: 0.0778 - f1_score: 0.2749 - loss: 0.0778 - precision: 0.9498 - recall: 0.9132 - val_accuracy: 0.4604 - val_binary_accuracy: 0.9677 - val_binary_crossentropy: 0.0952 - val_f1_score: 0.2485 - val_loss: 0.0952 - val_precision: 0.9225 - val_recall: 0.9142
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4340 - binary_accuracy: 0.9748 - binary_crossentropy: 0.0724 - f1_score: 0.2749 - loss: 0.0724 - precision: 0.9472 - recall: 0.9252 - val_accuracy: 0.4030 - val_binary_accuracy: 0.9661 - val_binary_crossentropy: 0.0963 - val_f1_score: 0.2362 - val_loss: 0.0963 - val_precision: 0.9208 - val_recall: 0.9073
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4313 - binary_accuracy: 0.9753 - binary_crossentropy: 0.0708 - f1_score: 0.2707 - loss: 0.0708 - precision: 0.9517 - recall: 0.9219 - val_accuracy: 0.4413 - val_binary_accuracy: 0.9666 - val_binary_crossentropy: 0.0941 - val_f1_score: 0.2376 - val_loss: 0.0941 - val_precision: 0.9286 - val_recall: 0.9011
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4392 - binary_accuracy: 0.9750 - binary_crossentropy: 0.0727 - f1_score: 0.2860 - loss: 0.0727 - precision: 0.9520 - recall: 0.9213 - val_accuracy: 0.4761 - val_binary_accuracy: 0.9658 - val_binary_crossentropy: 0.0966 - val_f1_score: 0.2288 - val_loss: 0.0966 - val_precision: 0.9231 - val_recall: 0.9029
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4415 - binary_accuracy: 0.9756 - binary_crossentropy: 0.0702 - f1_score: 0.2701 - loss: 0.0702 - precision: 0.9533 - recall: 0.9232 - val_accuracy: 0.4151 - val_binary_accuracy: 0.9658 - val_binary_crossentropy: 0.0966 - val_f1_score: 0.2551 - val_loss: 0.0966 - val_precision: 0.9338 - val_recall: 0.8908
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4234 - binary_accuracy: 0.9754 - binary_crossentropy: 0.0694 - f1_score: 0.2733 - loss: 0.0694 - precision: 0.9504 - recall: 0.9253 - val_accuracy: 0.4526 - val_binary_accuracy: 0.9650 - val_binary_crossentropy: 0.0972 - val_f1_score: 0.2641 - val_loss: 0.0972 - val_precision: 0.9287 - val_recall: 0.8923
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4337 - binary_accuracy: 0.9759 - binary_crossentropy: 0.0702 - f1_score: 0.2870 - loss: 0.0702 - precision: 0.9550 - recall: 0.9224 - val_accuracy: 0.4404 - val_binary_accuracy: 0.9664 - val_binary_crossentropy: 0.0933 - val_f1_score: 0.2584 - val_loss: 0.0933 - val_precision: 0.9211 - val_recall: 0.9088
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4469 - binary_accuracy: 0.9772 - binary_crossentropy: 0.0653 - f1_score: 0.2878 - loss: 0.0653 - precision: 0.9543 - recall: 0.9302 - val_accuracy: 0.4265 - val_binary_accuracy: 0.9670 - val_binary_crossentropy: 0.0949 - val_f1_score: 0.2250 - val_loss: 0.0949 - val_precision: 0.9201 - val_recall: 0.9134
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4311 - binary_accuracy: 0.9785 - binary_crossentropy: 0.0625 - f1_score: 0.2814 - loss: 0.0625 - precision: 0.9578 - recall: 0.9331 - val_accuracy: 0.4447 - val_binary_accuracy: 0.9676 - val_binary_crossentropy: 0.0924 - val_f1_score: 0.2433 - val_loss: 0.0924 - val_precision: 0.9287 - val_recall: 0.9065
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4452 - binary_accuracy: 0.9789 - binary_crossentropy: 0.0613 - f1_score: 0.2742 - loss: 0.0613 - precision: 0.9591 - recall: 0.9330 - val_accuracy: 0.4352 - val_binary_accuracy: 0.9673 - val_binary_crossentropy: 0.0934 - val_f1_score: 0.2442 - val_loss: 0.0934 - val_precision: 0.9191 - val_recall: 0.9160
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4464 - binary_accuracy: 0.9778 - binary_crossentropy: 0.0645 - f1_score: 0.2712 - loss: 0.0645 - precision: 0.9536 - recall: 0.9339 - val_accuracy: 0.4238 - val_binary_accuracy: 0.9671 - val_binary_crossentropy: 0.0941 - val_f1_score: 0.2462 - val_loss: 0.0941 - val_precision: 0.9195 - val_recall: 0.9147
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4327 - binary_accuracy: 0.9788 - binary_crossentropy: 0.0608 - f1_score: 0.2846 - loss: 0.0608 - precision: 0.9558 - recall: 0.9372 - val_accuracy: 0.4308 - val_binary_accuracy: 0.9670 - val_binary_crossentropy: 0.0942 - val_f1_score: 0.2532 - val_loss: 0.0942 - val_precision: 0.9310 - val_recall: 0.9008
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4483 - binary_accuracy: 0.9799 - binary_crossentropy: 0.0597 - f1_score: 0.2777 - loss: 0.0597 - precision: 0.9612 - recall: 0.9359 - val_accuracy: 0.4578 - val_binary_accuracy: 0.9683 - val_binary_crossentropy: 0.0917 - val_f1_score: 0.2474 - val_loss: 0.0917 - val_precision: 0.9322 - val_recall: 0.9065
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4489 - binary_accuracy: 0.9794 - binary_crossentropy: 0.0602 - f1_score: 0.2849 - loss: 0.0602 - precision: 0.9597 - recall: 0.9357 - val_accuracy: 0.4360 - val_binary_accuracy: 0.9686 - val_binary_crossentropy: 0.0933 - val_f1_score: 0.2573 - val_loss: 0.0933 - val_precision: 0.9278 - val_recall: 0.9132
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4462 - binary_accuracy: 0.9802 - binary_crossentropy: 0.0565 - f1_score: 0.2847 - loss: 0.0565 - precision: 0.9598 - recall: 0.9389 - val_accuracy: 0.4822 - val_binary_accuracy: 0.9683 - val_binary_crossentropy: 0.0951 - val_f1_score: 0.2296 - val_loss: 0.0951 - val_precision: 0.9254 - val_recall: 0.9140
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4455 - binary_accuracy: 0.9800 - binary_crossentropy: 0.0585 - f1_score: 0.2702 - loss: 0.0585 - precision: 0.9592 - recall: 0.9392 - val_accuracy: 0.4143 - val_binary_accuracy: 0.9674 - val_binary_crossentropy: 0.0952 - val_f1_score: 0.2455 - val_loss: 0.0952 - val_precision: 0.9130 - val_recall: 0.9243
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4319 - binary_accuracy: 0.9806 - binary_crossentropy: 0.0562 - f1_score: 0.2794 - loss: 0.0562 - precision: 0.9590 - recall: 0.9429 - val_accuracy: 0.4404 - val_binary_accuracy: 0.9690 - val_binary_crossentropy: 0.0936 - val_f1_score: 0.2431 - val_loss: 0.0936 - val_precision: 0.9211 - val_recall: 0.9230
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4344 - binary_accuracy: 0.9809 - binary_crossentropy: 0.0547 - f1_score: 0.2747 - loss: 0.0547 - precision: 0.9596 - recall: 0.9445 - val_accuracy: 0.4430 - val_binary_accuracy: 0.9684 - val_binary_crossentropy: 0.0931 - val_f1_score: 0.2450 - val_loss: 0.0931 - val_precision: 0.9274 - val_recall: 0.9122
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4359 - binary_accuracy: 0.9814 - binary_crossentropy: 0.0552 - f1_score: 0.2843 - loss: 0.0552 - precision: 0.9627 - recall: 0.9425 - val_accuracy: 0.4308 - val_binary_accuracy: 0.9685 - val_binary_crossentropy: 0.0947 - val_f1_score: 0.2545 - val_loss: 0.0947 - val_precision: 0.9297 - val_recall: 0.9101
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4413 - binary_accuracy: 0.9818 - binary_crossentropy: 0.0531 - f1_score: 0.2938 - loss: 0.0531 - precision: 0.9647 - recall: 0.9425 - val_accuracy: 0.4386 - val_binary_accuracy: 0.9683 - val_binary_crossentropy: 0.0935 - val_f1_score: 0.2443 - val_loss: 0.0935 - val_precision: 0.9223 - val_recall: 0.9178
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4423 - binary_accuracy: 0.9823 - binary_crossentropy: 0.0535 - f1_score: 0.2790 - loss: 0.0535 - precision: 0.9647 - recall: 0.9456 - val_accuracy: 0.4735 - val_binary_accuracy: 0.9691 - val_binary_crossentropy: 0.0939 - val_f1_score: 0.2458 - val_loss: 0.0939 - val_precision: 0.9300 - val_recall: 0.9132
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4527 - binary_accuracy: 0.9820 - binary_crossentropy: 0.0530 - f1_score: 0.2712 - loss: 0.0530 - precision: 0.9658 - recall: 0.9432 - val_accuracy: 0.4717 - val_binary_accuracy: 0.9698 - val_binary_crossentropy: 0.0921 - val_f1_score: 0.2390 - val_loss: 0.0921 - val_precision: 0.9295 - val_recall: 0.9176
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4519 - binary_accuracy: 0.9830 - binary_crossentropy: 0.0513 - f1_score: 0.2761 - loss: 0.0513 - precision: 0.9666 - recall: 0.9471 - val_accuracy: 0.4656 - val_binary_accuracy: 0.9695 - val_binary_crossentropy: 0.0913 - val_f1_score: 0.2476 - val_loss: 0.0913 - val_precision: 0.9283 - val_recall: 0.9173
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4512 - binary_accuracy: 0.9836 - binary_crossentropy: 0.0490 - f1_score: 0.2789 - loss: 0.0490 - precision: 0.9667 - recall: 0.9506 - val_accuracy: 0.4560 - val_binary_accuracy: 0.9689 - val_binary_crossentropy: 0.0937 - val_f1_score: 0.2393 - val_loss: 0.0937 - val_precision: 0.9235 - val_recall: 0.9199
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4332 - binary_accuracy: 0.9829 - binary_crossentropy: 0.0499 - f1_score: 0.2766 - loss: 0.0499 - precision: 0.9642 - recall: 0.9496 - val_accuracy: 0.4517 - val_binary_accuracy: 0.9689 - val_binary_crossentropy: 0.0941 - val_f1_score: 0.2343 - val_loss: 0.0941 - val_precision: 0.9204 - val_recall: 0.9232
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4308 - binary_accuracy: 0.9837 - binary_crossentropy: 0.0475 - f1_score: 0.2717 - loss: 0.0475 - precision: 0.9662 - recall: 0.9519 - val_accuracy: 0.4604 - val_binary_accuracy: 0.9678 - val_binary_crossentropy: 0.0967 - val_f1_score: 0.2520 - val_loss: 0.0967 - val_precision: 0.9275 - val_recall: 0.9091
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4458 - binary_accuracy: 0.9838 - binary_crossentropy: 0.0474 - f1_score: 0.2899 - loss: 0.0474 - precision: 0.9690 - recall: 0.9486 - val_accuracy: 0.4195 - val_binary_accuracy: 0.9692 - val_binary_crossentropy: 0.0944 - val_f1_score: 0.2657 - val_loss: 0.0944 - val_precision: 0.9286 - val_recall: 0.9152
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4480 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0455 - f1_score: 0.2797 - loss: 0.0455 - precision: 0.9697 - recall: 0.9525 - val_accuracy: 0.4413 - val_binary_accuracy: 0.9704 - val_binary_crossentropy: 0.0949 - val_f1_score: 0.2359 - val_loss: 0.0949 - val_precision: 0.9340 - val_recall: 0.9155
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4525 - binary_accuracy: 0.9843 - binary_crossentropy: 0.0453 - f1_score: 0.2831 - loss: 0.0453 - precision: 0.9687 - recall: 0.9517 - val_accuracy: 0.4308 - val_binary_accuracy: 0.9695 - val_binary_crossentropy: 0.0938 - val_f1_score: 0.2677 - val_loss: 0.0938 - val_precision: 0.9338 - val_recall: 0.9114
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4400 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0451 - f1_score: 0.2933 - loss: 0.0451 - precision: 0.9698 - recall: 0.9531 - val_accuracy: 0.4151 - val_binary_accuracy: 0.9696 - val_binary_crossentropy: 0.0949 - val_f1_score: 0.2593 - val_loss: 0.0949 - val_precision: 0.9370 - val_recall: 0.9080
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4354 - binary_accuracy: 0.9855 - binary_crossentropy: 0.0430 - f1_score: 0.2799 - loss: 0.0430 - precision: 0.9736 - recall: 0.9532 - val_accuracy: 0.4534 - val_binary_accuracy: 0.9697 - val_binary_crossentropy: 0.0956 - val_f1_score: 0.2626 - val_loss: 0.0956 - val_precision: 0.9293 - val_recall: 0.9173
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4478 - binary_accuracy: 0.9857 - binary_crossentropy: 0.0428 - f1_score: 0.2942 - loss: 0.0428 - precision: 0.9705 - recall: 0.9570 - val_accuracy: 0.4848 - val_binary_accuracy: 0.9701 - val_binary_crossentropy: 0.0957 - val_f1_score: 0.2500 - val_loss: 0.0957 - val_precision: 0.9296 - val_recall: 0.9189
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4603 - binary_accuracy: 0.9858 - binary_crossentropy: 0.0429 - f1_score: 0.2831 - loss: 0.0429 - precision: 0.9738 - recall: 0.9549 - val_accuracy: 0.4552 - val_binary_accuracy: 0.9687 - val_binary_crossentropy: 0.0964 - val_f1_score: 0.2528 - val_loss: 0.0964 - val_precision: 0.9332 - val_recall: 0.9073
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4416 - binary_accuracy: 0.9855 - binary_crossentropy: 0.0430 - f1_score: 0.2982 - loss: 0.0430 - precision: 0.9718 - recall: 0.9545 - val_accuracy: 0.4674 - val_binary_accuracy: 0.9699 - val_binary_crossentropy: 0.0956 - val_f1_score: 0.2553 - val_loss: 0.0956 - val_precision: 0.9336 - val_recall: 0.9134
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4459 - binary_accuracy: 0.9863 - binary_crossentropy: 0.0409 - f1_score: 0.2907 - loss: 0.0409 - precision: 0.9732 - recall: 0.9573 - val_accuracy: 0.5283 - val_binary_accuracy: 0.9686 - val_binary_crossentropy: 0.1000 - val_f1_score: 0.2392 - val_loss: 0.1000 - val_precision: 0.9253 - val_recall: 0.9160
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4548 - binary_accuracy: 0.9854 - binary_crossentropy: 0.0426 - f1_score: 0.2835 - loss: 0.0426 - precision: 0.9706 - recall: 0.9553 - val_accuracy: 0.4665 - val_binary_accuracy: 0.9688 - val_binary_crossentropy: 0.0974 - val_f1_score: 0.2432 - val_loss: 0.0974 - val_precision: 0.9191 - val_recall: 0.9245
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4609 - binary_accuracy: 0.9852 - binary_crossentropy: 0.0418 - f1_score: 0.2852 - loss: 0.0418 - precision: 0.9699 - recall: 0.9552 - val_accuracy: 0.4317 - val_binary_accuracy: 0.9692 - val_binary_crossentropy: 0.0989 - val_f1_score: 0.2458 - val_loss: 0.0989 - val_precision: 0.9203 - val_recall: 0.9253
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4455 - binary_accuracy: 0.9866 - binary_crossentropy: 0.0399 - f1_score: 0.2761 - loss: 0.0399 - precision: 0.9699 - recall: 0.9623 - val_accuracy: 0.4613 - val_binary_accuracy: 0.9698 - val_binary_crossentropy: 0.0980 - val_f1_score: 0.2545 - val_loss: 0.0980 - val_precision: 0.9264 - val_recall: 0.9214
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4448 - binary_accuracy: 0.9871 - binary_crossentropy: 0.0389 - f1_score: 0.2757 - loss: 0.0389 - precision: 0.9738 - recall: 0.9611 - val_accuracy: 0.4456 - val_binary_accuracy: 0.9695 - val_binary_crossentropy: 0.0976 - val_f1_score: 0.2627 - val_loss: 0.0976 - val_precision: 0.9384 - val_recall: 0.9060
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4391 - binary_accuracy: 0.9871 - binary_crossentropy: 0.0373 - f1_score: 0.2878 - loss: 0.0373 - precision: 0.9762 - recall: 0.9583 - val_accuracy: 0.4482 - val_binary_accuracy: 0.9697 - val_binary_crossentropy: 0.0978 - val_f1_score: 0.2637 - val_loss: 0.0978 - val_precision: 0.9331 - val_recall: 0.9132
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4542 - binary_accuracy: 0.9887 - binary_crossentropy: 0.0348 - f1_score: 0.3024 - loss: 0.0348 - precision: 0.9786 - recall: 0.9645 - val_accuracy: 0.4439 - val_binary_accuracy: 0.9698 - val_binary_crossentropy: 0.0998 - val_f1_score: 0.2679 - val_loss: 0.0998 - val_precision: 0.9311 - val_recall: 0.9158
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4386 - binary_accuracy: 0.9884 - binary_crossentropy: 0.0353 - f1_score: 0.2922 - loss: 0.0353 - precision: 0.9789 - recall: 0.9625 - val_accuracy: 0.4526 - val_binary_accuracy: 0.9693 - val_binary_crossentropy: 0.1003 - val_f1_score: 0.2556 - val_loss: 0.1003 - val_precision: 0.9214 - val_recall: 0.9245
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4489 - binary_accuracy: 0.9887 - binary_crossentropy: 0.0336 - f1_score: 0.2908 - loss: 0.0336 - precision: 0.9759 - recall: 0.9672 - val_accuracy: 0.4795 - val_binary_accuracy: 0.9695 - val_binary_crossentropy: 0.1005 - val_f1_score: 0.2659 - val_loss: 0.1005 - val_precision: 0.9228 - val_recall: 0.9238
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4672 - binary_accuracy: 0.9894 - binary_crossentropy: 0.0335 - f1_score: 0.2833 - loss: 0.0335 - precision: 0.9789 - recall: 0.9676 - val_accuracy: 0.4587 - val_binary_accuracy: 0.9704 - val_binary_crossentropy: 0.0995 - val_f1_score: 0.2707 - val_loss: 0.0995 - val_precision: 0.9322 - val_recall: 0.9176
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4504 - binary_accuracy: 0.9900 - binary_crossentropy: 0.0321 - f1_score: 0.3040 - loss: 0.0321 - precision: 0.9795 - recall: 0.9698 - val_accuracy: 0.4639 - val_binary_accuracy: 0.9709 - val_binary_crossentropy: 0.1005 - val_f1_score: 0.2496 - val_loss: 0.1005 - val_precision: 0.9354 - val_recall: 0.9171
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4468 - binary_accuracy: 0.9899 - binary_crossentropy: 0.0310 - f1_score: 0.2891 - loss: 0.0310 - precision: 0.9808 - recall: 0.9682 - val_accuracy: 0.4926 - val_binary_accuracy: 0.9702 - val_binary_crossentropy: 0.1012 - val_f1_score: 0.2542 - val_loss: 0.1012 - val_precision: 0.9299 - val_recall: 0.9194
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4596 - binary_accuracy: 0.9908 - binary_crossentropy: 0.0307 - f1_score: 0.3045 - loss: 0.0307 - precision: 0.9816 - recall: 0.9720 - val_accuracy: 0.4874 - val_binary_accuracy: 0.9707 - val_binary_crossentropy: 0.1016 - val_f1_score: 0.2654 - val_loss: 0.1016 - val_precision: 0.9274 - val_recall: 0.9248
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4572 - binary_accuracy: 0.9896 - binary_crossentropy: 0.0322 - f1_score: 0.2991 - loss: 0.0322 - precision: 0.9793 - recall: 0.9685 - val_accuracy: 0.4848 - val_binary_accuracy: 0.9701 - val_binary_crossentropy: 0.1038 - val_f1_score: 0.2574 - val_loss: 0.1038 - val_precision: 0.9274 - val_recall: 0.9214
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4638 - binary_accuracy: 0.9913 - binary_crossentropy: 0.0278 - f1_score: 0.2980 - loss: 0.0278 - precision: 0.9817 - recall: 0.9744 - val_accuracy: 0.5274 - val_binary_accuracy: 0.9688 - val_binary_crossentropy: 0.1078 - val_f1_score: 0.2549 - val_loss: 0.1078 - val_precision: 0.9199 - val_recall: 0.9232
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4807 - binary_accuracy: 0.9898 - binary_crossentropy: 0.0316 - f1_score: 0.2953 - loss: 0.0316 - precision: 0.9787 - recall: 0.9696 - val_accuracy: 0.4526 - val_binary_accuracy: 0.9702 - val_binary_crossentropy: 0.1057 - val_f1_score: 0.2790 - val_loss: 0.1057 - val_precision: 0.9338 - val_recall: 0.9150
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4633 - binary_accuracy: 0.9909 - binary_crossentropy: 0.0290 - f1_score: 0.3026 - loss: 0.0290 - precision: 0.9822 - recall: 0.9716 - val_accuracy: 0.4700 - val_binary_accuracy: 0.9699 - val_binary_crossentropy: 0.1069 - val_f1_score: 0.2750 - val_loss: 0.1069 - val_precision: 0.9312 - val_recall: 0.9163
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4693 - binary_accuracy: 0.9916 - binary_crossentropy: 0.0276 - f1_score: 0.3044 - loss: 0.0276 - precision: 0.9820 - recall: 0.9756 - val_accuracy: 0.4735 - val_binary_accuracy: 0.9696 - val_binary_crossentropy: 0.1052 - val_f1_score: 0.2771 - val_loss: 0.1052 - val_precision: 0.9268 - val_recall: 0.9199
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4667 - binary_accuracy: 0.9926 - binary_crossentropy: 0.0260 - f1_score: 0.3138 - loss: 0.0260 - precision: 0.9853 - recall: 0.9773 - val_accuracy: 0.4943 - val_binary_accuracy: 0.9698 - val_binary_crossentropy: 0.1084 - val_f1_score: 0.2705 - val_loss: 0.1084 - val_precision: 0.9249 - val_recall: 0.9232
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4730 - binary_accuracy: 0.9918 - binary_crossentropy: 0.0271 - f1_score: 0.3063 - loss: 0.0271 - precision: 0.9828 - recall: 0.9758 - val_accuracy: 0.5030 - val_binary_accuracy: 0.9699 - val_binary_crossentropy: 0.1072 - val_f1_score: 0.2688 - val_loss: 0.1072 - val_precision: 0.9312 - val_recall: 0.9165
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4686 - binary_accuracy: 0.9921 - binary_crossentropy: 0.0257 - f1_score: 0.3097 - loss: 0.0257 - precision: 0.9852 - recall: 0.9750 - val_accuracy: 0.4630 - val_binary_accuracy: 0.9682 - val_binary_crossentropy: 0.1134 - val_f1_score: 0.2909 - val_loss: 0.1134 - val_precision: 0.9133 - val_recall: 0.9281
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4611 - binary_accuracy: 0.9916 - binary_crossentropy: 0.0274 - f1_score: 0.3081 - loss: 0.0274 - precision: 0.9825 - recall: 0.9748 - val_accuracy: 0.4517 - val_binary_accuracy: 0.9696 - val_binary_crossentropy: 0.1143 - val_f1_score: 0.2842 - val_loss: 0.1143 - val_precision: 0.9264 - val_recall: 0.9204
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4731 - binary_accuracy: 0.9919 - binary_crossentropy: 0.0263 - f1_score: 0.3135 - loss: 0.0263 - precision: 0.9839 - recall: 0.9754 - val_accuracy: 0.4830 - val_binary_accuracy: 0.9702 - val_binary_crossentropy: 0.1093 - val_f1_score: 0.2858 - val_loss: 0.1093 - val_precision: 0.9257 - val_recall: 0.9240
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4706 - binary_accuracy: 0.9929 - binary_crossentropy: 0.0237 - f1_score: 0.3226 - loss: 0.0237 - precision: 0.9839 - recall: 0.9802 - val_accuracy: 0.5283 - val_binary_accuracy: 0.9691 - val_binary_crossentropy: 0.1170 - val_f1_score: 0.2670 - val_loss: 0.1170 - val_precision: 0.9289 - val_recall: 0.9147
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4758 - binary_accuracy: 0.9914 - binary_crossentropy: 0.0261 - f1_score: 0.3117 - loss: 0.0261 - precision: 0.9822 - recall: 0.9743 - val_accuracy: 0.5022 - val_binary_accuracy: 0.9698 - val_binary_crossentropy: 0.1122 - val_f1_score: 0.2884 - val_loss: 0.1122 - val_precision: 0.9260 - val_recall: 0.9217
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4819 - binary_accuracy: 0.9933 - binary_crossentropy: 0.0223 - f1_score: 0.3186 - loss: 0.0223 - precision: 0.9859 - recall: 0.9804 - val_accuracy: 0.4865 - val_binary_accuracy: 0.9699 - val_binary_crossentropy: 0.1138 - val_f1_score: 0.2987 - val_loss: 0.1138 - val_precision: 0.9325 - val_recall: 0.9147
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.0920 - binary_accuracy: 0.7297 - binary_crossentropy: 0.6446 - f1_score: 0.0350 - loss: 0.6446 - precision: 0.3595 - recall: 0.4083 - val_accuracy: 0.1532 - val_binary_accuracy: 0.8505 - val_binary_crossentropy: 0.4907 - val_f1_score: 0.0463 - val_loss: 0.4907 - val_precision: 0.6420 - val_recall: 0.5595
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.1495 - binary_accuracy: 0.8489 - binary_crossentropy: 0.4603 - f1_score: 0.0458 - loss: 0.4603 - precision: 0.6356 - recall: 0.5613 - val_accuracy: 0.1532 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.4014 - val_f1_score: 0.0463 - val_loss: 0.4014 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.2725 - binary_accuracy: 0.8476 - binary_crossentropy: 0.3970 - f1_score: 0.0566 - loss: 0.3970 - precision: 0.6315 - recall: 0.5605 - val_accuracy: 0.4874 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3757 - val_f1_score: 0.0854 - val_loss: 0.3757 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.2146 - binary_accuracy: 0.8495 - binary_crossentropy: 0.3760 - f1_score: 0.0623 - loss: 0.3760 - precision: 0.6372 - recall: 0.5654 - val_accuracy: 0.6580 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3689 - val_f1_score: 0.0657 - val_loss: 0.3689 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6685 - binary_accuracy: 0.8489 - binary_crossentropy: 0.3721 - f1_score: 0.0552 - loss: 0.3721 - precision: 0.6324 - recall: 0.5643 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3661 - val_f1_score: 0.0485 - val_loss: 0.3661 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6778 - binary_accuracy: 0.8494 - binary_crossentropy: 0.3685 - f1_score: 0.0510 - loss: 0.3685 - precision: 0.6359 - recall: 0.5651 - val_accuracy: 0.5892 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3628 - val_f1_score: 0.0679 - val_loss: 0.3628 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6593 - binary_accuracy: 0.8492 - binary_crossentropy: 0.3656 - f1_score: 0.0563 - loss: 0.3656 - precision: 0.6361 - recall: 0.5645 - val_accuracy: 0.6406 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3595 - val_f1_score: 0.0786 - val_loss: 0.3595 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6349 - binary_accuracy: 0.8487 - binary_crossentropy: 0.3624 - f1_score: 0.0753 - loss: 0.3624 - precision: 0.6343 - recall: 0.5632 - val_accuracy: 0.7015 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3543 - val_f1_score: 0.0628 - val_loss: 0.3543 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6263 - binary_accuracy: 0.8484 - binary_crossentropy: 0.3569 - f1_score: 0.0801 - loss: 0.3569 - precision: 0.6342 - recall: 0.5615 - val_accuracy: 0.6928 - val_binary_accuracy: 0.8598 - val_binary_crossentropy: 0.3466 - val_f1_score: 0.0677 - val_loss: 0.3466 - val_precision: 0.6766 - val_recall: 0.5641
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6223 - binary_accuracy: 0.8598 - binary_crossentropy: 0.3454 - f1_score: 0.0835 - loss: 0.3454 - precision: 0.6744 - recall: 0.5606 - val_accuracy: 0.6319 - val_binary_accuracy: 0.8643 - val_binary_crossentropy: 0.3355 - val_f1_score: 0.0850 - val_loss: 0.3355 - val_precision: 0.6999 - val_recall: 0.5551
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5826 - binary_accuracy: 0.8632 - binary_crossentropy: 0.3333 - f1_score: 0.0885 - loss: 0.3333 - precision: 0.6994 - recall: 0.5484 - val_accuracy: 0.5718 - val_binary_accuracy: 0.8690 - val_binary_crossentropy: 0.3216 - val_f1_score: 0.0907 - val_loss: 0.3216 - val_precision: 0.7392 - val_recall: 0.5265
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5678 - binary_accuracy: 0.8685 - binary_crossentropy: 0.3203 - f1_score: 0.0907 - loss: 0.3203 - precision: 0.7420 - recall: 0.5185 - val_accuracy: 0.5822 - val_binary_accuracy: 0.8704 - val_binary_crossentropy: 0.3102 - val_f1_score: 0.0922 - val_loss: 0.3102 - val_precision: 0.7551 - val_recall: 0.5147
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5730 - binary_accuracy: 0.8719 - binary_crossentropy: 0.3100 - f1_score: 0.0932 - loss: 0.3100 - precision: 0.7658 - recall: 0.5086 - val_accuracy: 0.5796 - val_binary_accuracy: 0.8755 - val_binary_crossentropy: 0.3010 - val_f1_score: 0.0945 - val_loss: 0.3010 - val_precision: 0.7625 - val_recall: 0.5425
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5667 - binary_accuracy: 0.8766 - binary_crossentropy: 0.2997 - f1_score: 0.0942 - loss: 0.2997 - precision: 0.7747 - recall: 0.5384 - val_accuracy: 0.5788 - val_binary_accuracy: 0.8784 - val_binary_crossentropy: 0.2907 - val_f1_score: 0.0957 - val_loss: 0.2907 - val_precision: 0.7815 - val_recall: 0.5389
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5612 - binary_accuracy: 0.8808 - binary_crossentropy: 0.2886 - f1_score: 0.0950 - loss: 0.2886 - precision: 0.7847 - recall: 0.5501 - val_accuracy: 0.5944 - val_binary_accuracy: 0.8826 - val_binary_crossentropy: 0.2824 - val_f1_score: 0.0956 - val_loss: 0.2824 - val_precision: 0.7750 - val_recall: 0.5768
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5621 - binary_accuracy: 0.8846 - binary_crossentropy: 0.2813 - f1_score: 0.0961 - loss: 0.2813 - precision: 0.7806 - recall: 0.5811 - val_accuracy: 0.5988 - val_binary_accuracy: 0.8848 - val_binary_crossentropy: 0.2777 - val_f1_score: 0.0989 - val_loss: 0.2777 - val_precision: 0.7780 - val_recall: 0.5878
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5694 - binary_accuracy: 0.8875 - binary_crossentropy: 0.2740 - f1_score: 0.1000 - loss: 0.2740 - precision: 0.7911 - recall: 0.5867 - val_accuracy: 0.5570 - val_binary_accuracy: 0.8872 - val_binary_crossentropy: 0.2735 - val_f1_score: 0.1017 - val_loss: 0.2735 - val_precision: 0.7947 - val_recall: 0.5832
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5590 - binary_accuracy: 0.8887 - binary_crossentropy: 0.2732 - f1_score: 0.1020 - loss: 0.2732 - precision: 0.7972 - recall: 0.5891 - val_accuracy: 0.5509 - val_binary_accuracy: 0.8890 - val_binary_crossentropy: 0.2704 - val_f1_score: 0.1003 - val_loss: 0.2704 - val_precision: 0.8081 - val_recall: 0.5791
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5540 - binary_accuracy: 0.8899 - binary_crossentropy: 0.2692 - f1_score: 0.1027 - loss: 0.2692 - precision: 0.8063 - recall: 0.5879 - val_accuracy: 0.5692 - val_binary_accuracy: 0.8904 - val_binary_crossentropy: 0.2664 - val_f1_score: 0.1015 - val_loss: 0.2664 - val_precision: 0.8001 - val_recall: 0.5981
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5578 - binary_accuracy: 0.8914 - binary_crossentropy: 0.2661 - f1_score: 0.1027 - loss: 0.2661 - precision: 0.8050 - recall: 0.5975 - val_accuracy: 0.5605 - val_binary_accuracy: 0.8916 - val_binary_crossentropy: 0.2633 - val_f1_score: 0.1056 - val_loss: 0.2633 - val_precision: 0.8061 - val_recall: 0.5987
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5423 - binary_accuracy: 0.8939 - binary_crossentropy: 0.2628 - f1_score: 0.1046 - loss: 0.2628 - precision: 0.8124 - recall: 0.6067 - val_accuracy: 0.5483 - val_binary_accuracy: 0.8940 - val_binary_crossentropy: 0.2601 - val_f1_score: 0.1048 - val_loss: 0.2601 - val_precision: 0.8036 - val_recall: 0.6175
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5436 - binary_accuracy: 0.8957 - binary_crossentropy: 0.2580 - f1_score: 0.1063 - loss: 0.2580 - precision: 0.8145 - recall: 0.6150 - val_accuracy: 0.5666 - val_binary_accuracy: 0.8938 - val_binary_crossentropy: 0.2574 - val_f1_score: 0.1074 - val_loss: 0.2574 - val_precision: 0.7937 - val_recall: 0.6293
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5384 - binary_accuracy: 0.8968 - binary_crossentropy: 0.2548 - f1_score: 0.1071 - loss: 0.2548 - precision: 0.8134 - recall: 0.6243 - val_accuracy: 0.5466 - val_binary_accuracy: 0.8960 - val_binary_crossentropy: 0.2538 - val_f1_score: 0.1086 - val_loss: 0.2538 - val_precision: 0.8160 - val_recall: 0.6157
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5282 - binary_accuracy: 0.8974 - binary_crossentropy: 0.2514 - f1_score: 0.1109 - loss: 0.2514 - precision: 0.8184 - recall: 0.6218 - val_accuracy: 0.5292 - val_binary_accuracy: 0.8971 - val_binary_crossentropy: 0.2514 - val_f1_score: 0.1094 - val_loss: 0.2514 - val_precision: 0.8255 - val_recall: 0.6118
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5296 - binary_accuracy: 0.8987 - binary_crossentropy: 0.2490 - f1_score: 0.1138 - loss: 0.2490 - precision: 0.8206 - recall: 0.6252 - val_accuracy: 0.5231 - val_binary_accuracy: 0.8985 - val_binary_crossentropy: 0.2485 - val_f1_score: 0.1166 - val_loss: 0.2485 - val_precision: 0.8096 - val_recall: 0.6396
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5110 - binary_accuracy: 0.8996 - binary_crossentropy: 0.2468 - f1_score: 0.1131 - loss: 0.2468 - precision: 0.8200 - recall: 0.6361 - val_accuracy: 0.5614 - val_binary_accuracy: 0.8973 - val_binary_crossentropy: 0.2465 - val_f1_score: 0.1109 - val_loss: 0.2465 - val_precision: 0.8133 - val_recall: 0.6273
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5120 - binary_accuracy: 0.8991 - binary_crossentropy: 0.2448 - f1_score: 0.1152 - loss: 0.2448 - precision: 0.8176 - recall: 0.6370 - val_accuracy: 0.4761 - val_binary_accuracy: 0.8997 - val_binary_crossentropy: 0.2451 - val_f1_score: 0.1178 - val_loss: 0.2451 - val_precision: 0.8249 - val_recall: 0.6285
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5057 - binary_accuracy: 0.9020 - binary_crossentropy: 0.2400 - f1_score: 0.1177 - loss: 0.2400 - precision: 0.8192 - recall: 0.6494 - val_accuracy: 0.5187 - val_binary_accuracy: 0.9008 - val_binary_crossentropy: 0.2399 - val_f1_score: 0.1181 - val_loss: 0.2399 - val_precision: 0.8170 - val_recall: 0.6453
# Epoch 29/100
# ...
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4347 - binary_accuracy: 0.9271 - binary_crossentropy: 0.1836 - f1_score: 0.1567 - loss: 0.1836 - precision: 0.8577 - recall: 0.7578 - val_accuracy: 0.4491 - val_binary_accuracy: 0.9250 - val_binary_crossentropy: 0.1901 - val_f1_score: 0.1626 - val_loss: 0.1901 - val_precision: 0.8472 - val_recall: 0.7599
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4378 - binary_accuracy: 0.9272 - binary_crossentropy: 0.1827 - f1_score: 0.1635 - loss: 0.1827 - precision: 0.8571 - recall: 0.7609 - val_accuracy: 0.4299 - val_binary_accuracy: 0.9237 - val_binary_crossentropy: 0.1899 - val_f1_score: 0.1692 - val_loss: 0.1899 - val_precision: 0.8491 - val_recall: 0.7491
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4524 - binary_accuracy: 0.9272 - binary_crossentropy: 0.1830 - f1_score: 0.1633 - loss: 0.1830 - precision: 0.8609 - recall: 0.7547 - val_accuracy: 0.4430 - val_binary_accuracy: 0.9257 - val_binary_crossentropy: 0.1891 - val_f1_score: 0.1688 - val_loss: 0.1891 - val_precision: 0.8549 - val_recall: 0.7543
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4475 - binary_accuracy: 0.9284 - binary_crossentropy: 0.1806 - f1_score: 0.1653 - loss: 0.1806 - precision: 0.8637 - recall: 0.7606 - val_accuracy: 0.4352 - val_binary_accuracy: 0.9247 - val_binary_crossentropy: 0.1893 - val_f1_score: 0.1491 - val_loss: 0.1893 - val_precision: 0.8518 - val_recall: 0.7522
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4348 - binary_accuracy: 0.9278 - binary_crossentropy: 0.1821 - f1_score: 0.1573 - loss: 0.1821 - precision: 0.8634 - recall: 0.7570 - val_accuracy: 0.4308 - val_binary_accuracy: 0.9252 - val_binary_crossentropy: 0.1892 - val_f1_score: 0.1713 - val_loss: 0.1892 - val_precision: 0.8557 - val_recall: 0.7501
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4389 - binary_accuracy: 0.9291 - binary_crossentropy: 0.1793 - f1_score: 0.1678 - loss: 0.1793 - precision: 0.8653 - recall: 0.7606 - val_accuracy: 0.4378 - val_binary_accuracy: 0.9270 - val_binary_crossentropy: 0.1871 - val_f1_score: 0.1648 - val_loss: 0.1871 - val_precision: 0.8576 - val_recall: 0.7586
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4349 - binary_accuracy: 0.9291 - binary_crossentropy: 0.1793 - f1_score: 0.1665 - loss: 0.1793 - precision: 0.8624 - recall: 0.7678 - val_accuracy: 0.4282 - val_binary_accuracy: 0.9257 - val_binary_crossentropy: 0.1865 - val_f1_score: 0.1625 - val_loss: 0.1865 - val_precision: 0.8442 - val_recall: 0.7676
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4465 - binary_accuracy: 0.9294 - binary_crossentropy: 0.1772 - f1_score: 0.1676 - loss: 0.1772 - precision: 0.8607 - recall: 0.7705 - val_accuracy: 0.4247 - val_binary_accuracy: 0.9260 - val_binary_crossentropy: 0.1860 - val_f1_score: 0.1687 - val_loss: 0.1860 - val_precision: 0.8529 - val_recall: 0.7586
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4319 - binary_accuracy: 0.9295 - binary_crossentropy: 0.1777 - f1_score: 0.1639 - loss: 0.1777 - precision: 0.8615 - recall: 0.7694 - val_accuracy: 0.4421 - val_binary_accuracy: 0.9268 - val_binary_crossentropy: 0.1863 - val_f1_score: 0.1781 - val_loss: 0.1863 - val_precision: 0.8487 - val_recall: 0.7687
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4423 - binary_accuracy: 0.9306 - binary_crossentropy: 0.1756 - f1_score: 0.1734 - loss: 0.1756 - precision: 0.8624 - recall: 0.7746 - val_accuracy: 0.4282 - val_binary_accuracy: 0.9262 - val_binary_crossentropy: 0.1856 - val_f1_score: 0.1758 - val_loss: 0.1856 - val_precision: 0.8561 - val_recall: 0.7555
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4406 - binary_accuracy: 0.9300 - binary_crossentropy: 0.1763 - f1_score: 0.1760 - loss: 0.1763 - precision: 0.8647 - recall: 0.7687 - val_accuracy: 0.4256 - val_binary_accuracy: 0.9254 - val_binary_crossentropy: 0.1842 - val_f1_score: 0.1678 - val_loss: 0.1842 - val_precision: 0.8515 - val_recall: 0.7563
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4301 - binary_accuracy: 0.9319 - binary_crossentropy: 0.1726 - f1_score: 0.1721 - loss: 0.1726 - precision: 0.8708 - recall: 0.7734 - val_accuracy: 0.4587 - val_binary_accuracy: 0.9260 - val_binary_crossentropy: 0.1864 - val_f1_score: 0.1912 - val_loss: 0.1864 - val_precision: 0.8494 - val_recall: 0.7630
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4430 - binary_accuracy: 0.9294 - binary_crossentropy: 0.1779 - f1_score: 0.1755 - loss: 0.1779 - precision: 0.8630 - recall: 0.7668 - val_accuracy: 0.4273 - val_binary_accuracy: 0.9278 - val_binary_crossentropy: 0.1837 - val_f1_score: 0.1699 - val_loss: 0.1837 - val_precision: 0.8547 - val_recall: 0.7669
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4358 - binary_accuracy: 0.9313 - binary_crossentropy: 0.1727 - f1_score: 0.1759 - loss: 0.1727 - precision: 0.8677 - recall: 0.7715 - val_accuracy: 0.4195 - val_binary_accuracy: 0.9274 - val_binary_crossentropy: 0.1842 - val_f1_score: 0.1809 - val_loss: 0.1842 - val_precision: 0.8504 - val_recall: 0.7700
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4259 - binary_accuracy: 0.9325 - binary_crossentropy: 0.1707 - f1_score: 0.1756 - loss: 0.1707 - precision: 0.8711 - recall: 0.7749 - val_accuracy: 0.4247 - val_binary_accuracy: 0.9284 - val_binary_crossentropy: 0.1829 - val_f1_score: 0.1813 - val_loss: 0.1829 - val_precision: 0.8542 - val_recall: 0.7713
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4349 - binary_accuracy: 0.9305 - binary_crossentropy: 0.1742 - f1_score: 0.1784 - loss: 0.1742 - precision: 0.8623 - recall: 0.7739 - val_accuracy: 0.4395 - val_binary_accuracy: 0.9271 - val_binary_crossentropy: 0.1828 - val_f1_score: 0.1837 - val_loss: 0.1828 - val_precision: 0.8466 - val_recall: 0.7736
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4425 - binary_accuracy: 0.9311 - binary_crossentropy: 0.1732 - f1_score: 0.1775 - loss: 0.1732 - precision: 0.8656 - recall: 0.7747 - val_accuracy: 0.4230 - val_binary_accuracy: 0.9284 - val_binary_crossentropy: 0.1820 - val_f1_score: 0.1835 - val_loss: 0.1820 - val_precision: 0.8602 - val_recall: 0.7640
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4374 - binary_accuracy: 0.9333 - binary_crossentropy: 0.1708 - f1_score: 0.1759 - loss: 0.1708 - precision: 0.8732 - recall: 0.7772 - val_accuracy: 0.4125 - val_binary_accuracy: 0.9279 - val_binary_crossentropy: 0.1812 - val_f1_score: 0.1858 - val_loss: 0.1812 - val_precision: 0.8598 - val_recall: 0.7615
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4358 - binary_accuracy: 0.9325 - binary_crossentropy: 0.1712 - f1_score: 0.1801 - loss: 0.1712 - precision: 0.8725 - recall: 0.7744 - val_accuracy: 0.4308 - val_binary_accuracy: 0.9288 - val_binary_crossentropy: 0.1811 - val_f1_score: 0.1909 - val_loss: 0.1811 - val_precision: 0.8572 - val_recall: 0.7702
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4342 - binary_accuracy: 0.9321 - binary_crossentropy: 0.1714 - f1_score: 0.1847 - loss: 0.1714 - precision: 0.8665 - recall: 0.7777 - val_accuracy: 0.3856 - val_binary_accuracy: 0.9286 - val_binary_crossentropy: 0.1808 - val_f1_score: 0.1858 - val_loss: 0.1808 - val_precision: 0.8544 - val_recall: 0.7723
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4253 - binary_accuracy: 0.9329 - binary_crossentropy: 0.1698 - f1_score: 0.1789 - loss: 0.1698 - precision: 0.8690 - recall: 0.7797 - val_accuracy: 0.4421 - val_binary_accuracy: 0.9291 - val_binary_crossentropy: 0.1806 - val_f1_score: 0.1805 - val_loss: 0.1806 - val_precision: 0.8536 - val_recall: 0.7764
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4396 - binary_accuracy: 0.9334 - binary_crossentropy: 0.1682 - f1_score: 0.1816 - loss: 0.1682 - precision: 0.8699 - recall: 0.7821 - val_accuracy: 0.4413 - val_binary_accuracy: 0.9297 - val_binary_crossentropy: 0.1792 - val_f1_score: 0.1765 - val_loss: 0.1792 - val_precision: 0.8565 - val_recall: 0.7761
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4344 - binary_accuracy: 0.9337 - binary_crossentropy: 0.1667 - f1_score: 0.1792 - loss: 0.1667 - precision: 0.8693 - recall: 0.7860 - val_accuracy: 0.4352 - val_binary_accuracy: 0.9299 - val_binary_crossentropy: 0.1790 - val_f1_score: 0.1918 - val_loss: 0.1790 - val_precision: 0.8546 - val_recall: 0.7798
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4298 - binary_accuracy: 0.9345 - binary_crossentropy: 0.1666 - f1_score: 0.1876 - loss: 0.1666 - precision: 0.8747 - recall: 0.7818 - val_accuracy: 0.4386 - val_binary_accuracy: 0.9302 - val_binary_crossentropy: 0.1782 - val_f1_score: 0.1845 - val_loss: 0.1782 - val_precision: 0.8589 - val_recall: 0.7764
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4434 - binary_accuracy: 0.9343 - binary_crossentropy: 0.1659 - f1_score: 0.1905 - loss: 0.1659 - precision: 0.8736 - recall: 0.7840 - val_accuracy: 0.3829 - val_binary_accuracy: 0.9286 - val_binary_crossentropy: 0.1803 - val_f1_score: 0.1822 - val_loss: 0.1803 - val_precision: 0.8534 - val_recall: 0.7736
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4161 - binary_accuracy: 0.9345 - binary_crossentropy: 0.1662 - f1_score: 0.1887 - loss: 0.1662 - precision: 0.8737 - recall: 0.7859 - val_accuracy: 0.4386 - val_binary_accuracy: 0.9293 - val_binary_crossentropy: 0.1782 - val_f1_score: 0.2075 - val_loss: 0.1782 - val_precision: 0.8452 - val_recall: 0.7888
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4314 - binary_accuracy: 0.9346 - binary_crossentropy: 0.1665 - f1_score: 0.1895 - loss: 0.1665 - precision: 0.8697 - recall: 0.7918 - val_accuracy: 0.4421 - val_binary_accuracy: 0.9295 - val_binary_crossentropy: 0.1776 - val_f1_score: 0.1969 - val_loss: 0.1776 - val_precision: 0.8604 - val_recall: 0.7702
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4403 - binary_accuracy: 0.9345 - binary_crossentropy: 0.1655 - f1_score: 0.1904 - loss: 0.1655 - precision: 0.8756 - recall: 0.7820 - val_accuracy: 0.4308 - val_binary_accuracy: 0.9300 - val_binary_crossentropy: 0.1766 - val_f1_score: 0.1857 - val_loss: 0.1766 - val_precision: 0.8602 - val_recall: 0.7736
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4271 - binary_accuracy: 0.9359 - binary_crossentropy: 0.1618 - f1_score: 0.1860 - loss: 0.1618 - precision: 0.8776 - recall: 0.7878 - val_accuracy: 0.4265 - val_binary_accuracy: 0.9314 - val_binary_crossentropy: 0.1754 - val_f1_score: 0.1913 - val_loss: 0.1754 - val_precision: 0.8555 - val_recall: 0.7883
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4253 - binary_accuracy: 0.9360 - binary_crossentropy: 0.1632 - f1_score: 0.1899 - loss: 0.1632 - precision: 0.8746 - recall: 0.7915 - val_accuracy: 0.4056 - val_binary_accuracy: 0.9321 - val_binary_crossentropy: 0.1759 - val_f1_score: 0.1989 - val_loss: 0.1759 - val_precision: 0.8606 - val_recall: 0.7857
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4306 - binary_accuracy: 0.9369 - binary_crossentropy: 0.1627 - f1_score: 0.2012 - loss: 0.1627 - precision: 0.8809 - recall: 0.7887 - val_accuracy: 0.4282 - val_binary_accuracy: 0.9312 - val_binary_crossentropy: 0.1752 - val_f1_score: 0.1960 - val_loss: 0.1752 - val_precision: 0.8563 - val_recall: 0.7859
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4260 - binary_accuracy: 0.9360 - binary_crossentropy: 0.1645 - f1_score: 0.1932 - loss: 0.1645 - precision: 0.8750 - recall: 0.7926 - val_accuracy: 0.4360 - val_binary_accuracy: 0.9300 - val_binary_crossentropy: 0.1767 - val_f1_score: 0.1877 - val_loss: 0.1767 - val_precision: 0.8608 - val_recall: 0.7725
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4262 - binary_accuracy: 0.9361 - binary_crossentropy: 0.1622 - f1_score: 0.1882 - loss: 0.1622 - precision: 0.8800 - recall: 0.7886 - val_accuracy: 0.4334 - val_binary_accuracy: 0.9306 - val_binary_crossentropy: 0.1771 - val_f1_score: 0.2050 - val_loss: 0.1771 - val_precision: 0.8772 - val_recall: 0.7566
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4353 - binary_accuracy: 0.9357 - binary_crossentropy: 0.1634 - f1_score: 0.1951 - loss: 0.1634 - precision: 0.8827 - recall: 0.7795 - val_accuracy: 0.4404 - val_binary_accuracy: 0.9314 - val_binary_crossentropy: 0.1757 - val_f1_score: 0.2025 - val_loss: 0.1757 - val_precision: 0.8568 - val_recall: 0.7862
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4425 - binary_accuracy: 0.9368 - binary_crossentropy: 0.1596 - f1_score: 0.1893 - loss: 0.1596 - precision: 0.8741 - recall: 0.7958 - val_accuracy: 0.4291 - val_binary_accuracy: 0.9314 - val_binary_crossentropy: 0.1756 - val_f1_score: 0.1821 - val_loss: 0.1756 - val_precision: 0.8521 - val_recall: 0.7924
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.4355 - binary_accuracy: 0.9370 - binary_crossentropy: 0.1617 - f1_score: 0.1892 - loss: 0.1617 - precision: 0.8771 - recall: 0.7948 - val_accuracy: 0.4413 - val_binary_accuracy: 0.9324 - val_binary_crossentropy: 0.1734 - val_f1_score: 0.1920 - val_loss: 0.1734 - val_precision: 0.8635 - val_recall: 0.7836
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4324 - binary_accuracy: 0.9382 - binary_crossentropy: 0.1576 - f1_score: 0.1952 - loss: 0.1576 - precision: 0.8832 - recall: 0.7928 - val_accuracy: 0.4291 - val_binary_accuracy: 0.9325 - val_binary_crossentropy: 0.1734 - val_f1_score: 0.2075 - val_loss: 0.1734 - val_precision: 0.8661 - val_recall: 0.7813
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4412 - binary_accuracy: 0.9377 - binary_crossentropy: 0.1603 - f1_score: 0.1970 - loss: 0.1603 - precision: 0.8804 - recall: 0.7935 - val_accuracy: 0.4447 - val_binary_accuracy: 0.9299 - val_binary_crossentropy: 0.1751 - val_f1_score: 0.2051 - val_loss: 0.1751 - val_precision: 0.8603 - val_recall: 0.7725
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4396 - binary_accuracy: 0.9371 - binary_crossentropy: 0.1607 - f1_score: 0.1935 - loss: 0.1607 - precision: 0.8777 - recall: 0.7938 - val_accuracy: 0.4369 - val_binary_accuracy: 0.9320 - val_binary_crossentropy: 0.1747 - val_f1_score: 0.2078 - val_loss: 0.1747 - val_precision: 0.8561 - val_recall: 0.7908
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4367 - binary_accuracy: 0.9384 - binary_crossentropy: 0.1591 - f1_score: 0.2014 - loss: 0.1591 - precision: 0.8795 - recall: 0.7996 - val_accuracy: 0.4030 - val_binary_accuracy: 0.9319 - val_binary_crossentropy: 0.1733 - val_f1_score: 0.2052 - val_loss: 0.1733 - val_precision: 0.8773 - val_recall: 0.7643
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4274 - binary_accuracy: 0.9376 - binary_crossentropy: 0.1591 - f1_score: 0.2002 - loss: 0.1591 - precision: 0.8857 - recall: 0.7886 - val_accuracy: 0.4247 - val_binary_accuracy: 0.9329 - val_binary_crossentropy: 0.1722 - val_f1_score: 0.1878 - val_loss: 0.1722 - val_precision: 0.8627 - val_recall: 0.7880
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4322 - binary_accuracy: 0.9385 - binary_crossentropy: 0.1580 - f1_score: 0.1869 - loss: 0.1580 - precision: 0.8820 - recall: 0.7991 - val_accuracy: 0.4430 - val_binary_accuracy: 0.9296 - val_binary_crossentropy: 0.1760 - val_f1_score: 0.2121 - val_loss: 0.1760 - val_precision: 0.8572 - val_recall: 0.7749
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# # Comparações

# %%
def compute_general_metrics(y_real,y_pred,i=None):

  if i is None:
    names = 'general'
    accur = metrics.accuracy_score(y_real, y_pred)
    f1 = metrics.f1_score(y_real, y_pred, average='weighted')
    prec = metrics.precision_score(y_real, y_pred, average='weighted')
    rec = metrics.recall_score(y_real, y_pred, average='weighted')
    jacc = float(metrics.jaccard_score(y_real, y_pred, average='weighted'))
    hamm = metrics.hamming_loss(y_real, y_pred)
    log_loss = metrics.log_loss(y_real, y_pred)

  elif i is not None:
    names = column_names[i]
    accur = metrics.accuracy_score(y_real.iloc[:, i], y_pred[:, i])
    f1 = metrics.f1_score(y_real.iloc[:, i], y_pred[:, i],zero_division=0)
    prec = metrics.precision_score(y_real.iloc[:, i], y_pred[:, i],zero_division=0)
    rec = metrics.recall_score(y_real.iloc[:, i], y_pred[:, i],zero_division=0)
    jacc = float(metrics.jaccard_score(y_real.iloc[:, i], y_pred[:, i]))
    hamm = metrics.hamming_loss(y_real.iloc[:, i], y_pred[:, i])
    log_loss = metrics.log_loss(y_real.iloc[:, i], y_pred[:, i])

  return [names, accur, f1, prec, rec, jacc, hamm, log_loss]

# %%
def compute_all_comparisons(func_model, data_model):
    model_prefix = f'conv1d_{func_model}_{data_model}'
    model_suffix = f'_2025_07_22_call_True'
    model_name = model_prefix + model_suffix
    model_path = os.path.join(MODELS_DIR, f'{model_name}.keras')
    model = keras.models.load_model(model_path)

    dataset_final = get_dataset(df_spectra_all, dataset_y, func_model)

    X = dataset_final[[col for col in dataset_final.columns if 'bin' in col]]
    X = X.apply(pd.to_numeric, errors='coerce').fillna(0)

    Y = dataset_final[column_names].apply(lambda x: x.astype(int))
    X_train, X_test_temp, Y_train, Y_test_temp = train_test_split(X, Y, test_size=0.25, random_state=42)

    X_validation, X_test, Y_validation, Y_test = train_test_split(X_test_temp, Y_test_temp, test_size=0.45, random_state=42)

    if data_model == 'encoder':
        X_train = pd.DataFrame(encoder_model_load.predict(X_train))
        X_test = pd.DataFrame(encoder_model_load.predict(X_test))
        X_test_temp = pd.DataFrame(encoder_model_load.predict(X_test_temp))

    train_predict = (model.predict(X_train) > 0.5).astype(int)
    test_predict = (model.predict(X_test_temp) > 0.5).astype(int)

    metrics_list = ['accuracy','f1_score','precision', 'recall', 'jaccard','hamming', 'log_loss']

    train_metrics = [compute_general_metrics(Y_train,train_predict)] + [compute_general_metrics(Y_train,train_predict,x) for x in range(len(column_names))]
    test_metrics = [compute_general_metrics(Y_test_temp,test_predict)] + [compute_general_metrics(Y_test_temp,test_predict,x) for x in range(len(column_names))]

    full_metrics_df = pd.DataFrame(train_metrics)
    full_metrics_df.columns = ['metric'] + metrics_list
    full_metrics_df['data'] = 'train'

    test_metrics_df = pd.DataFrame(test_metrics)
    test_metrics_df.columns = ['metric'] + metrics_list
    test_metrics_df['data'] = 'test'

    merged_df = pd.concat([full_metrics_df, test_metrics_df], ignore_index=True)
    merged_df['model'] = model_prefix

    return merged_df

results_list = []
for func_model in ['min','max','mean']:
    for data_model in ['encoder','normal']:
        results_list.append(compute_all_comparisons(func_model, data_model))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2894283833.py in <cell line: 0>()
#      46 for func_model in ['min','max','mean']:
#      47   for data_model in ['encoder','normal']:
# ---> 48     results_list.append(compute_all_comparisons(func_model,data_model))
#
# /tmp/ipython-input-2894283833.py in compute_all_comparisons(func_model, data_model)
#       5   model_suffix = f'_2025_07_22_call_True'
#       6   model_name = model_prefix + model_suffix
# ----> 7   model = keras.models.load_model(f'/content/{model_name}.keras')
#       8
#       9   dataset_final = get_dataset(df_spectra_all, dataset_y, func_model)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     198         )
#     199     elif str(filepath).endswith(".keras"):
# --> 200         raise ValueError(
#     201             f"File not found: filepath={filepath}. "
#     202             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=/content/conv1d_min_encoder_2025_07_22_call_True.keras. Please ensure the file is an accessible `.keras` zip file.

# %%
all_metrics = pd.concat(results_list).groupby(['model','data','metric']).mean()
all_metrics
