# %% [markdown]
# # Import

# %%
# Definição dos caminhos principais (ajuste conforme necessário)
import os
ROOT_DIR = os.getcwd()
DATASET_DIR = os.path.join(ROOT_DIR, 'datasets')
HISTORY_DIR = os.path.join(ROOT_DIR, 'history')
MODELS_DIR = os.path.join(ROOT_DIR, 'models')
RESULTS_DIR = os.path.join(ROOT_DIR, 'results')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import re
from time import sleep
from datetime import datetime
import pandas as pd
import requests
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from packaging import version
from IPython import display
import math
from sklearn.preprocessing import StandardScaler
import pickle
from sklearn.model_selection import train_test_split
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras import layers, losses, Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, GRU, Conv2D, MaxPooling2D, AvgPool2D, Flatten
sns.set(style="whitegrid")
# %matplotlib inline
# Dicionário de grupos funcionais e SMARTS
func_grp_smarts = {
    'alkane':'[CX4;H0,H1,H2,H4]',
    'methyl':'[CH3]',
    'alkene':'[CX3]=[CX3]',
    'alkyne':'[CX2]#C',
    'alcohols':'[#6][OX2H]',
    'amines':'[NX3;H2,H1;!$(NC=O)]',
    'nitriles':'[NX1]#[CX2]',
    'aromatics':'[$([cX3](:*):*),$([cX2+](:*):*)]',
    'alkyl halides':'[#6][F,Cl,Br,I]',
    'esters':'[#6][CX3](=O)[OX2H0][#6]',
    'ketones':'[#6][CX3](=O)[#6]',
    'aldehydes':'[CX3H1](=O)[#6]',
    'carboxylic acids':'[CX3](=O)[OX2H1]',
    'ether': '[OD2]([#6])[#6]',
    'acyl halides':'[CX3](=[OX1])[F,Cl,Br,I]',
    'amides':'[NX3][CX3](=[OX1])[#6]',
    'nitro':'[$([NX3](=O)=O),$([NX3+](=O)[O-])][!#8]'
}
column_names = list(func_grp_smarts.keys())

# %%
df_enrich = pd.read_csv(os.path.join(DATASET_DIR, 'df_enrich.csv'))
dataset_y = df_enrich.copy()
dataset_y.index = dataset_y['CAS']
len(dataset_y.CAS.unique())
# Out:
# 8241

# %%
# df_spectra_all.to_parquet(os.path.join(DATASET_DIR, 'df_spectra_all_mixture_interpolate.parquet'), index=False)

# %%
# df_spectra_all = pd.read_csv(os.path.join(DATASET_DIR, 'df_spectra_all_mixture_interpolate.csv'))
df_spectra_all = pd.read_parquet(os.path.join(DATASET_DIR, 'df_spectra_all_mixture_interpolate.parquet'))
mean_cols = [x for x in df_spectra_all.columns if 'mean' in x]
min_cols = [x for x in df_spectra_all.columns if 'min' in x]
max_cols = [x for x in df_spectra_all.columns if 'max' in x]
all_cols = mean_cols + min_cols + max_cols
df_spectra_all.shape
# Out:
# (1030, 24636)

# %% [markdown]
# # Functions

# %%
def turn_spectra_into_image(data, ratio = None):
  matrix_result = np.zeros((100,1030))

  for i,val in enumerate((data.values//0.01).astype(int)):

    matrix_result[val, i] = 1

  if ratio is not None:
    matrix_result = matrix_result[:, 0:1030:ratio]

  return matrix_result

def get_dataset(df_spectra_all, dataset_y, agg_func):

  if agg_func == 'mean':
    dataset_x = df_spectra_all[mean_cols].copy()
  elif agg_func == 'min':
    dataset_x = df_spectra_all[min_cols].copy()

  elif agg_func == 'max':
    dataset_x = df_spectra_all[max_cols].copy()

  # dataset_x = df_spectra_all.copy()
  dataset_x = dataset_x.T
  dataset_x.columns = ['bin_' + str(x) for x in dataset_x.columns]
  dataset_x.reset_index(inplace=True)
  dataset_x.index = dataset_x['index'].apply(lambda x: x.split('_')[0])

  dataset_y = dataset_y[dataset_y['yunits'] == 'ABSORBANCE']

  dataset_final = pd.merge(dataset_y, dataset_x, left_index = True, right_index = True, how='inner')

  return dataset_final

def find_best_epoch(history):
    """
    Finds the epoch with the lowest validation loss.

    Args:
        history: Training history object from Keras model.fit().

    Returns:
        A tuple containing the best epoch number and its corresponding validation loss.
        Returns None if history object is invalid or empty.
    """
    if not history or 'val_loss' not in history.history:
        return None

    val_losses = history.history['val_loss']
    best_epoch = np.argmin(val_losses)  # Index of the minimum validation loss
    best_val_loss = val_losses[best_epoch]

    return best_epoch, best_val_loss

# %%
def compute_model_analysis(agg_func, data_prep, current_date, batch_size=380, epochs=100, callbacks=False, save_history=True, save_figure=False):
    dataset_final = get_dataset(df_spectra_all, dataset_y, agg_func)
    X = dataset_final[[col for col in dataset_final.columns if 'bin' in col]].apply(pd.to_numeric, errors='coerce').fillna(0)
    Y = dataset_final[column_names].apply(lambda x: x.astype(int))
    X_train, X_test_temp, Y_train, Y_test_temp = train_test_split(X, Y, test_size=0.20, random_state=42, stratify=Y[column_names].sum(axis=1))
    X_validation, X_test, Y_validation, Y_test = train_test_split(X_test_temp, Y_test_temp, test_size=0.30, random_state=42, stratify=Y_test_temp[column_names].sum(axis=1))
    ratio = 10
    X_train_image = np.array([turn_spectra_into_image(X_train.loc[i], ratio=ratio) for i in X_train.index])
    X_validation_image = np.array([turn_spectra_into_image(X_validation.loc[i], ratio=ratio) for i in X_validation.index])
    X_test_image = np.array([turn_spectra_into_image(X_test.loc[i], ratio=ratio) for i in X_test.index])
    X_train_image = X_train_image[..., np.newaxis]
    X_validation_image = X_validation_image[..., np.newaxis]
    X_test_image = X_test_image[..., np.newaxis]
    model = Sequential([
        layers.Input(shape=(X_train_image.shape[1], X_train_image.shape[2], 1)),
        layers.Conv2D(64, (4, 4), activation='relu'),
        layers.MaxPooling2D((4, 4)),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(Y_train.shape[1], activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'binary_accuracy', 'precision', 'recall'])
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='min', start_from_epoch=25, restore_best_weights=True)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-8, verbose=0, mode='min')
    callbacks_list = [early_stopping, reduce_lr] if callbacks else []
    history = model.fit(X_train_image, Y_train, validation_data=(X_validation_image, Y_validation), callbacks=callbacks_list, epochs=epochs, verbose=1, shuffle=True, batch_size=batch_size)
    y_pred = (model.predict(X_validation_image) > 0.5).astype(int)
    compose_name = f'conv2d_{agg_func}_{data_prep}_{current_date}_call_{callbacks}'
    model.save(os.path.join(MODELS_DIR, f'{compose_name}.keras'))
    if save_history:
        with open(os.path.join(HISTORY_DIR, f'{compose_name}_history.pkl'), 'wb') as f:
            pickle.dump(history.history, f)
    best_epoch, best_val_loss = find_best_epoch(history)
    if save_figure:
        plt.figure(figsize=(16, 10))
        plt.suptitle(f'Métricas Treinamento - Época Escolhida {best_epoch} - {best_val_loss:.3f} Validação Loss Function')
        plt.subplot(3, 1, 1)
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.axvline(x=best_epoch, color='red', linestyle='--')
        plt.ylabel('Acurácia')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: '{:.3f}'.format(x)))
        plt.subplot(3, 1, 2)
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.axvline(x=best_epoch, color='red', linestyle='--')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: '{:.3f}'.format(x)))
        plt.subplot(3, 1, 3)
        plt.plot(history.history['binary_accuracy'])
        plt.plot(history.history['val_binary_accuracy'])
        plt.axvline(x=best_epoch, color='red', linestyle='--')
        plt.ylabel('Acurácia Binarizada')
        plt.xlabel('Epoch')
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: '{:.3f}'.format(x)))
        plt.savefig(os.path.join(RESULTS_DIR, f'{compose_name}.png'))
        plt.show()
    return history

# %%
callbacks = False
epochs = 100
batch_size = 600
current_date = datetime.now().strftime('%Y_%m_%d')
compute_model_analysis('min', 'normal', current_date, batch_size=batch_size, epochs=epochs, callbacks=callbacks)
compute_model_analysis('max', 'normal', current_date, batch_size=batch_size, epochs=epochs, callbacks=callbacks)
compute_model_analysis('mean', 'normal', current_date, batch_size=batch_size, epochs=epochs, callbacks=callbacks)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.0922 - binary_accuracy: 0.7115 - binary_crossentropy: 0.6290 - f1_score: 0.0575 - loss: 0.6290 - precision: 0.3227 - recall: 0.3324 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.4148 - val_f1_score: 0.0485 - val_loss: 0.4148 - val_precision: 0.6381 - val_recall: 0.5683
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 53s 5s/step - accuracy: 0.5362 - binary_accuracy: 0.8535 - binary_crossentropy: 0.3970 - f1_score: 0.0674 - loss: 0.3970 - precision: 0.6632 - recall: 0.5417 - val_accuracy: 0.4804 - val_binary_accuracy: 0.8534 - val_binary_crossentropy: 0.3589 - val_f1_score: 0.0876 - val_loss: 0.3589 - val_precision: 0.6591 - val_recall: 0.5438
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4080 - binary_accuracy: 0.8523 - binary_crossentropy: 0.3567 - f1_score: 0.0868 - loss: 0.3567 - precision: 0.6513 - recall: 0.5487 - val_accuracy: 0.6031 - val_binary_accuracy: 0.8627 - val_binary_crossentropy: 0.3372 - val_f1_score: 0.0846 - val_loss: 0.3372 - val_precision: 0.6980 - val_recall: 0.5453
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.5836 - binary_accuracy: 0.8607 - binary_crossentropy: 0.3382 - f1_score: 0.0841 - loss: 0.3382 - precision: 0.6943 - recall: 0.5333 - val_accuracy: 0.5004 - val_binary_accuracy: 0.8712 - val_binary_crossentropy: 0.3244 - val_f1_score: 0.0895 - val_loss: 0.3244 - val_precision: 0.7689 - val_recall: 0.5031
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 91s 6s/step - accuracy: 0.4874 - binary_accuracy: 0.8709 - binary_crossentropy: 0.3259 - f1_score: 0.0890 - loss: 0.3259 - precision: 0.7664 - recall: 0.5034 - val_accuracy: 0.4795 - val_binary_accuracy: 0.8754 - val_binary_crossentropy: 0.3145 - val_f1_score: 0.0957 - val_loss: 0.3145 - val_precision: 0.7873 - val_recall: 0.5111
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 74s 5s/step - accuracy: 0.4618 - binary_accuracy: 0.8755 - binary_crossentropy: 0.3148 - f1_score: 0.0949 - loss: 0.3148 - precision: 0.7848 - recall: 0.5106 - val_accuracy: 0.5152 - val_binary_accuracy: 0.8789 - val_binary_crossentropy: 0.3053 - val_f1_score: 0.0910 - val_loss: 0.3053 - val_precision: 0.7954 - val_recall: 0.5258
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 85s 5s/step - accuracy: 0.4556 - binary_accuracy: 0.8792 - binary_crossentropy: 0.3066 - f1_score: 0.0975 - loss: 0.3066 - precision: 0.7849 - recall: 0.5335 - val_accuracy: 0.5065 - val_binary_accuracy: 0.8837 - val_binary_crossentropy: 0.2967 - val_f1_score: 0.0924 - val_loss: 0.2967 - val_precision: 0.7695 - val_recall: 0.5925
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.4722 - binary_accuracy: 0.8838 - binary_crossentropy: 0.2951 - f1_score: 0.0999 - loss: 0.2951 - precision: 0.7839 - recall: 0.5761 - val_accuracy: 0.5100 - val_binary_accuracy: 0.8856 - val_binary_crossentropy: 0.2863 - val_f1_score: 0.1016 - val_loss: 0.2863 - val_precision: 0.7680 - val_recall: 0.6079
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4791 - binary_accuracy: 0.8865 - binary_crossentropy: 0.2843 - f1_score: 0.1078 - loss: 0.2843 - precision: 0.7817 - recall: 0.5920 - val_accuracy: 0.4935 - val_binary_accuracy: 0.8881 - val_binary_crossentropy: 0.2793 - val_f1_score: 0.1107 - val_loss: 0.2793 - val_precision: 0.7618 - val_recall: 0.6360
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4701 - binary_accuracy: 0.8900 - binary_crossentropy: 0.2754 - f1_score: 0.1134 - loss: 0.2754 - precision: 0.7845 - recall: 0.6144 - val_accuracy: 0.5648 - val_binary_accuracy: 0.8903 - val_binary_crossentropy: 0.2700 - val_f1_score: 0.1122 - val_loss: 0.2700 - val_precision: 0.7720 - val_recall: 0.6360
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 57s 5s/step - accuracy: 0.4871 - binary_accuracy: 0.8913 - binary_crossentropy: 0.2670 - f1_score: 0.1192 - loss: 0.2670 - precision: 0.7831 - recall: 0.6281 - val_accuracy: 0.4865 - val_binary_accuracy: 0.8949 - val_binary_crossentropy: 0.2599 - val_f1_score: 0.1225 - val_loss: 0.2599 - val_precision: 0.8014 - val_recall: 0.6267
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 5s/step - accuracy: 0.4926 - binary_accuracy: 0.8969 - binary_crossentropy: 0.2563 - f1_score: 0.1223 - loss: 0.2563 - precision: 0.8072 - recall: 0.6295 - val_accuracy: 0.5231 - val_binary_accuracy: 0.8985 - val_binary_crossentropy: 0.2520 - val_f1_score: 0.1236 - val_loss: 0.2520 - val_precision: 0.8100 - val_recall: 0.6391
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 88s 6s/step - accuracy: 0.4960 - binary_accuracy: 0.9010 - binary_crossentropy: 0.2467 - f1_score: 0.1241 - loss: 0.2467 - precision: 0.8171 - recall: 0.6460 - val_accuracy: 0.5805 - val_binary_accuracy: 0.9012 - val_binary_crossentropy: 0.2448 - val_f1_score: 0.1266 - val_loss: 0.2448 - val_precision: 0.8035 - val_recall: 0.6659
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 74s 5s/step - accuracy: 0.5102 - binary_accuracy: 0.9046 - binary_crossentropy: 0.2394 - f1_score: 0.1277 - loss: 0.2394 - precision: 0.8183 - recall: 0.6676 - val_accuracy: 0.5196 - val_binary_accuracy: 0.9051 - val_binary_crossentropy: 0.2361 - val_f1_score: 0.1335 - val_loss: 0.2361 - val_precision: 0.8199 - val_recall: 0.6698
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.5032 - binary_accuracy: 0.9080 - binary_crossentropy: 0.2304 - f1_score: 0.1348 - loss: 0.2304 - precision: 0.8278 - recall: 0.6782 - val_accuracy: 0.5257 - val_binary_accuracy: 0.9085 - val_binary_crossentropy: 0.2280 - val_f1_score: 0.1385 - val_loss: 0.2280 - val_precision: 0.8098 - val_recall: 0.7053
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4946 - binary_accuracy: 0.9123 - binary_crossentropy: 0.2227 - f1_score: 0.1448 - loss: 0.2227 - precision: 0.8367 - recall: 0.6932 - val_accuracy: 0.5500 - val_binary_accuracy: 0.9097 - val_binary_crossentropy: 0.2217 - val_f1_score: 0.1410 - val_loss: 0.2217 - val_precision: 0.8141 - val_recall: 0.7071
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 86s 5s/step - accuracy: 0.4985 - binary_accuracy: 0.9141 - binary_crossentropy: 0.2160 - f1_score: 0.1478 - loss: 0.2160 - precision: 0.8335 - recall: 0.7084 - val_accuracy: 0.4735 - val_binary_accuracy: 0.9111 - val_binary_crossentropy: 0.2187 - val_f1_score: 0.1337 - val_loss: 0.2187 - val_precision: 0.8199 - val_recall: 0.7084
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4749 - binary_accuracy: 0.9155 - binary_crossentropy: 0.2103 - f1_score: 0.1502 - loss: 0.2103 - precision: 0.8368 - recall: 0.7127 - val_accuracy: 0.4900 - val_binary_accuracy: 0.9144 - val_binary_crossentropy: 0.2110 - val_f1_score: 0.1447 - val_loss: 0.2110 - val_precision: 0.8295 - val_recall: 0.7166
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 78s 5s/step - accuracy: 0.4734 - binary_accuracy: 0.9195 - binary_crossentropy: 0.2022 - f1_score: 0.1514 - loss: 0.2022 - precision: 0.8464 - recall: 0.7262 - val_accuracy: 0.5640 - val_binary_accuracy: 0.9155 - val_binary_crossentropy: 0.2108 - val_f1_score: 0.1479 - val_loss: 0.2108 - val_precision: 0.8242 - val_recall: 0.7308
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4923 - binary_accuracy: 0.9196 - binary_crossentropy: 0.2006 - f1_score: 0.1658 - loss: 0.2006 - precision: 0.8438 - recall: 0.7334 - val_accuracy: 0.4778 - val_binary_accuracy: 0.9167 - val_binary_crossentropy: 0.2045 - val_f1_score: 0.1508 - val_loss: 0.2045 - val_precision: 0.8517 - val_recall: 0.7030
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.4766 - binary_accuracy: 0.9221 - binary_crossentropy: 0.1959 - f1_score: 0.1634 - loss: 0.1959 - precision: 0.8508 - recall: 0.7366 - val_accuracy: 0.5091 - val_binary_accuracy: 0.9202 - val_binary_crossentropy: 0.1987 - val_f1_score: 0.1604 - val_loss: 0.1987 - val_precision: 0.8495 - val_recall: 0.7272
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 71s 5s/step - accuracy: 0.4771 - binary_accuracy: 0.9235 - binary_crossentropy: 0.1908 - f1_score: 0.1706 - loss: 0.1908 - precision: 0.8527 - recall: 0.7427 - val_accuracy: 0.4839 - val_binary_accuracy: 0.9215 - val_binary_crossentropy: 0.1945 - val_f1_score: 0.1640 - val_loss: 0.1945 - val_precision: 0.8370 - val_recall: 0.7514
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.4756 - binary_accuracy: 0.9267 - binary_crossentropy: 0.1842 - f1_score: 0.1741 - loss: 0.1842 - precision: 0.8534 - recall: 0.7622 - val_accuracy: 0.5205 - val_binary_accuracy: 0.9223 - val_binary_crossentropy: 0.1938 - val_f1_score: 0.1751 - val_loss: 0.1938 - val_precision: 0.8341 - val_recall: 0.7602
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 78s 5s/step - accuracy: 0.4809 - binary_accuracy: 0.9277 - binary_crossentropy: 0.1809 - f1_score: 0.1811 - loss: 0.1809 - precision: 0.8572 - recall: 0.7633 - val_accuracy: 0.4769 - val_binary_accuracy: 0.9236 - val_binary_crossentropy: 0.1901 - val_f1_score: 0.1648 - val_loss: 0.1901 - val_precision: 0.8559 - val_recall: 0.7403
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4585 - binary_accuracy: 0.9294 - binary_crossentropy: 0.1780 - f1_score: 0.1837 - loss: 0.1780 - precision: 0.8608 - recall: 0.7671 - val_accuracy: 0.5283 - val_binary_accuracy: 0.9245 - val_binary_crossentropy: 0.1877 - val_f1_score: 0.1581 - val_loss: 0.1877 - val_precision: 0.8653 - val_recall: 0.7344
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 54s 5s/step - accuracy: 0.4740 - binary_accuracy: 0.9315 - binary_crossentropy: 0.1729 - f1_score: 0.1793 - loss: 0.1729 - precision: 0.8707 - recall: 0.7711 - val_accuracy: 0.4769 - val_binary_accuracy: 0.9252 - val_binary_crossentropy: 0.1857 - val_f1_score: 0.1614 - val_loss: 0.1857 - val_precision: 0.8341 - val_recall: 0.7782
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4643 - binary_accuracy: 0.9335 - binary_crossentropy: 0.1699 - f1_score: 0.1711 - loss: 0.1699 - precision: 0.8689 - recall: 0.7844 - val_accuracy: 0.4639 - val_binary_accuracy: 0.9279 - val_binary_crossentropy: 0.1826 - val_f1_score: 0.1793 - val_loss: 0.1826 - val_precision: 0.8485 - val_recall: 0.7759
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4627 - binary_accuracy: 0.9344 - binary_crossentropy: 0.1657 - f1_score: 0.1821 - loss: 0.1657 - precision: 0.8721 - recall: 0.7853 - val_accuracy: 0.4926 - val_binary_accuracy: 0.9280 - val_binary_crossentropy: 0.1798 - val_f1_score: 0.1671 - val_loss: 0.1798 - val_precision: 0.8495 - val_recall: 0.7751
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 88s 6s/step - accuracy: 0.4525 - binary_accuracy: 0.9354 - binary_crossentropy: 0.1632 - f1_score: 0.1831 - loss: 0.1632 - precision: 0.8740 - recall: 0.7892 - val_accuracy: 0.4787 - val_binary_accuracy: 0.9286 - val_binary_crossentropy: 0.1793 - val_f1_score: 0.1769 - val_loss: 0.1793 - val_precision: 0.8597 - val_recall: 0.7658
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 75s 5s/step - accuracy: 0.4524 - binary_accuracy: 0.9373 - binary_crossentropy: 0.1616 - f1_score: 0.1918 - loss: 0.1616 - precision: 0.8766 - recall: 0.7965 - val_accuracy: 0.4795 - val_binary_accuracy: 0.9283 - val_binary_crossentropy: 0.1793 - val_f1_score: 0.1894 - val_loss: 0.1793 - val_precision: 0.8601 - val_recall: 0.7635
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.4501 - binary_accuracy: 0.9376 - binary_crossentropy: 0.1573 - f1_score: 0.2012 - loss: 0.1573 - precision: 0.8831 - recall: 0.7918 - val_accuracy: 0.4874 - val_binary_accuracy: 0.9304 - val_binary_crossentropy: 0.1760 - val_f1_score: 0.1762 - val_loss: 0.1760 - val_precision: 0.8412 - val_recall: 0.8009
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4625 - binary_accuracy: 0.9404 - binary_crossentropy: 0.1516 - f1_score: 0.1971 - loss: 0.1516 - precision: 0.8834 - recall: 0.8073 - val_accuracy: 0.5370 - val_binary_accuracy: 0.9316 - val_binary_crossentropy: 0.1746 - val_f1_score: 0.1694 - val_loss: 0.1746 - val_precision: 0.8459 - val_recall: 0.8016
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 54s 5s/step - accuracy: 0.4589 - binary_accuracy: 0.9413 - binary_crossentropy: 0.1497 - f1_score: 0.2023 - loss: 0.1497 - precision: 0.8834 - recall: 0.8136 - val_accuracy: 0.4482 - val_binary_accuracy: 0.9282 - val_binary_crossentropy: 0.1783 - val_f1_score: 0.2196 - val_loss: 0.1783 - val_precision: 0.8489 - val_recall: 0.7769
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4508 - binary_accuracy: 0.9398 - binary_crossentropy: 0.1521 - f1_score: 0.2079 - loss: 0.1521 - precision: 0.8835 - recall: 0.8029 - val_accuracy: 0.4778 - val_binary_accuracy: 0.9279 - val_binary_crossentropy: 0.1766 - val_f1_score: 0.2053 - val_loss: 0.1766 - val_precision: 0.8221 - val_recall: 0.8130
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4645 - binary_accuracy: 0.9418 - binary_crossentropy: 0.1474 - f1_score: 0.2011 - loss: 0.1474 - precision: 0.8793 - recall: 0.8199 - val_accuracy: 0.4970 - val_binary_accuracy: 0.9290 - val_binary_crossentropy: 0.1775 - val_f1_score: 0.2053 - val_loss: 0.1775 - val_precision: 0.8276 - val_recall: 0.8122
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 51s 5s/step - accuracy: 0.4833 - binary_accuracy: 0.9422 - binary_crossentropy: 0.1467 - f1_score: 0.2096 - loss: 0.1467 - precision: 0.8859 - recall: 0.8147 - val_accuracy: 0.4804 - val_binary_accuracy: 0.9316 - val_binary_crossentropy: 0.1736 - val_f1_score: 0.1992 - val_loss: 0.1736 - val_precision: 0.8495 - val_recall: 0.7968
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 86s 5s/step - accuracy: 0.4581 - binary_accuracy: 0.9469 - binary_crossentropy: 0.1380 - f1_score: 0.2064 - loss: 0.1380 - precision: 0.8938 - recall: 0.8323 - val_accuracy: 0.4978 - val_binary_accuracy: 0.9333 - val_binary_crossentropy: 0.1723 - val_f1_score: 0.1949 - val_loss: 0.1723 - val_precision: 0.8640 - val_recall: 0.7885
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 88s 5s/step - accuracy: 0.4507 - binary_accuracy: 0.9467 - binary_crossentropy: 0.1376 - f1_score: 0.2185 - loss: 0.1376 - precision: 0.8960 - recall: 0.8275 - val_accuracy: 0.5109 - val_binary_accuracy: 0.9326 - val_binary_crossentropy: 0.1704 - val_f1_score: 0.2114 - val_loss: 0.1704 - val_precision: 0.8496 - val_recall: 0.8032
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 73s 5s/step - accuracy: 0.4555 - binary_accuracy: 0.9474 - binary_crossentropy: 0.1358 - f1_score: 0.2251 - loss: 0.1358 - precision: 0.8966 - recall: 0.8316 - val_accuracy: 0.4639 - val_binary_accuracy: 0.9339 - val_binary_crossentropy: 0.1695 - val_f1_score: 0.2005 - val_loss: 0.1695 - val_precision: 0.8564 - val_recall: 0.8016
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 5s/step - accuracy: 0.4527 - binary_accuracy: 0.9498 - binary_crossentropy: 0.1304 - f1_score: 0.2179 - loss: 0.1304 - precision: 0.9020 - recall: 0.8386 - val_accuracy: 0.4169 - val_binary_accuracy: 0.9342 - val_binary_crossentropy: 0.1696 - val_f1_score: 0.2074 - val_loss: 0.1696 - val_precision: 0.8660 - val_recall: 0.7911
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4359 - binary_accuracy: 0.9514 - binary_crossentropy: 0.1272 - f1_score: 0.2198 - loss: 0.1272 - precision: 0.9053 - recall: 0.8434 - val_accuracy: 0.4369 - val_binary_accuracy: 0.9332 - val_binary_crossentropy: 0.1696 - val_f1_score: 0.2174 - val_loss: 0.1696 - val_precision: 0.8422 - val_recall: 0.8168
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4447 - binary_accuracy: 0.9525 - binary_crossentropy: 0.1248 - f1_score: 0.2297 - loss: 0.1248 - precision: 0.9049 - recall: 0.8509 - val_accuracy: 0.4952 - val_binary_accuracy: 0.9337 - val_binary_crossentropy: 0.1706 - val_f1_score: 0.2144 - val_loss: 0.1706 - val_precision: 0.8648 - val_recall: 0.7895
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 57s 5s/step - accuracy: 0.4552 - binary_accuracy: 0.9520 - binary_crossentropy: 0.1217 - f1_score: 0.2304 - loss: 0.1217 - precision: 0.9076 - recall: 0.8446 - val_accuracy: 0.3890 - val_binary_accuracy: 0.9333 - val_binary_crossentropy: 0.1696 - val_f1_score: 0.2256 - val_loss: 0.1696 - val_precision: 0.8536 - val_recall: 0.8019
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 57s 5s/step - accuracy: 0.4280 - binary_accuracy: 0.9519 - binary_crossentropy: 0.1245 - f1_score: 0.2356 - loss: 0.1245 - precision: 0.9073 - recall: 0.8462 - val_accuracy: 0.4795 - val_binary_accuracy: 0.9322 - val_binary_crossentropy: 0.1706 - val_f1_score: 0.2193 - val_loss: 0.1706 - val_precision: 0.8469 - val_recall: 0.8040
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4383 - binary_accuracy: 0.9535 - binary_crossentropy: 0.1215 - f1_score: 0.2296 - loss: 0.1215 - precision: 0.9044 - recall: 0.8564 - val_accuracy: 0.4282 - val_binary_accuracy: 0.9318 - val_binary_crossentropy: 0.1729 - val_f1_score: 0.2350 - val_loss: 0.1729 - val_precision: 0.8284 - val_recall: 0.8284
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 87s 5s/step - accuracy: 0.4342 - binary_accuracy: 0.9547 - binary_crossentropy: 0.1190 - f1_score: 0.2374 - loss: 0.1190 - precision: 0.9072 - recall: 0.8595 - val_accuracy: 0.4656 - val_binary_accuracy: 0.9350 - val_binary_crossentropy: 0.1705 - val_f1_score: 0.2049 - val_loss: 0.1705 - val_precision: 0.8563 - val_recall: 0.8089
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 72s 5s/step - accuracy: 0.4477 - binary_accuracy: 0.9571 - binary_crossentropy: 0.1135 - f1_score: 0.2326 - loss: 0.1135 - precision: 0.9125 - recall: 0.8667 - val_accuracy: 0.4560 - val_binary_accuracy: 0.9339 - val_binary_crossentropy: 0.1704 - val_f1_score: 0.2003 - val_loss: 0.1704 - val_precision: 0.8534 - val_recall: 0.8055
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4329 - binary_accuracy: 0.9564 - binary_crossentropy: 0.1158 - f1_score: 0.2346 - loss: 0.1158 - precision: 0.9147 - recall: 0.8621 - val_accuracy: 0.3786 - val_binary_accuracy: 0.9324 - val_binary_crossentropy: 0.1761 - val_f1_score: 0.2172 - val_loss: 0.1761 - val_precision: 0.8438 - val_recall: 0.8096
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 5s/step - accuracy: 0.4408 - binary_accuracy: 0.9560 - binary_crossentropy: 0.1146 - f1_score: 0.2256 - loss: 0.1146 - precision: 0.9086 - recall: 0.8664 - val_accuracy: 0.4265 - val_binary_accuracy: 0.9345 - val_binary_crossentropy: 0.1729 - val_f1_score: 0.2218 - val_loss: 0.1729 - val_precision: 0.8560 - val_recall: 0.8058
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4385 - binary_accuracy: 0.9562 - binary_crossentropy: 0.1134 - f1_score: 0.2325 - loss: 0.1134 - precision: 0.9120 - recall: 0.8622 - val_accuracy: 0.3534 - val_binary_accuracy: 0.9317 - val_binary_crossentropy: 0.1767 - val_f1_score: 0.2398 - val_loss: 0.1767 - val_precision: 0.8266 - val_recall: 0.8302
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4330 - binary_accuracy: 0.9567 - binary_crossentropy: 0.1144 - f1_score: 0.2332 - loss: 0.1144 - precision: 0.9062 - recall: 0.8718 - val_accuracy: 0.4143 - val_binary_accuracy: 0.9345 - val_binary_crossentropy: 0.1752 - val_f1_score: 0.2423 - val_loss: 0.1752 - val_precision: 0.8582 - val_recall: 0.8029
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 5s/step - accuracy: 0.4436 - binary_accuracy: 0.9593 - binary_crossentropy: 0.1075 - f1_score: 0.2377 - loss: 0.1075 - precision: 0.9193 - recall: 0.8726 - val_accuracy: 0.4560 - val_binary_accuracy: 0.9342 - val_binary_crossentropy: 0.1717 - val_f1_score: 0.2303 - val_loss: 0.1717 - val_precision: 0.8447 - val_recall: 0.8194
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 86s 6s/step - accuracy: 0.4434 - binary_accuracy: 0.9614 - binary_crossentropy: 0.1023 - f1_score: 0.2375 - loss: 0.1023 - precision: 0.9206 - recall: 0.8832 - val_accuracy: 0.3856 - val_binary_accuracy: 0.9343 - val_binary_crossentropy: 0.1726 - val_f1_score: 0.2351 - val_loss: 0.1726 - val_precision: 0.8437 - val_recall: 0.8217
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 52s 5s/step - accuracy: 0.4338 - binary_accuracy: 0.9608 - binary_crossentropy: 0.1031 - f1_score: 0.2407 - loss: 0.1031 - precision: 0.9200 - recall: 0.8788 - val_accuracy: 0.4395 - val_binary_accuracy: 0.9317 - val_binary_crossentropy: 0.1753 - val_f1_score: 0.2428 - val_loss: 0.1753 - val_precision: 0.8331 - val_recall: 0.8205
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 54s 5s/step - accuracy: 0.4437 - binary_accuracy: 0.9610 - binary_crossentropy: 0.1042 - f1_score: 0.2331 - loss: 0.1042 - precision: 0.9191 - recall: 0.8812 - val_accuracy: 0.4238 - val_binary_accuracy: 0.9331 - val_binary_crossentropy: 0.1785 - val_f1_score: 0.2469 - val_loss: 0.1785 - val_precision: 0.8414 - val_recall: 0.8174
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4298 - binary_accuracy: 0.9635 - binary_crossentropy: 0.0995 - f1_score: 0.2510 - loss: 0.0995 - precision: 0.9257 - recall: 0.8871 - val_accuracy: 0.4439 - val_binary_accuracy: 0.9344 - val_binary_crossentropy: 0.1747 - val_f1_score: 0.2348 - val_loss: 0.1747 - val_precision: 0.8373 - val_recall: 0.8313
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.4413 - binary_accuracy: 0.9636 - binary_crossentropy: 0.0967 - f1_score: 0.2458 - loss: 0.0967 - precision: 0.9226 - recall: 0.8915 - val_accuracy: 0.4604 - val_binary_accuracy: 0.9345 - val_binary_crossentropy: 0.1741 - val_f1_score: 0.2305 - val_loss: 0.1741 - val_precision: 0.8475 - val_recall: 0.8174
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4480 - binary_accuracy: 0.9648 - binary_crossentropy: 0.0947 - f1_score: 0.2446 - loss: 0.0947 - precision: 0.9261 - recall: 0.8930 - val_accuracy: 0.4195 - val_binary_accuracy: 0.9328 - val_binary_crossentropy: 0.1806 - val_f1_score: 0.2403 - val_loss: 0.1806 - val_precision: 0.8476 - val_recall: 0.8068
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4414 - binary_accuracy: 0.9649 - binary_crossentropy: 0.0934 - f1_score: 0.2458 - loss: 0.0934 - precision: 0.9309 - recall: 0.8900 - val_accuracy: 0.4665 - val_binary_accuracy: 0.9356 - val_binary_crossentropy: 0.1766 - val_f1_score: 0.2255 - val_loss: 0.1766 - val_precision: 0.8546 - val_recall: 0.8145
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.4410 - binary_accuracy: 0.9648 - binary_crossentropy: 0.0932 - f1_score: 0.2421 - loss: 0.0932 - precision: 0.9291 - recall: 0.8914 - val_accuracy: 0.4917 - val_binary_accuracy: 0.9349 - val_binary_crossentropy: 0.1813 - val_f1_score: 0.2159 - val_loss: 0.1813 - val_precision: 0.8486 - val_recall: 0.8184
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.4594 - binary_accuracy: 0.9648 - binary_crossentropy: 0.0940 - f1_score: 0.2444 - loss: 0.0940 - precision: 0.9256 - recall: 0.8951 - val_accuracy: 0.4273 - val_binary_accuracy: 0.9349 - val_binary_crossentropy: 0.1800 - val_f1_score: 0.2287 - val_loss: 0.1800 - val_precision: 0.8519 - val_recall: 0.8138
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.4296 - binary_accuracy: 0.9658 - binary_crossentropy: 0.0913 - f1_score: 0.2433 - loss: 0.0913 - precision: 0.9314 - recall: 0.8954 - val_accuracy: 0.4221 - val_binary_accuracy: 0.9334 - val_binary_crossentropy: 0.1849 - val_f1_score: 0.2203 - val_loss: 0.1849 - val_precision: 0.8260 - val_recall: 0.8426
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 74s 5s/step - accuracy: 0.4356 - binary_accuracy: 0.9672 - binary_crossentropy: 0.0888 - f1_score: 0.2482 - loss: 0.0888 - precision: 0.9307 - recall: 0.9025 - val_accuracy: 0.4134 - val_binary_accuracy: 0.9356 - val_binary_crossentropy: 0.1838 - val_f1_score: 0.2264 - val_loss: 0.1838 - val_precision: 0.8529 - val_recall: 0.8168
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4324 - binary_accuracy: 0.9674 - binary_crossentropy: 0.0865 - f1_score: 0.2455 - loss: 0.0865 - precision: 0.9332 - recall: 0.9007 - val_accuracy: 0.3655 - val_binary_accuracy: 0.9337 - val_binary_crossentropy: 0.1832 - val_f1_score: 0.2532 - val_loss: 0.1832 - val_precision: 0.8461 - val_recall: 0.8143
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4243 - binary_accuracy: 0.9681 - binary_crossentropy: 0.0850 - f1_score: 0.2521 - loss: 0.0850 - precision: 0.9372 - recall: 0.8990 - val_accuracy: 0.4221 - val_binary_accuracy: 0.9366 - val_binary_crossentropy: 0.1830 - val_f1_score: 0.2429 - val_loss: 0.1830 - val_precision: 0.8630 - val_recall: 0.8096
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.4172 - binary_accuracy: 0.9702 - binary_crossentropy: 0.0827 - f1_score: 0.2581 - loss: 0.0827 - precision: 0.9429 - recall: 0.9041 - val_accuracy: 0.4447 - val_binary_accuracy: 0.9349 - val_binary_crossentropy: 0.1852 - val_f1_score: 0.2383 - val_loss: 0.1852 - val_precision: 0.8510 - val_recall: 0.8153
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.4410 - binary_accuracy: 0.9709 - binary_crossentropy: 0.0796 - f1_score: 0.2481 - loss: 0.0796 - precision: 0.9426 - recall: 0.9088 - val_accuracy: 0.4125 - val_binary_accuracy: 0.9341 - val_binary_crossentropy: 0.1869 - val_f1_score: 0.2429 - val_loss: 0.1869 - val_precision: 0.8314 - val_recall: 0.8382
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4286 - binary_accuracy: 0.9713 - binary_crossentropy: 0.0797 - f1_score: 0.2546 - loss: 0.0797 - precision: 0.9373 - recall: 0.9172 - val_accuracy: 0.4787 - val_binary_accuracy: 0.9324 - val_binary_crossentropy: 0.1920 - val_f1_score: 0.2163 - val_loss: 0.1920 - val_precision: 0.8326 - val_recall: 0.8261
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4529 - binary_accuracy: 0.9720 - binary_crossentropy: 0.0755 - f1_score: 0.2458 - loss: 0.0755 - precision: 0.9398 - recall: 0.9177 - val_accuracy: 0.4552 - val_binary_accuracy: 0.9340 - val_binary_crossentropy: 0.1891 - val_f1_score: 0.2243 - val_loss: 0.1891 - val_precision: 0.8377 - val_recall: 0.8284
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.4525 - binary_accuracy: 0.9720 - binary_crossentropy: 0.0758 - f1_score: 0.2510 - loss: 0.0758 - precision: 0.9400 - recall: 0.9176 - val_accuracy: 0.4056 - val_binary_accuracy: 0.9339 - val_binary_crossentropy: 0.1929 - val_f1_score: 0.2602 - val_loss: 0.1929 - val_precision: 0.8455 - val_recall: 0.8163
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 71s 5s/step - accuracy: 0.4327 - binary_accuracy: 0.9737 - binary_crossentropy: 0.0742 - f1_score: 0.2617 - loss: 0.0742 - precision: 0.9471 - recall: 0.9192 - val_accuracy: 0.4334 - val_binary_accuracy: 0.9334 - val_binary_crossentropy: 0.1914 - val_f1_score: 0.2470 - val_loss: 0.1914 - val_precision: 0.8450 - val_recall: 0.8143
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4506 - binary_accuracy: 0.9740 - binary_crossentropy: 0.0720 - f1_score: 0.2613 - loss: 0.0720 - precision: 0.9479 - recall: 0.9198 - val_accuracy: 0.4056 - val_binary_accuracy: 0.9339 - val_binary_crossentropy: 0.1990 - val_f1_score: 0.2413 - val_loss: 0.1990 - val_precision: 0.8376 - val_recall: 0.8277
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 56s 5s/step - accuracy: 0.4294 - binary_accuracy: 0.9730 - binary_crossentropy: 0.0723 - f1_score: 0.2584 - loss: 0.0723 - precision: 0.9432 - recall: 0.9200 - val_accuracy: 0.3629 - val_binary_accuracy: 0.9314 - val_binary_crossentropy: 0.2007 - val_f1_score: 0.2662 - val_loss: 0.2007 - val_precision: 0.8370 - val_recall: 0.8132
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 56s 5s/step - accuracy: 0.4238 - binary_accuracy: 0.9739 - binary_crossentropy: 0.0716 - f1_score: 0.2688 - loss: 0.0716 - precision: 0.9487 - recall: 0.9189 - val_accuracy: 0.4395 - val_binary_accuracy: 0.9333 - val_binary_crossentropy: 0.1991 - val_f1_score: 0.2369 - val_loss: 0.1991 - val_precision: 0.8393 - val_recall: 0.8217
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.4264 - binary_accuracy: 0.9759 - binary_crossentropy: 0.0663 - f1_score: 0.2535 - loss: 0.0663 - precision: 0.9525 - recall: 0.9253 - val_accuracy: 0.4291 - val_binary_accuracy: 0.9325 - val_binary_crossentropy: 0.2009 - val_f1_score: 0.2414 - val_loss: 0.2009 - val_precision: 0.8433 - val_recall: 0.8109
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4237 - binary_accuracy: 0.9752 - binary_crossentropy: 0.0683 - f1_score: 0.2592 - loss: 0.0683 - precision: 0.9492 - recall: 0.9253 - val_accuracy: 0.4256 - val_binary_accuracy: 0.9311 - val_binary_crossentropy: 0.2041 - val_f1_score: 0.2314 - val_loss: 0.2041 - val_precision: 0.8198 - val_recall: 0.8377
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 78s 5s/step - accuracy: 0.4186 - binary_accuracy: 0.9766 - binary_crossentropy: 0.0646 - f1_score: 0.2583 - loss: 0.0646 - precision: 0.9498 - recall: 0.9313 - val_accuracy: 0.4813 - val_binary_accuracy: 0.9330 - val_binary_crossentropy: 0.2062 - val_f1_score: 0.2303 - val_loss: 0.2062 - val_precision: 0.8419 - val_recall: 0.8161
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 92s 6s/step - accuracy: 0.4447 - binary_accuracy: 0.9761 - binary_crossentropy: 0.0663 - f1_score: 0.2598 - loss: 0.0663 - precision: 0.9542 - recall: 0.9237 - val_accuracy: 0.4900 - val_binary_accuracy: 0.9319 - val_binary_crossentropy: 0.2078 - val_f1_score: 0.2274 - val_loss: 0.2078 - val_precision: 0.8260 - val_recall: 0.8328
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 56s 5s/step - accuracy: 0.4553 - binary_accuracy: 0.9769 - binary_crossentropy: 0.0631 - f1_score: 0.2585 - loss: 0.0631 - precision: 0.9507 - recall: 0.9323 - val_accuracy: 0.3899 - val_binary_accuracy: 0.9333 - val_binary_crossentropy: 0.2097 - val_f1_score: 0.2440 - val_loss: 0.2097 - val_precision: 0.8323 - val_recall: 0.8320
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4176 - binary_accuracy: 0.9784 - binary_crossentropy: 0.0613 - f1_score: 0.2547 - loss: 0.0613 - precision: 0.9543 - recall: 0.9361 - val_accuracy: 0.4030 - val_binary_accuracy: 0.9327 - val_binary_crossentropy: 0.2109 - val_f1_score: 0.2584 - val_loss: 0.2109 - val_precision: 0.8388 - val_recall: 0.8189
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 78s 5s/step - accuracy: 0.4240 - binary_accuracy: 0.9787 - binary_crossentropy: 0.0594 - f1_score: 0.2593 - loss: 0.0594 - precision: 0.9578 - recall: 0.9336 - val_accuracy: 0.4012 - val_binary_accuracy: 0.9327 - val_binary_crossentropy: 0.2078 - val_f1_score: 0.2579 - val_loss: 0.2078 - val_precision: 0.8321 - val_recall: 0.8284
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4115 - binary_accuracy: 0.9796 - binary_crossentropy: 0.0581 - f1_score: 0.2661 - loss: 0.0581 - precision: 0.9561 - recall: 0.9410 - val_accuracy: 0.4560 - val_binary_accuracy: 0.9325 - val_binary_crossentropy: 0.2112 - val_f1_score: 0.2541 - val_loss: 0.2112 - val_precision: 0.8363 - val_recall: 0.8210
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 56s 5s/step - accuracy: 0.4340 - binary_accuracy: 0.9811 - binary_crossentropy: 0.0562 - f1_score: 0.2676 - loss: 0.0562 - precision: 0.9613 - recall: 0.9433 - val_accuracy: 0.3943 - val_binary_accuracy: 0.9321 - val_binary_crossentropy: 0.2185 - val_f1_score: 0.2332 - val_loss: 0.2185 - val_precision: 0.8310 - val_recall: 0.8261
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4249 - binary_accuracy: 0.9801 - binary_crossentropy: 0.0566 - f1_score: 0.2566 - loss: 0.0566 - precision: 0.9603 - recall: 0.9388 - val_accuracy: 0.4326 - val_binary_accuracy: 0.9300 - val_binary_crossentropy: 0.2236 - val_f1_score: 0.2309 - val_loss: 0.2236 - val_precision: 0.8194 - val_recall: 0.8308
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.4270 - binary_accuracy: 0.9808 - binary_crossentropy: 0.0541 - f1_score: 0.2622 - loss: 0.0541 - precision: 0.9553 - recall: 0.9477 - val_accuracy: 0.4012 - val_binary_accuracy: 0.9329 - val_binary_crossentropy: 0.2182 - val_f1_score: 0.2437 - val_loss: 0.2182 - val_precision: 0.8375 - val_recall: 0.8217
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 89s 6s/step - accuracy: 0.4337 - binary_accuracy: 0.9826 - binary_crossentropy: 0.0513 - f1_score: 0.2691 - loss: 0.0513 - precision: 0.9674 - recall: 0.9440 - val_accuracy: 0.4560 - val_binary_accuracy: 0.9308 - val_binary_crossentropy: 0.2234 - val_f1_score: 0.2548 - val_loss: 0.2234 - val_precision: 0.8270 - val_recall: 0.8241
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 76s 5s/step - accuracy: 0.4313 - binary_accuracy: 0.9826 - binary_crossentropy: 0.0508 - f1_score: 0.2642 - loss: 0.0508 - precision: 0.9642 - recall: 0.9477 - val_accuracy: 0.4334 - val_binary_accuracy: 0.9311 - val_binary_crossentropy: 0.2294 - val_f1_score: 0.2582 - val_loss: 0.2294 - val_precision: 0.8512 - val_recall: 0.7916
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 56s 5s/step - accuracy: 0.4290 - binary_accuracy: 0.9815 - binary_crossentropy: 0.0523 - f1_score: 0.2720 - loss: 0.0523 - precision: 0.9652 - recall: 0.9406 - val_accuracy: 0.3795 - val_binary_accuracy: 0.9318 - val_binary_crossentropy: 0.2342 - val_f1_score: 0.2401 - val_loss: 0.2342 - val_precision: 0.8327 - val_recall: 0.8220
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.4127 - binary_accuracy: 0.9809 - binary_crossentropy: 0.0529 - f1_score: 0.2685 - loss: 0.0529 - precision: 0.9592 - recall: 0.9438 - val_accuracy: 0.4204 - val_binary_accuracy: 0.9309 - val_binary_crossentropy: 0.2316 - val_f1_score: 0.2343 - val_loss: 0.2316 - val_precision: 0.8321 - val_recall: 0.8171
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4388 - binary_accuracy: 0.9829 - binary_crossentropy: 0.0490 - f1_score: 0.2628 - loss: 0.0490 - precision: 0.9650 - recall: 0.9483 - val_accuracy: 0.3777 - val_binary_accuracy: 0.9306 - val_binary_crossentropy: 0.2370 - val_f1_score: 0.2573 - val_loss: 0.2370 - val_precision: 0.8340 - val_recall: 0.8125
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 5s/step - accuracy: 0.4115 - binary_accuracy: 0.9830 - binary_crossentropy: 0.0496 - f1_score: 0.2733 - loss: 0.0496 - precision: 0.9670 - recall: 0.9467 - val_accuracy: 0.3708 - val_binary_accuracy: 0.9322 - val_binary_crossentropy: 0.2339 - val_f1_score: 0.2763 - val_loss: 0.2339 - val_precision: 0.8283 - val_recall: 0.8313
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 53s 5s/step - accuracy: 0.4205 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0453 - f1_score: 0.2727 - loss: 0.0453 - precision: 0.9659 - recall: 0.9566 - val_accuracy: 0.3890 - val_binary_accuracy: 0.9321 - val_binary_crossentropy: 0.2350 - val_f1_score: 0.2516 - val_loss: 0.2350 - val_precision: 0.8390 - val_recall: 0.8148
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 53s 5s/step - accuracy: 0.4241 - binary_accuracy: 0.9864 - binary_crossentropy: 0.0424 - f1_score: 0.2600 - loss: 0.0424 - precision: 0.9747 - recall: 0.9568 - val_accuracy: 0.4134 - val_binary_accuracy: 0.9318 - val_binary_crossentropy: 0.2382 - val_f1_score: 0.2632 - val_loss: 0.2382 - val_precision: 0.8389 - val_recall: 0.8127
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.4142 - binary_accuracy: 0.9866 - binary_crossentropy: 0.0415 - f1_score: 0.2755 - loss: 0.0415 - precision: 0.9729 - recall: 0.9592 - val_accuracy: 0.3725 - val_binary_accuracy: 0.9323 - val_binary_crossentropy: 0.2441 - val_f1_score: 0.2532 - val_loss: 0.2441 - val_precision: 0.8379 - val_recall: 0.8176
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 52s 5s/step - accuracy: 0.4180 - binary_accuracy: 0.9866 - binary_crossentropy: 0.0406 - f1_score: 0.2692 - loss: 0.0406 - precision: 0.9729 - recall: 0.9590 - val_accuracy: 0.3916 - val_binary_accuracy: 0.9307 - val_binary_crossentropy: 0.2493 - val_f1_score: 0.2689 - val_loss: 0.2493 - val_precision: 0.8339 - val_recall: 0.8135
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 85s 5s/step - accuracy: 0.4188 - binary_accuracy: 0.9858 - binary_crossentropy: 0.0432 - f1_score: 0.2777 - loss: 0.0432 - precision: 0.9732 - recall: 0.9549 - val_accuracy: 0.3847 - val_binary_accuracy: 0.9308 - val_binary_crossentropy: 0.2523 - val_f1_score: 0.2715 - val_loss: 0.2523 - val_precision: 0.8345 - val_recall: 0.8130
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4211 - binary_accuracy: 0.9859 - binary_crossentropy: 0.0420 - f1_score: 0.2745 - loss: 0.0420 - precision: 0.9722 - recall: 0.9565 - val_accuracy: 0.3995 - val_binary_accuracy: 0.9312 - val_binary_crossentropy: 0.2564 - val_f1_score: 0.2398 - val_loss: 0.2564 - val_precision: 0.8312 - val_recall: 0.8207
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4174 - binary_accuracy: 0.9843 - binary_crossentropy: 0.0454 - f1_score: 0.2650 - loss: 0.0454 - precision: 0.9706 - recall: 0.9501 - val_accuracy: 0.4595 - val_binary_accuracy: 0.9296 - val_binary_crossentropy: 0.2570 - val_f1_score: 0.2470 - val_loss: 0.2570 - val_precision: 0.8173 - val_recall: 0.8318
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4513 - binary_accuracy: 0.9856 - binary_crossentropy: 0.0421 - f1_score: 0.2656 - loss: 0.0421 - precision: 0.9670 - recall: 0.9604 - val_accuracy: 0.4334 - val_binary_accuracy: 0.9321 - val_binary_crossentropy: 0.2525 - val_f1_score: 0.2504 - val_loss: 0.2525 - val_precision: 0.8342 - val_recall: 0.8215
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4441 - binary_accuracy: 0.9880 - binary_crossentropy: 0.0368 - f1_score: 0.2763 - loss: 0.0368 - precision: 0.9764 - recall: 0.9629 - val_accuracy: 0.3751 - val_binary_accuracy: 0.9299 - val_binary_crossentropy: 0.2655 - val_f1_score: 0.2579 - val_loss: 0.2655 - val_precision: 0.8313 - val_recall: 0.8122
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.4559 - binary_accuracy: 0.7330 - binary_crossentropy: 0.6191 - f1_score: 0.0527 - loss: 0.6191 - precision: 0.3976 - recall: 0.5694 - val_accuracy: 0.6432 - val_binary_accuracy: 0.8517 - val_binary_crossentropy: 0.3956 - val_f1_score: 0.0740 - val_loss: 0.3956 - val_precision: 0.6441 - val_recall: 0.5670
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - accuracy: 0.3766 - binary_accuracy: 0.8531 - binary_crossentropy: 0.3772 - f1_score: 0.0863 - loss: 0.3772 - precision: 0.6528 - recall: 0.5601 - val_accuracy: 0.6789 - val_binary_accuracy: 0.8611 - val_binary_crossentropy: 0.3426 - val_f1_score: 0.0635 - val_loss: 0.3426 - val_precision: 0.6976 - val_recall: 0.5312
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 74s 5s/step - accuracy: 0.5511 - binary_accuracy: 0.8614 - binary_crossentropy: 0.3443 - f1_score: 0.0799 - loss: 0.3443 - precision: 0.7076 - recall: 0.5120 - val_accuracy: 0.4700 - val_binary_accuracy: 0.8639 - val_binary_crossentropy: 0.3304 - val_f1_score: 0.0952 - val_loss: 0.3304 - val_precision: 0.7162 - val_recall: 0.5219
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.4894 - binary_accuracy: 0.8624 - binary_crossentropy: 0.3331 - f1_score: 0.0924 - loss: 0.3331 - precision: 0.7113 - recall: 0.5152 - val_accuracy: 0.4926 - val_binary_accuracy: 0.8690 - val_binary_crossentropy: 0.3231 - val_f1_score: 0.0881 - val_loss: 0.3231 - val_precision: 0.7625 - val_recall: 0.4954
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 85s 5s/step - accuracy: 0.4800 - binary_accuracy: 0.8680 - binary_crossentropy: 0.3262 - f1_score: 0.0902 - loss: 0.3262 - precision: 0.7633 - recall: 0.4883 - val_accuracy: 0.5057 - val_binary_accuracy: 0.8716 - val_binary_crossentropy: 0.3160 - val_f1_score: 0.0886 - val_loss: 0.3160 - val_precision: 0.7806 - val_recall: 0.4923
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.5083 - binary_accuracy: 0.8724 - binary_crossentropy: 0.3183 - f1_score: 0.0889 - loss: 0.3183 - precision: 0.7823 - recall: 0.4947 - val_accuracy: 0.5135 - val_binary_accuracy: 0.8784 - val_binary_crossentropy: 0.3067 - val_f1_score: 0.0902 - val_loss: 0.3067 - val_precision: 0.8049 - val_recall: 0.5124
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 53s 5s/step - accuracy: 0.5038 - binary_accuracy: 0.8795 - binary_crossentropy: 0.3063 - f1_score: 0.0920 - loss: 0.3063 - precision: 0.8104 - recall: 0.5146 - val_accuracy: 0.5692 - val_binary_accuracy: 0.8831 - val_binary_crossentropy: 0.2936 - val_f1_score: 0.0921 - val_loss: 0.2936 - val_precision: 0.7979 - val_recall: 0.5513
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 5s/step - accuracy: 0.5389 - binary_accuracy: 0.8860 - binary_crossentropy: 0.2905 - f1_score: 0.0975 - loss: 0.2905 - precision: 0.8040 - recall: 0.5637 - val_accuracy: 0.5117 - val_binary_accuracy: 0.8880 - val_binary_crossentropy: 0.2790 - val_f1_score: 0.1075 - val_loss: 0.2790 - val_precision: 0.7907 - val_recall: 0.5935
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.4800 - binary_accuracy: 0.8896 - binary_crossentropy: 0.2773 - f1_score: 0.1095 - loss: 0.2773 - precision: 0.7962 - recall: 0.5953 - val_accuracy: 0.5352 - val_binary_accuracy: 0.8904 - val_binary_crossentropy: 0.2682 - val_f1_score: 0.1158 - val_loss: 0.2682 - val_precision: 0.7744 - val_recall: 0.6332
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 63s 6s/step - accuracy: 0.4692 - binary_accuracy: 0.8949 - binary_crossentropy: 0.2635 - f1_score: 0.1147 - loss: 0.2635 - precision: 0.8029 - recall: 0.6210 - val_accuracy: 0.4648 - val_binary_accuracy: 0.8960 - val_binary_crossentropy: 0.2569 - val_f1_score: 0.1191 - val_loss: 0.2569 - val_precision: 0.7956 - val_recall: 0.6417
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 57s 5s/step - accuracy: 0.4446 - binary_accuracy: 0.8995 - binary_crossentropy: 0.2502 - f1_score: 0.1208 - loss: 0.2502 - precision: 0.8148 - recall: 0.6382 - val_accuracy: 0.5265 - val_binary_accuracy: 0.9008 - val_binary_crossentropy: 0.2424 - val_f1_score: 0.1211 - val_loss: 0.2424 - val_precision: 0.8059 - val_recall: 0.6600
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.4682 - binary_accuracy: 0.9038 - binary_crossentropy: 0.2393 - f1_score: 0.1252 - loss: 0.2393 - precision: 0.8188 - recall: 0.6618 - val_accuracy: 0.4961 - val_binary_accuracy: 0.9051 - val_binary_crossentropy: 0.2324 - val_f1_score: 0.1331 - val_loss: 0.2324 - val_precision: 0.8231 - val_recall: 0.6654
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.4608 - binary_accuracy: 0.9066 - binary_crossentropy: 0.2301 - f1_score: 0.1355 - loss: 0.2301 - precision: 0.8337 - recall: 0.6663 - val_accuracy: 0.4804 - val_binary_accuracy: 0.9092 - val_binary_crossentropy: 0.2238 - val_f1_score: 0.1396 - val_loss: 0.2238 - val_precision: 0.8298 - val_recall: 0.6832
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 53s 5s/step - accuracy: 0.4653 - binary_accuracy: 0.9127 - binary_crossentropy: 0.2188 - f1_score: 0.1487 - loss: 0.2188 - precision: 0.8405 - recall: 0.6930 - val_accuracy: 0.4822 - val_binary_accuracy: 0.9123 - val_binary_crossentropy: 0.2157 - val_f1_score: 0.1487 - val_loss: 0.2157 - val_precision: 0.8336 - val_recall: 0.6981
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 89s 6s/step - accuracy: 0.4493 - binary_accuracy: 0.9156 - binary_crossentropy: 0.2110 - f1_score: 0.1633 - loss: 0.2110 - precision: 0.8407 - recall: 0.7100 - val_accuracy: 0.4996 - val_binary_accuracy: 0.9129 - val_binary_crossentropy: 0.2135 - val_f1_score: 0.1631 - val_loss: 0.2135 - val_precision: 0.8215 - val_recall: 0.7174
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step - accuracy: 0.4579 - binary_accuracy: 0.9176 - binary_crossentropy: 0.2083 - f1_score: 0.1607 - loss: 0.2083 - precision: 0.8392 - recall: 0.7245 - val_accuracy: 0.4752 - val_binary_accuracy: 0.9162 - val_binary_crossentropy: 0.2055 - val_f1_score: 0.1594 - val_loss: 0.2055 - val_precision: 0.8316 - val_recall: 0.7251
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.4561 - binary_accuracy: 0.9205 - binary_crossentropy: 0.2006 - f1_score: 0.1683 - loss: 0.2006 - precision: 0.8461 - recall: 0.7355 - val_accuracy: 0.4648 - val_binary_accuracy: 0.9177 - val_binary_crossentropy: 0.2012 - val_f1_score: 0.1648 - val_loss: 0.2012 - val_precision: 0.8299 - val_recall: 0.7367
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 53s 5s/step - accuracy: 0.4562 - binary_accuracy: 0.9236 - binary_crossentropy: 0.1924 - f1_score: 0.1713 - loss: 0.1924 - precision: 0.8525 - recall: 0.7436 - val_accuracy: 0.4500 - val_binary_accuracy: 0.9187 - val_binary_crossentropy: 0.1991 - val_f1_score: 0.1707 - val_loss: 0.1991 - val_precision: 0.8285 - val_recall: 0.7452
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 85s 5s/step - accuracy: 0.4454 - binary_accuracy: 0.9257 - binary_crossentropy: 0.1880 - f1_score: 0.1798 - loss: 0.1880 - precision: 0.8525 - recall: 0.7569 - val_accuracy: 0.4839 - val_binary_accuracy: 0.9213 - val_binary_crossentropy: 0.1926 - val_f1_score: 0.1772 - val_loss: 0.1926 - val_precision: 0.8386 - val_recall: 0.7481
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4500 - binary_accuracy: 0.9265 - binary_crossentropy: 0.1851 - f1_score: 0.1813 - loss: 0.1851 - precision: 0.8548 - recall: 0.7599 - val_accuracy: 0.4848 - val_binary_accuracy: 0.9228 - val_binary_crossentropy: 0.1905 - val_f1_score: 0.1723 - val_loss: 0.1905 - val_precision: 0.8435 - val_recall: 0.7512
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4552 - binary_accuracy: 0.9275 - binary_crossentropy: 0.1820 - f1_score: 0.1904 - loss: 0.1820 - precision: 0.8560 - recall: 0.7639 - val_accuracy: 0.4517 - val_binary_accuracy: 0.9240 - val_binary_crossentropy: 0.1868 - val_f1_score: 0.1787 - val_loss: 0.1868 - val_precision: 0.8495 - val_recall: 0.7504
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.4629 - binary_accuracy: 0.9299 - binary_crossentropy: 0.1770 - f1_score: 0.1905 - loss: 0.1770 - precision: 0.8620 - recall: 0.7692 - val_accuracy: 0.4447 - val_binary_accuracy: 0.9229 - val_binary_crossentropy: 0.1878 - val_f1_score: 0.1753 - val_loss: 0.1878 - val_precision: 0.8345 - val_recall: 0.7635
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 60s 5s/step - accuracy: 0.4415 - binary_accuracy: 0.9308 - binary_crossentropy: 0.1747 - f1_score: 0.1953 - loss: 0.1747 - precision: 0.8632 - recall: 0.7765 - val_accuracy: 0.4830 - val_binary_accuracy: 0.9269 - val_binary_crossentropy: 0.1814 - val_f1_score: 0.1853 - val_loss: 0.1814 - val_precision: 0.8555 - val_recall: 0.7609
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 58s 5s/step - accuracy: 0.4456 - binary_accuracy: 0.9330 - binary_crossentropy: 0.1703 - f1_score: 0.2039 - loss: 0.1703 - precision: 0.8674 - recall: 0.7826 - val_accuracy: 0.4526 - val_binary_accuracy: 0.9278 - val_binary_crossentropy: 0.1803 - val_f1_score: 0.1875 - val_loss: 0.1803 - val_precision: 0.8375 - val_recall: 0.7898
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.4476 - binary_accuracy: 0.9349 - binary_crossentropy: 0.1663 - f1_score: 0.2013 - loss: 0.1663 - precision: 0.8689 - recall: 0.7930 - val_accuracy: 0.5265 - val_binary_accuracy: 0.9278 - val_binary_crossentropy: 0.1809 - val_f1_score: 0.1760 - val_loss: 0.1809 - val_precision: 0.8491 - val_recall: 0.7741
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 87s 6s/step - accuracy: 0.4618 - binary_accuracy: 0.9352 - binary_crossentropy: 0.1633 - f1_score: 0.2049 - loss: 0.1633 - precision: 0.8709 - recall: 0.7908 - val_accuracy: 0.4621 - val_binary_accuracy: 0.9306 - val_binary_crossentropy: 0.1757 - val_f1_score: 0.2068 - val_loss: 0.1757 - val_precision: 0.8584 - val_recall: 0.7795
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.4519 - binary_accuracy: 0.9371 - binary_crossentropy: 0.1591 - f1_score: 0.2073 - loss: 0.1591 - precision: 0.8728 - recall: 0.8007 - val_accuracy: 0.4308 - val_binary_accuracy: 0.9305 - val_binary_crossentropy: 0.1745 - val_f1_score: 0.2013 - val_loss: 0.1745 - val_precision: 0.8647 - val_recall: 0.7707
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 58s 5s/step - accuracy: 0.4282 - binary_accuracy: 0.9388 - binary_crossentropy: 0.1571 - f1_score: 0.2162 - loss: 0.1571 - precision: 0.8836 - recall: 0.7981 - val_accuracy: 0.4491 - val_binary_accuracy: 0.9313 - val_binary_crossentropy: 0.1768 - val_f1_score: 0.1945 - val_loss: 0.1768 - val_precision: 0.8449 - val_recall: 0.8014
# Epoch 29/100
# ...
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.3924 - binary_accuracy: 0.9648 - binary_crossentropy: 0.0930 - f1_score: 0.2569 - loss: 0.0930 - precision: 0.9311 - recall: 0.8890 - val_accuracy: 0.3185 - val_binary_accuracy: 0.9357 - val_binary_crossentropy: 0.1823 - val_f1_score: 0.2619 - val_loss: 0.1823 - val_precision: 0.8584 - val_recall: 0.8101
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step - accuracy: 0.3793 - binary_accuracy: 0.9668 - binary_crossentropy: 0.0888 - f1_score: 0.2684 - loss: 0.0888 - precision: 0.9335 - recall: 0.8959 - val_accuracy: 0.3272 - val_binary_accuracy: 0.9374 - val_binary_crossentropy: 0.1782 - val_f1_score: 0.2606 - val_loss: 0.1782 - val_precision: 0.8526 - val_recall: 0.8282
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 6s/step - accuracy: 0.3836 - binary_accuracy: 0.9678 - binary_crossentropy: 0.0862 - f1_score: 0.2590 - loss: 0.0862 - precision: 0.9354 - recall: 0.8999 - val_accuracy: 0.4195 - val_binary_accuracy: 0.9339 - val_binary_crossentropy: 0.1808 - val_f1_score: 0.2548 - val_loss: 0.1808 - val_precision: 0.8500 - val_recall: 0.8101
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step - accuracy: 0.3967 - binary_accuracy: 0.9688 - binary_crossentropy: 0.0841 - f1_score: 0.2720 - loss: 0.0841 - precision: 0.9367 - recall: 0.9044 - val_accuracy: 0.3594 - val_binary_accuracy: 0.9357 - val_binary_crossentropy: 0.1810 - val_f1_score: 0.2773 - val_loss: 0.1810 - val_precision: 0.8604 - val_recall: 0.8078
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 6s/step - accuracy: 0.3752 - binary_accuracy: 0.9685 - binary_crossentropy: 0.0852 - f1_score: 0.2591 - loss: 0.0852 - precision: 0.9412 - recall: 0.8984 - val_accuracy: 0.3838 - val_binary_accuracy: 0.9346 - val_binary_crossentropy: 0.1805 - val_f1_score: 0.2684 - val_loss: 0.1805 - val_precision: 0.8472 - val_recall: 0.8187
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.3942 - binary_accuracy: 0.9701 - binary_crossentropy: 0.0802 - f1_score: 0.2645 - loss: 0.0802 - precision: 0.9390 - recall: 0.9088 - val_accuracy: 0.3299 - val_binary_accuracy: 0.9365 - val_binary_crossentropy: 0.1808 - val_f1_score: 0.2568 - val_loss: 0.1808 - val_precision: 0.8494 - val_recall: 0.8269
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step - accuracy: 0.3807 - binary_accuracy: 0.9714 - binary_crossentropy: 0.0782 - f1_score: 0.2532 - loss: 0.0782 - precision: 0.9402 - recall: 0.9138 - val_accuracy: 0.4134 - val_binary_accuracy: 0.9358 - val_binary_crossentropy: 0.1825 - val_f1_score: 0.2618 - val_loss: 0.1825 - val_precision: 0.8478 - val_recall: 0.8251
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.4096 - binary_accuracy: 0.9700 - binary_crossentropy: 0.0794 - f1_score: 0.2613 - loss: 0.0794 - precision: 0.9363 - recall: 0.9107 - val_accuracy: 0.4247 - val_binary_accuracy: 0.9344 - val_binary_crossentropy: 0.1855 - val_f1_score: 0.2669 - val_loss: 0.1855 - val_precision: 0.8510 - val_recall: 0.8120
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 80s 6s/step - accuracy: 0.3990 - binary_accuracy: 0.9716 - binary_crossentropy: 0.0771 - f1_score: 0.2635 - loss: 0.0771 - precision: 0.9419 - recall: 0.9138 - val_accuracy: 0.3995 - val_binary_accuracy: 0.9345 - val_binary_crossentropy: 0.1851 - val_f1_score: 0.2756 - val_loss: 0.1851 - val_precision: 0.8534 - val_recall: 0.8096
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 6s/step - accuracy: 0.4023 - binary_accuracy: 0.9724 - binary_crossentropy: 0.0753 - f1_score: 0.2686 - loss: 0.0753 - precision: 0.9451 - recall: 0.9145 - val_accuracy: 0.3629 - val_binary_accuracy: 0.9343 - val_binary_crossentropy: 0.1903 - val_f1_score: 0.2498 - val_loss: 0.1903 - val_precision: 0.8387 - val_recall: 0.8290
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 6s/step - accuracy: 0.3885 - binary_accuracy: 0.9736 - binary_crossentropy: 0.0730 - f1_score: 0.2648 - loss: 0.0730 - precision: 0.9468 - recall: 0.9181 - val_accuracy: 0.4369 - val_binary_accuracy: 0.9312 - val_binary_crossentropy: 0.1944 - val_f1_score: 0.2659 - val_loss: 0.1944 - val_precision: 0.8314 - val_recall: 0.8205
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step - accuracy: 0.3916 - binary_accuracy: 0.9745 - binary_crossentropy: 0.0708 - f1_score: 0.2846 - loss: 0.0708 - precision: 0.9470 - recall: 0.9229 - val_accuracy: 0.3986 - val_binary_accuracy: 0.9355 - val_binary_crossentropy: 0.1872 - val_f1_score: 0.2675 - val_loss: 0.1872 - val_precision: 0.8476 - val_recall: 0.8238
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.3909 - binary_accuracy: 0.9741 - binary_crossentropy: 0.0696 - f1_score: 0.2686 - loss: 0.0696 - precision: 0.9503 - recall: 0.9181 - val_accuracy: 0.3760 - val_binary_accuracy: 0.9350 - val_binary_crossentropy: 0.1919 - val_f1_score: 0.2520 - val_loss: 0.1919 - val_precision: 0.8437 - val_recall: 0.8261
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 83s 6s/step - accuracy: 0.3888 - binary_accuracy: 0.9736 - binary_crossentropy: 0.0702 - f1_score: 0.2610 - loss: 0.0702 - precision: 0.9470 - recall: 0.9180 - val_accuracy: 0.3995 - val_binary_accuracy: 0.9337 - val_binary_crossentropy: 0.1942 - val_f1_score: 0.2564 - val_loss: 0.1942 - val_precision: 0.8305 - val_recall: 0.8369
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.3882 - binary_accuracy: 0.9757 - binary_crossentropy: 0.0666 - f1_score: 0.2679 - loss: 0.0666 - precision: 0.9505 - recall: 0.9257 - val_accuracy: 0.3368 - val_binary_accuracy: 0.9359 - val_binary_crossentropy: 0.2012 - val_f1_score: 0.2553 - val_loss: 0.2012 - val_precision: 0.8486 - val_recall: 0.8243
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.3801 - binary_accuracy: 0.9744 - binary_crossentropy: 0.0692 - f1_score: 0.2670 - loss: 0.0692 - precision: 0.9484 - recall: 0.9211 - val_accuracy: 0.4003 - val_binary_accuracy: 0.9348 - val_binary_crossentropy: 0.1956 - val_f1_score: 0.2521 - val_loss: 0.1956 - val_precision: 0.8419 - val_recall: 0.8272
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.4028 - binary_accuracy: 0.9772 - binary_crossentropy: 0.0635 - f1_score: 0.2677 - loss: 0.0635 - precision: 0.9546 - recall: 0.9295 - val_accuracy: 0.3977 - val_binary_accuracy: 0.9344 - val_binary_crossentropy: 0.1999 - val_f1_score: 0.2659 - val_loss: 0.1999 - val_precision: 0.8342 - val_recall: 0.8359
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step - accuracy: 0.3813 - binary_accuracy: 0.9784 - binary_crossentropy: 0.0619 - f1_score: 0.2750 - loss: 0.0619 - precision: 0.9548 - recall: 0.9360 - val_accuracy: 0.4108 - val_binary_accuracy: 0.9337 - val_binary_crossentropy: 0.1975 - val_f1_score: 0.2899 - val_loss: 0.1975 - val_precision: 0.8539 - val_recall: 0.8040
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.3970 - binary_accuracy: 0.9799 - binary_crossentropy: 0.0589 - f1_score: 0.2739 - loss: 0.0589 - precision: 0.9632 - recall: 0.9348 - val_accuracy: 0.4265 - val_binary_accuracy: 0.9328 - val_binary_crossentropy: 0.2028 - val_f1_score: 0.2643 - val_loss: 0.2028 - val_precision: 0.8317 - val_recall: 0.8300
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 59s 5s/step - accuracy: 0.3967 - binary_accuracy: 0.9789 - binary_crossentropy: 0.0612 - f1_score: 0.2688 - loss: 0.0612 - precision: 0.9568 - recall: 0.9362 - val_accuracy: 0.3751 - val_binary_accuracy: 0.9327 - val_binary_crossentropy: 0.2068 - val_f1_score: 0.2639 - val_loss: 0.2068 - val_precision: 0.8178 - val_recall: 0.8509
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 85s 6s/step - accuracy: 0.3741 - binary_accuracy: 0.9788 - binary_crossentropy: 0.0593 - f1_score: 0.2829 - loss: 0.0593 - precision: 0.9522 - recall: 0.9410 - val_accuracy: 0.3664 - val_binary_accuracy: 0.9320 - val_binary_crossentropy: 0.2078 - val_f1_score: 0.2660 - val_loss: 0.2078 - val_precision: 0.8212 - val_recall: 0.8411
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 6s/step - accuracy: 0.3891 - binary_accuracy: 0.9794 - binary_crossentropy: 0.0576 - f1_score: 0.2847 - loss: 0.0576 - precision: 0.9552 - recall: 0.9402 - val_accuracy: 0.3255 - val_binary_accuracy: 0.9344 - val_binary_crossentropy: 0.2106 - val_f1_score: 0.2772 - val_loss: 0.2106 - val_precision: 0.8443 - val_recall: 0.8212
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step - accuracy: 0.3814 - binary_accuracy: 0.9798 - binary_crossentropy: 0.0566 - f1_score: 0.2738 - loss: 0.0566 - precision: 0.9590 - recall: 0.9382 - val_accuracy: 0.3377 - val_binary_accuracy: 0.9319 - val_binary_crossentropy: 0.2250 - val_f1_score: 0.2646 - val_loss: 0.2250 - val_precision: 0.8250 - val_recall: 0.8344
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 6s/step - accuracy: 0.3770 - binary_accuracy: 0.9769 - binary_crossentropy: 0.0618 - f1_score: 0.2891 - loss: 0.0618 - precision: 0.9489 - recall: 0.9339 - val_accuracy: 0.3873 - val_binary_accuracy: 0.9337 - val_binary_crossentropy: 0.2117 - val_f1_score: 0.2905 - val_loss: 0.2117 - val_precision: 0.8491 - val_recall: 0.8104
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 60s 6s/step - accuracy: 0.3963 - binary_accuracy: 0.9805 - binary_crossentropy: 0.0548 - f1_score: 0.2796 - loss: 0.0548 - precision: 0.9639 - recall: 0.9374 - val_accuracy: 0.3586 - val_binary_accuracy: 0.9342 - val_binary_crossentropy: 0.2121 - val_f1_score: 0.2559 - val_loss: 0.2121 - val_precision: 0.8326 - val_recall: 0.8369
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 6s/step - accuracy: 0.3853 - binary_accuracy: 0.9818 - binary_crossentropy: 0.0522 - f1_score: 0.2813 - loss: 0.0522 - precision: 0.9644 - recall: 0.9434 - val_accuracy: 0.3943 - val_binary_accuracy: 0.9327 - val_binary_crossentropy: 0.2214 - val_f1_score: 0.2723 - val_loss: 0.2214 - val_precision: 0.8395 - val_recall: 0.8179
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.3915 - binary_accuracy: 0.9816 - binary_crossentropy: 0.0524 - f1_score: 0.2728 - loss: 0.0524 - precision: 0.9635 - recall: 0.9434 - val_accuracy: 0.4421 - val_binary_accuracy: 0.9300 - val_binary_crossentropy: 0.2245 - val_f1_score: 0.2790 - val_loss: 0.2245 - val_precision: 0.8321 - val_recall: 0.8117
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.4024 - binary_accuracy: 0.9828 - binary_crossentropy: 0.0496 - f1_score: 0.2814 - loss: 0.0496 - precision: 0.9642 - recall: 0.9488 - val_accuracy: 0.3882 - val_binary_accuracy: 0.9339 - val_binary_crossentropy: 0.2360 - val_f1_score: 0.2726 - val_loss: 0.2360 - val_precision: 0.8618 - val_recall: 0.7950
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 82s 5s/step - accuracy: 0.3937 - binary_accuracy: 0.9782 - binary_crossentropy: 0.0577 - f1_score: 0.2828 - loss: 0.0577 - precision: 0.9599 - recall: 0.9291 - val_accuracy: 0.4569 - val_binary_accuracy: 0.9312 - val_binary_crossentropy: 0.2251 - val_f1_score: 0.2622 - val_loss: 0.2251 - val_precision: 0.8349 - val_recall: 0.8153
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 5s/step - accuracy: 0.3962 - binary_accuracy: 0.9827 - binary_crossentropy: 0.0489 - f1_score: 0.2814 - loss: 0.0489 - precision: 0.9619 - recall: 0.9503 - val_accuracy: 0.4238 - val_binary_accuracy: 0.9322 - val_binary_crossentropy: 0.2277 - val_f1_score: 0.2668 - val_loss: 0.2277 - val_precision: 0.8336 - val_recall: 0.8233
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 62s 6s/step - accuracy: 0.3931 - binary_accuracy: 0.9841 - binary_crossentropy: 0.0474 - f1_score: 0.2789 - loss: 0.0474 - precision: 0.9697 - recall: 0.9496 - val_accuracy: 0.3673 - val_binary_accuracy: 0.9329 - val_binary_crossentropy: 0.2240 - val_f1_score: 0.2798 - val_loss: 0.2240 - val_precision: 0.8342 - val_recall: 0.8266
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.3781 - binary_accuracy: 0.9842 - binary_crossentropy: 0.0465 - f1_score: 0.2815 - loss: 0.0465 - precision: 0.9696 - recall: 0.9502 - val_accuracy: 0.3124 - val_binary_accuracy: 0.9329 - val_binary_crossentropy: 0.2483 - val_f1_score: 0.2837 - val_loss: 0.2483 - val_precision: 0.8413 - val_recall: 0.8166
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 60s 6s/step - accuracy: 0.3789 - binary_accuracy: 0.9806 - binary_crossentropy: 0.0513 - f1_score: 0.2798 - loss: 0.0513 - precision: 0.9600 - recall: 0.9409 - val_accuracy: 0.3403 - val_binary_accuracy: 0.9335 - val_binary_crossentropy: 0.2408 - val_f1_score: 0.2813 - val_loss: 0.2408 - val_precision: 0.8356 - val_recall: 0.8287
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.3832 - binary_accuracy: 0.9826 - binary_crossentropy: 0.0488 - f1_score: 0.2755 - loss: 0.0488 - precision: 0.9649 - recall: 0.9477 - val_accuracy: 0.3534 - val_binary_accuracy: 0.9334 - val_binary_crossentropy: 0.2295 - val_f1_score: 0.2971 - val_loss: 0.2295 - val_precision: 0.8320 - val_recall: 0.8333
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step - accuracy: 0.3966 - binary_accuracy: 0.9864 - binary_crossentropy: 0.0417 - f1_score: 0.2932 - loss: 0.0417 - precision: 0.9718 - recall: 0.9596 - val_accuracy: 0.3568 - val_binary_accuracy: 0.9335 - val_binary_crossentropy: 0.2322 - val_f1_score: 0.2766 - val_loss: 0.2322 - val_precision: 0.8401 - val_recall: 0.8217
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 81s 6s/step - accuracy: 0.3808 - binary_accuracy: 0.9877 - binary_crossentropy: 0.0388 - f1_score: 0.2829 - loss: 0.0388 - precision: 0.9772 - recall: 0.9602 - val_accuracy: 0.4047 - val_binary_accuracy: 0.9316 - val_binary_crossentropy: 0.2418 - val_f1_score: 0.2780 - val_loss: 0.2418 - val_precision: 0.8271 - val_recall: 0.8292
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 6s/step - accuracy: 0.4010 - binary_accuracy: 0.9863 - binary_crossentropy: 0.0412 - f1_score: 0.2870 - loss: 0.0412 - precision: 0.9698 - recall: 0.9612 - val_accuracy: 0.4273 - val_binary_accuracy: 0.9337 - val_binary_crossentropy: 0.2428 - val_f1_score: 0.2594 - val_loss: 0.2428 - val_precision: 0.8338 - val_recall: 0.8320
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.3941 - binary_accuracy: 0.9857 - binary_crossentropy: 0.0414 - f1_score: 0.2855 - loss: 0.0414 - precision: 0.9692 - recall: 0.9589 - val_accuracy: 0.4326 - val_binary_accuracy: 0.9306 - val_binary_crossentropy: 0.2546 - val_f1_score: 0.2620 - val_loss: 0.2546 - val_precision: 0.8231 - val_recall: 0.8292
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 86s 6s/step - accuracy: 0.3864 - binary_accuracy: 0.9855 - binary_crossentropy: 0.0419 - f1_score: 0.2771 - loss: 0.0419 - precision: 0.9674 - recall: 0.9601 - val_accuracy: 0.3986 - val_binary_accuracy: 0.9318 - val_binary_crossentropy: 0.2430 - val_f1_score: 0.2726 - val_loss: 0.2430 - val_precision: 0.8316 - val_recall: 0.8233
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 62s 6s/step - accuracy: 0.3959 - binary_accuracy: 0.9893 - binary_crossentropy: 0.0352 - f1_score: 0.2868 - loss: 0.0352 - precision: 0.9783 - recall: 0.9672 - val_accuracy: 0.3943 - val_binary_accuracy: 0.9323 - val_binary_crossentropy: 0.2464 - val_f1_score: 0.2899 - val_loss: 0.2464 - val_precision: 0.8335 - val_recall: 0.8241
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 84s 6s/step - accuracy: 0.3887 - binary_accuracy: 0.9901 - binary_crossentropy: 0.0334 - f1_score: 0.2822 - loss: 0.0334 - precision: 0.9800 - recall: 0.9703 - val_accuracy: 0.3647 - val_binary_accuracy: 0.9340 - val_binary_crossentropy: 0.2500 - val_f1_score: 0.2639 - val_loss: 0.2500 - val_precision: 0.8344 - val_recall: 0.8333
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 80s 6s/step - accuracy: 0.3827 - binary_accuracy: 0.9898 - binary_crossentropy: 0.0333 - f1_score: 0.2862 - loss: 0.0333 - precision: 0.9789 - recall: 0.9695 - val_accuracy: 0.3751 - val_binary_accuracy: 0.9335 - val_binary_crossentropy: 0.2547 - val_f1_score: 0.2806 - val_loss: 0.2547 - val_precision: 0.8286 - val_recall: 0.8393
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step

# %% [markdown]
# # Comparações

# %%
def compute_general_metrics(y_real,y_pred,i=None):

  if i is None:
    names = 'general'
    accur = metrics.accuracy_score(y_real, y_pred)
    f1 = metrics.f1_score(y_real, y_pred, average='weighted')
    prec = metrics.precision_score(y_real, y_pred, average='weighted')
    rec = metrics.recall_score(y_real, y_pred, average='weighted')
    jacc = float(metrics.jaccard_score(y_real, y_pred, average='weighted'))
    hamm = metrics.hamming_loss(y_real, y_pred)
    log_loss = metrics.log_loss(y_real, y_pred)

  elif i is not None:
    names = column_names[i]
    accur = metrics.accuracy_score(y_real.iloc[:, i], y_pred[:, i])
    f1 = metrics.f1_score(y_real.iloc[:, i], y_pred[:, i],zero_division=0)
    prec = metrics.precision_score(y_real.iloc[:, i], y_pred[:, i],zero_division=0)
    rec = metrics.recall_score(y_real.iloc[:, i], y_pred[:, i],zero_division=0)
    jacc = float(metrics.jaccard_score(y_real.iloc[:, i], y_pred[:, i]))
    hamm = metrics.hamming_loss(y_real.iloc[:, i], y_pred[:, i])
    log_loss = metrics.log_loss(y_real.iloc[:, i], y_pred[:, i])

  return [names, accur, f1, prec, rec, jacc, hamm, log_loss]

# %%
def compute_all_comparisons(func_model, data_model):
    model_prefix = f'conv2d_{func_model}_{data_model}'
    # Ajuste a data conforme necessário ou automatize
    model_suffix = f'_2025_08_09_call_False'  # Substitua por variável se necessário
    model_name = model_prefix + model_suffix
    model = keras.models.load_model(os.path.join(MODELS_DIR, f'{model_name}.keras'))
    dataset_final = get_dataset(df_spectra_all, dataset_y, func_model)
    X = dataset_final[[col for col in dataset_final.columns if 'bin' in col]].apply(pd.to_numeric, errors='coerce').fillna(0)
    Y = dataset_final[column_names].apply(lambda x: x.astype(int))
    X_train, X_test_temp, Y_train, Y_test_temp = train_test_split(X, Y, test_size=0.25, random_state=42)
    X_validation, X_test, Y_validation, Y_test = train_test_split(X_test_temp, Y_test_temp, test_size=0.45, random_state=42)
    ratio = 5
    X_train_image = np.array([turn_spectra_into_image(X_train.loc[i], ratio=ratio) for i in X_train.index])[..., np.newaxis]
    X_validation_image = np.array([turn_spectra_into_image(X_validation.loc[i], ratio=ratio) for i in X_validation.index])[..., np.newaxis]
    X_test_image = np.array([turn_spectra_into_image(X_test.loc[i], ratio=ratio) for i in X_test.index])[..., np.newaxis]
    train_predict = (model.predict(X_train_image) > 0.5).astype(int)
    test_predict = (model.predict(X_test_image) > 0.5).astype(int)
    metrics_list = ['accuracy', 'f1_score', 'precision', 'recall', 'jaccard', 'hamming', 'log_loss']
    train_metrics = [compute_general_metrics(Y_train, train_predict)] + [compute_general_metrics(Y_train, train_predict, x) for x in range(len(column_names))]
    test_metrics = [compute_general_metrics(Y_test, test_predict)] + [compute_general_metrics(Y_test, test_predict, x) for x in range(len(column_names))]
    full_metrics_df = pd.DataFrame(train_metrics)
    full_metrics_df.columns = ['metric'] + metrics_list
    full_metrics_df['data'] = 'train'
    test_metrics_df = pd.DataFrame(test_metrics)
    test_metrics_df.columns = ['metric'] + metrics_list
    test_metrics_df['data'] = 'test'
    merged_df = pd.concat([full_metrics_df, test_metrics_df], ignore_index=True)
    merged_df['model'] = model_prefix
    return merged_df
results_list = []
for func_model in ['min', 'max', 'mean']:
    for data_model in ['normal']:
        results_list.append(compute_all_comparisons(func_model, data_model))

# %%
all_metrics = pd.concat(results_list) #.groupby(['model','data','metric']).mean()
all_metrics

# %%
all_metrics = pd.concat(results_list)
# all_metrics[(all_metrics['model'] == 'mlp_min_normal') & (all_metrics['data'] == 'test')][['metric','accuracy','f1_score','hamming','data']]
all_metrics[(all_metrics['data'] == 'test')].sort_values(by=['f1_score','hamming','model'], ascending = True)

# %%
all_metrics.to_csv(os.path.join(RESULTS_DIR, 'conv2d_all_results_2.csv'), index=False)
