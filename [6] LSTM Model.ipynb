# %% [markdown]
# # Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import re
import pickle
from datetime import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from packaging import version
from IPython import display
import math
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras import layers, losses, Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, GRU

# Configurações de caminhos
BASE_DIR = os.path.dirname(os.path.abspath("."))
DATASET_DIR = os.path.join(BASE_DIR, "datasets")
MODELS_DIR = os.path.join(BASE_DIR, "models")
RESULTS_DIR = os.path.join(BASE_DIR, "results")
HISTORY_DIR = os.path.join(BASE_DIR, "history")

# Dicionário de grupos funcionais
func_grp_smarts = {
    'alkane':'[CX4;H0,H1,H2,H4]',
    'methyl':'[CH3]',
    'alkene':'[CX3]=[CX3]',
    'alkyne':'[CX2]#C',
    'alcohols':'[#6][OX2H]',
    'amines':'[NX3;H2,H1;!$(NC=O)]',
    'nitriles':'[NX1]#[CX2]',
    'aromatics':'[$([cX3](:*):*),$([cX2+](:*):*)]',
    'alkyl halides':'[#6][F,Cl,Br,I]',
    'esters':'[#6][CX3](=O)[OX2H0][#6]',
    'ketones':'[#6][CX3](=O)[#6]',
    'aldehydes':'[CX3H1](=O)[#6]',
    'carboxylic acids':'[CX3](=O)[OX2H1]',
    'ether': '[OD2]([#6])[#6]',
    'acyl halides':'[CX3](=[OX1])[F,Cl,Br,I]',
    'amides':'[NX3][CX3](=[OX1])[#6]',
    'nitro':'[$([NX3](=O)=O),$([NX3+](=O)[O-])][!#8]'}

column_names = list(func_grp_smarts.keys())

# %%
# Carregar modelo autoencoder
autoencoder_path = os.path.join(MODELS_DIR, 'autoencoder_model_2025_04_07.keras')
autoencoder_load = tf.keras.models.load_model(autoencoder_path)
autoencoder_load.summary()
encoder_model_load = tf.keras.Model(inputs=autoencoder_load.input, outputs=autoencoder_load.layers[4].output)  # Ajuste se necessário
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 1030)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 512)            │       527,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 25)             │         3,225 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 128)            │         3,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 1030)           │       528,390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,174,943 (15.93 MB)
#  Trainable params: 1,391,647 (5.31 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,783,296 (10.62 MB)

# %%
df_enrich_path = os.path.join(DATASET_DIR, 'df_enrich.csv')
df_enrich = pd.read_csv(df_enrich_path)
dataset_y = df_enrich.copy()
dataset_y.index = dataset_y['CAS']
len(dataset_y.CAS.unique())
# Out:
# 8241

# %%
# df_spectra_all = pd.read_csv(os.path.join(DATASET_DIR, 'df_spectra_all_mixture_interpolate.csv'))
df_spectra_all_path = os.path.join(DATASET_DIR, 'df_spectra_all_mixture_interpolate.parquet')
df_spectra_all = pd.read_parquet(df_spectra_all_path)
mean_cols = [x for x in df_spectra_all.columns if 'mean' in x]
min_cols = [x for x in df_spectra_all.columns if 'min' in x]
max_cols = [x for x in df_spectra_all.columns if 'max' in x]
all_cols = mean_cols + min_cols + max_cols
df_spectra_all.shape
# Out:
# (1030, 24636)

# %% [markdown]
# # Functions

# %%
def get_dataset(df_spectra_all, dataset_y, agg_func):
    if agg_func == 'mean':
        dataset_x = df_spectra_all[mean_cols].copy()
    elif agg_func == 'min':
        dataset_x = df_spectra_all[min_cols].copy()
    elif agg_func == 'max':
        dataset_x = df_spectra_all[max_cols].copy()

    dataset_x = dataset_x.T
    dataset_x.columns = ['bin_' + str(x) for x in dataset_x.columns]
    dataset_x.reset_index(inplace=True)
    dataset_x.index = dataset_x['index'].apply(lambda x: x.split('_')[0])

    dataset_y = dataset_y[dataset_y['yunits'] == 'ABSORBANCE']

    dataset_final = pd.merge(dataset_y, dataset_x, left_index=True, right_index=True, how='inner')
    return dataset_final

def find_best_epoch(history):
    """Retorna a época com menor loss de validação."""
    if not history or 'val_loss' not in history.history:
        return None
    val_losses = history.history['val_loss']
    best_epoch = np.argmin(val_losses)
    best_val_loss = val_losses[best_epoch]
    return best_epoch, best_val_loss

# %%
agg_func = 'max'
current_date = datetime.now().strftime('%Y_%m_%d')

dataset_final = get_dataset(df_spectra_all, dataset_y, agg_func)

X = dataset_final[[col for col in dataset_final.columns if 'bin' in col]]
X = X.apply(pd.to_numeric, errors='coerce').fillna(0)

Y = dataset_final[column_names].apply(lambda x: x.astype(int))
X_train, X_test_temp, Y_train, Y_test_temp = train_test_split(X, Y, test_size=0.25, random_state=42)

X_validation, X_test, Y_validation, Y_test = train_test_split(X_test_temp, Y_test_temp, test_size=0.45, random_state=42)

# Reshape input data for LSTM
X_train = np.array(X_train).reshape((X_train.shape[0], X_train.shape[1], 1))
X_validation = np.array(X_validation).reshape((X_validation.shape[0], X_validation.shape[1], 1))
X_test = np.array(X_test).reshape((X_test.shape[0], X_test.shape[1], 1))
X_test_temp = np.array(X_test_temp).reshape((X_test_temp.shape[0], X_test_temp.shape[1], 1))

# %%
def compute_model_analysis(agg_func, data_prep, current_date, batch_size=380, epochs=100, callbacks=False, save_history=True, save_plot=False):
    dataset_final = get_dataset(df_spectra_all, dataset_y, agg_func)

    X = dataset_final[[col for col in dataset_final.columns if 'bin' in col]]
    X = X.apply(pd.to_numeric, errors='coerce').fillna(0)

    if data_prep == 'encoder':
        X = encoder_model_load.predict(X)

    Y = dataset_final[column_names].apply(lambda x: x.astype(int))
    X_train, X_test_temp, Y_train, Y_test_temp = train_test_split(X, Y, test_size=0.20, random_state=42, stratify=Y[column_names].sum(axis=1))

    X_validation, X_test, Y_validation, Y_test = train_test_split(X_test_temp, Y_test_temp, test_size=0.30, random_state=42, stratify=Y_test_temp[column_names].sum(axis=1))

    data_type = np.float32

    # Reshape input data for LSTM
    X_train = np.array(X_train, dtype=data_type).reshape((X_train.shape[0], X_train.shape[1], 1))
    X_validation = np.array(X_validation, dtype=data_type).reshape((X_validation.shape[0], X_validation.shape[1], 1))
    X_test = np.array(X_test, dtype=data_type).reshape((X_test.shape[0], X_test.shape[1], 1))
    X_test_temp = np.array(X_test_temp, dtype=data_type).reshape((X_test_temp.shape[0], X_test_temp.shape[1], 1))

    # Definição do modelo LSTM
    model = tf.keras.Sequential([
        layers.Input(shape=(X_train.shape[1], 1)),
        layers.LSTM(64, return_sequences=True),
        layers.Dropout(0.2),
        layers.LSTM(32, return_sequences=True),
        layers.Dropout(0.2),
        layers.LSTM(32),
        layers.Dense(64, activation='relu'),
        layers.Dense(Y_train.shape[1], activation='sigmoid')
    ])

    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy', 'binary_accuracy'])

    # Callbacks
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7, verbose=0, mode='min', start_from_epoch=50, restore_best_weights=True)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, min_lr=1e-4, verbose=0, mode='min')
    callbacks_list = [early_stopping, reduce_lr] if callbacks else []

    history = model.fit(X_train, Y_train,
                        validation_data=(X_validation, Y_validation),
                        callbacks=callbacks_list,
                        epochs=epochs, verbose=1, shuffle=True, batch_size=batch_size)

    # Avaliação do modelo
    val_loss = history.history['val_loss'][-1]

    y_pred = model.predict(X_validation)
    y_pred = (y_pred > 0.5).astype(int)

    compose_name = f'lstm_{agg_func}_{data_prep}_{current_date}_call_{callbacks}'
    model_save_path = os.path.join(MODELS_DIR, f'{compose_name}.keras')
    model.save(model_save_path)

    if save_history:
        history_save_path = os.path.join(HISTORY_DIR, f'{compose_name}_history.pkl')
        with open(history_save_path, 'wb') as f:
            pickle.dump(history.history, f)

    best_epoch, best_val_loss = find_best_epoch(history)

    if save_plot:
        plt.figure(figsize=(16, 10))
        plt.suptitle(f'Métricas Treinamento - Época Escolhida {best_epoch} - {best_val_loss:.3f} Validação Loss Function')

        plt.subplot(3, 1, 1)
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.axvline(x=best_epoch, color='red', linestyle='--')
        plt.ylabel('Acurácia')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.3f}".format(x)))

        plt.subplot(3, 1, 2)
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.axvline(x=best_epoch, color='red', linestyle='--')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.3f}".format(x)))

        plt.subplot(3, 1, 3)
        plt.plot(history.history['binary_accuracy'])
        plt.plot(history.history['val_binary_accuracy'])
        plt.axvline(x=best_epoch, color='red', linestyle='--')
        plt.ylabel('Acurácia Binarizada')
        plt.xlabel('Epoch')
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.3f}".format(x)))
        plt.savefig(os.path.join(RESULTS_DIR, f'{compose_name}.png'))
        plt.show()

    return history

# %%
batch_size = 800
epochs = 100
callbacks = False
# compute_model_analysis('min', 'normal', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
# compute_model_analysis('min', 'encoder', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
# compute_model_analysis('max', 'normal', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
# compute_model_analysis('max', 'encoder', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
compute_model_analysis('mean', 'normal', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
compute_model_analysis('mean', 'encoder', current_date, batch_size = batch_size,epochs = epochs, callbacks=callbacks)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 142s 15s/step - accuracy: 0.4815 - binary_accuracy: 0.6720 - binary_crossentropy: 0.6910 - f1_score: 0.0524 - loss: 0.6910 - precision: 0.3372 - recall: 0.5033 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.6773 - val_f1_score: 0.0485 - val_loss: 0.6773 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.6838 - binary_accuracy: 0.8279 - binary_crossentropy: 0.6595 - f1_score: 0.0477 - loss: 0.6595 - precision: 0.5688 - recall: 0.5690 - val_accuracy: 0.7041 - val_binary_accuracy: 0.7942 - val_binary_crossentropy: 0.5504 - val_f1_score: 0.0485 - val_loss: 0.5504 - val_precision: 0.4850 - val_recall: 0.5742
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.6896 - binary_accuracy: 0.8135 - binary_crossentropy: 0.5282 - f1_score: 0.0480 - loss: 0.5282 - precision: 0.5323 - recall: 0.5702 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.4527 - val_f1_score: 0.0485 - val_loss: 0.4527 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.6888 - binary_accuracy: 0.8494 - binary_crossentropy: 0.4384 - f1_score: 0.0479 - loss: 0.4384 - precision: 0.6370 - recall: 0.5651 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3912 - val_f1_score: 0.0485 - val_loss: 0.3912 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.6881 - binary_accuracy: 0.8479 - binary_crossentropy: 0.3897 - f1_score: 0.0479 - loss: 0.3897 - precision: 0.6337 - recall: 0.5610 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3670 - val_f1_score: 0.0485 - val_loss: 0.3670 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 138s 14s/step - accuracy: 0.6816 - binary_accuracy: 0.8488 - binary_crossentropy: 0.3691 - f1_score: 0.0476 - loss: 0.3691 - precision: 0.6366 - recall: 0.5634 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3591 - val_f1_score: 0.0485 - val_loss: 0.3591 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 131s 15s/step - accuracy: 0.6872 - binary_accuracy: 0.8492 - binary_crossentropy: 0.3623 - f1_score: 0.0479 - loss: 0.3623 - precision: 0.6369 - recall: 0.5644 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3562 - val_f1_score: 0.0485 - val_loss: 0.3562 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 153s 16s/step - accuracy: 0.6912 - binary_accuracy: 0.8500 - binary_crossentropy: 0.3581 - f1_score: 0.0480 - loss: 0.3581 - precision: 0.6367 - recall: 0.5668 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3550 - val_f1_score: 0.0485 - val_loss: 0.3550 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 217s 17s/step - accuracy: 0.6871 - binary_accuracy: 0.8489 - binary_crossentropy: 0.3598 - f1_score: 0.0478 - loss: 0.3598 - precision: 0.6359 - recall: 0.5638 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3550 - val_f1_score: 0.0485 - val_loss: 0.3550 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 186s 16s/step - accuracy: 0.6888 - binary_accuracy: 0.8483 - binary_crossentropy: 0.3597 - f1_score: 0.0480 - loss: 0.3597 - precision: 0.6373 - recall: 0.5618 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3550 - val_f1_score: 0.0485 - val_loss: 0.3550 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 146s 16s/step - accuracy: 0.6852 - binary_accuracy: 0.8494 - binary_crossentropy: 0.3577 - f1_score: 0.0478 - loss: 0.3577 - precision: 0.6364 - recall: 0.5651 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3549 - val_f1_score: 0.0485 - val_loss: 0.3549 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 210s 17s/step - accuracy: 0.6842 - binary_accuracy: 0.8494 - binary_crossentropy: 0.3576 - f1_score: 0.0477 - loss: 0.3576 - precision: 0.6367 - recall: 0.5650 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 187s 15s/step - accuracy: 0.6946 - binary_accuracy: 0.8486 - binary_crossentropy: 0.3589 - f1_score: 0.0481 - loss: 0.3589 - precision: 0.6362 - recall: 0.5629 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 168s 18s/step - accuracy: 0.6851 - binary_accuracy: 0.8497 - binary_crossentropy: 0.3570 - f1_score: 0.0478 - loss: 0.3570 - precision: 0.6367 - recall: 0.5658 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 174s 15s/step - accuracy: 0.6917 - binary_accuracy: 0.8497 - binary_crossentropy: 0.3578 - f1_score: 0.0480 - loss: 0.3578 - precision: 0.6384 - recall: 0.5656 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 161s 18s/step - accuracy: 0.6897 - binary_accuracy: 0.8489 - binary_crossentropy: 0.3590 - f1_score: 0.0480 - loss: 0.3590 - precision: 0.6374 - recall: 0.5634 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3549 - val_f1_score: 0.0485 - val_loss: 0.3549 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 203s 18s/step - accuracy: 0.6929 - binary_accuracy: 0.8495 - binary_crossentropy: 0.3576 - f1_score: 0.0481 - loss: 0.3576 - precision: 0.6359 - recall: 0.5655 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 181s 15s/step - accuracy: 0.6809 - binary_accuracy: 0.8487 - binary_crossentropy: 0.3585 - f1_score: 0.0476 - loss: 0.3585 - precision: 0.6344 - recall: 0.5634 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 147s 16s/step - accuracy: 0.6942 - binary_accuracy: 0.8490 - binary_crossentropy: 0.3588 - f1_score: 0.0481 - loss: 0.3588 - precision: 0.6377 - recall: 0.5638 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 133s 15s/step - accuracy: 0.6927 - binary_accuracy: 0.8498 - binary_crossentropy: 0.3578 - f1_score: 0.0481 - loss: 0.3578 - precision: 0.6377 - recall: 0.5662 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3549 - val_f1_score: 0.0485 - val_loss: 0.3549 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 139s 15s/step - accuracy: 0.6885 - binary_accuracy: 0.8483 - binary_crossentropy: 0.3592 - f1_score: 0.0479 - loss: 0.3592 - precision: 0.6322 - recall: 0.5625 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3549 - val_f1_score: 0.0485 - val_loss: 0.3549 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 141s 15s/step - accuracy: 0.6876 - binary_accuracy: 0.8490 - binary_crossentropy: 0.3580 - f1_score: 0.0479 - loss: 0.3580 - precision: 0.6360 - recall: 0.5639 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 139s 15s/step - accuracy: 0.6873 - binary_accuracy: 0.8501 - binary_crossentropy: 0.3561 - f1_score: 0.0478 - loss: 0.3561 - precision: 0.6382 - recall: 0.5667 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 145s 15s/step - accuracy: 0.6884 - binary_accuracy: 0.8480 - binary_crossentropy: 0.3593 - f1_score: 0.0479 - loss: 0.3593 - precision: 0.6342 - recall: 0.5613 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 146s 16s/step - accuracy: 0.6853 - binary_accuracy: 0.8489 - binary_crossentropy: 0.3588 - f1_score: 0.0478 - loss: 0.3588 - precision: 0.6357 - recall: 0.5637 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 185s 14s/step - accuracy: 0.6889 - binary_accuracy: 0.8485 - binary_crossentropy: 0.3592 - f1_score: 0.0479 - loss: 0.3592 - precision: 0.6387 - recall: 0.5623 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.6740 - binary_accuracy: 0.8482 - binary_crossentropy: 0.3595 - f1_score: 0.0473 - loss: 0.3595 - precision: 0.6298 - recall: 0.5624 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3549 - val_f1_score: 0.0485 - val_loss: 0.3549 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 136s 15s/step - accuracy: 0.6884 - binary_accuracy: 0.8499 - binary_crossentropy: 0.3576 - f1_score: 0.0479 - loss: 0.3576 - precision: 0.6371 - recall: 0.5665 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 140s 15s/step - accuracy: 0.6936 - binary_accuracy: 0.8496 - binary_crossentropy: 0.3579 - f1_score: 0.0481 - loss: 0.3579 - precision: 0.6388 - recall: 0.5653 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3549 - val_f1_score: 0.0485 - val_loss: 0.3549 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.6840 - binary_accuracy: 0.8494 - binary_crossentropy: 0.3583 - f1_score: 0.0477 - loss: 0.3583 - precision: 0.6375 - recall: 0.5649 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.6884 - binary_accuracy: 0.8497 - binary_crossentropy: 0.3567 - f1_score: 0.0479 - loss: 0.3567 - precision: 0.6353 - recall: 0.5662 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.6879 - binary_accuracy: 0.8483 - binary_crossentropy: 0.3583 - f1_score: 0.0479 - loss: 0.3583 - precision: 0.6334 - recall: 0.5624 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 157s 16s/step - accuracy: 0.6881 - binary_accuracy: 0.8490 - binary_crossentropy: 0.3578 - f1_score: 0.0479 - loss: 0.3578 - precision: 0.6339 - recall: 0.5642 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 145s 16s/step - accuracy: 0.6887 - binary_accuracy: 0.8489 - binary_crossentropy: 0.3587 - f1_score: 0.0479 - loss: 0.3587 - precision: 0.6364 - recall: 0.5635 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 194s 15s/step - accuracy: 0.6930 - binary_accuracy: 0.8498 - binary_crossentropy: 0.3571 - f1_score: 0.0481 - loss: 0.3571 - precision: 0.6378 - recall: 0.5660 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 142s 15s/step - accuracy: 0.6891 - binary_accuracy: 0.8492 - binary_crossentropy: 0.3587 - f1_score: 0.0479 - loss: 0.3587 - precision: 0.6349 - recall: 0.5647 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3549 - val_f1_score: 0.0485 - val_loss: 0.3549 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 149s 16s/step - accuracy: 0.6933 - binary_accuracy: 0.8486 - binary_crossentropy: 0.3580 - f1_score: 0.0481 - loss: 0.3580 - precision: 0.6350 - recall: 0.5631 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 210s 17s/step - accuracy: 0.6969 - binary_accuracy: 0.8495 - binary_crossentropy: 0.3582 - f1_score: 0.0482 - loss: 0.3582 - precision: 0.6392 - recall: 0.5651 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 138s 15s/step - accuracy: 0.6816 - binary_accuracy: 0.8489 - binary_crossentropy: 0.3579 - f1_score: 0.0476 - loss: 0.3579 - precision: 0.6366 - recall: 0.5637 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3547 - val_f1_score: 0.0485 - val_loss: 0.3547 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 140s 15s/step - accuracy: 0.6870 - binary_accuracy: 0.8488 - binary_crossentropy: 0.3585 - f1_score: 0.0478 - loss: 0.3585 - precision: 0.6342 - recall: 0.5635 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 164s 18s/step - accuracy: 0.6840 - binary_accuracy: 0.8493 - binary_crossentropy: 0.3574 - f1_score: 0.0477 - loss: 0.3574 - precision: 0.6332 - recall: 0.5653 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3548 - val_f1_score: 0.0485 - val_loss: 0.3548 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 200s 18s/step - accuracy: 0.6847 - binary_accuracy: 0.8485 - binary_crossentropy: 0.3596 - f1_score: 0.0477 - loss: 0.3596 - precision: 0.6349 - recall: 0.5626 - val_accuracy: 0.7041 - val_binary_accuracy: 0.8502 - val_binary_crossentropy: 0.3549 - val_f1_score: 0.0485 - val_loss: 0.3549 - val_precision: 0.6385 - val_recall: 0.5670
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 350ms/step - accuracy: 0.4284 - binary_accuracy: 0.8555 - binary_crossentropy: 0.3489 - f1_score: 0.0787 - loss: 0.3489 - precision: 0.6708 - recall: 0.5335 - val_accuracy: 0.3603 - val_binary_accuracy: 0.8576 - val_binary_crossentropy: 0.3439 - val_f1_score: 0.0781 - val_loss: 0.3439 - val_precision: 0.6766 - val_recall: 0.5433
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 310ms/step - accuracy: 0.3702 - binary_accuracy: 0.8580 - binary_crossentropy: 0.3437 - f1_score: 0.0795 - loss: 0.3437 - precision: 0.6779 - recall: 0.5416 - val_accuracy: 0.3377 - val_binary_accuracy: 0.8579 - val_binary_crossentropy: 0.3438 - val_f1_score: 0.0768 - val_loss: 0.3438 - val_precision: 0.6771 - val_recall: 0.5451
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 324ms/step - accuracy: 0.3632 - binary_accuracy: 0.8570 - binary_crossentropy: 0.3454 - f1_score: 0.0782 - loss: 0.3454 - precision: 0.6742 - recall: 0.5434 - val_accuracy: 0.3159 - val_binary_accuracy: 0.8575 - val_binary_crossentropy: 0.3439 - val_f1_score: 0.0748 - val_loss: 0.3439 - val_precision: 0.6733 - val_recall: 0.5495
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - accuracy: 0.3504 - binary_accuracy: 0.8577 - binary_crossentropy: 0.3439 - f1_score: 0.0785 - loss: 0.3439 - precision: 0.6771 - recall: 0.5450 - val_accuracy: 0.3316 - val_binary_accuracy: 0.8575 - val_binary_crossentropy: 0.3440 - val_f1_score: 0.0763 - val_loss: 0.3440 - val_precision: 0.6732 - val_recall: 0.5497
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 319ms/step - accuracy: 0.4061 - binary_accuracy: 0.8553 - binary_crossentropy: 0.3466 - f1_score: 0.0801 - loss: 0.3466 - precision: 0.6689 - recall: 0.5362 - val_accuracy: 0.3690 - val_binary_accuracy: 0.8579 - val_binary_crossentropy: 0.3425 - val_f1_score: 0.0788 - val_loss: 0.3425 - val_precision: 0.6775 - val_recall: 0.5443
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.3963 - binary_accuracy: 0.8568 - binary_crossentropy: 0.3455 - f1_score: 0.0800 - loss: 0.3455 - precision: 0.6764 - recall: 0.5384 - val_accuracy: 0.3795 - val_binary_accuracy: 0.8581 - val_binary_crossentropy: 0.3421 - val_f1_score: 0.0792 - val_loss: 0.3421 - val_precision: 0.6778 - val_recall: 0.5456
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 405ms/step - accuracy: 0.4147 - binary_accuracy: 0.8571 - binary_crossentropy: 0.3447 - f1_score: 0.0803 - loss: 0.3447 - precision: 0.6764 - recall: 0.5386 - val_accuracy: 0.4012 - val_binary_accuracy: 0.8579 - val_binary_crossentropy: 0.3417 - val_f1_score: 0.0801 - val_loss: 0.3417 - val_precision: 0.6784 - val_recall: 0.5422
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 363ms/step - accuracy: 0.4392 - binary_accuracy: 0.8560 - binary_crossentropy: 0.3454 - f1_score: 0.0813 - loss: 0.3454 - precision: 0.6764 - recall: 0.5339 - val_accuracy: 0.4134 - val_binary_accuracy: 0.8582 - val_binary_crossentropy: 0.3411 - val_f1_score: 0.0802 - val_loss: 0.3411 - val_precision: 0.6796 - val_recall: 0.5420
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.4350 - binary_accuracy: 0.8564 - binary_crossentropy: 0.3436 - f1_score: 0.0812 - loss: 0.3436 - precision: 0.6752 - recall: 0.5368 - val_accuracy: 0.4413 - val_binary_accuracy: 0.8582 - val_binary_crossentropy: 0.3409 - val_f1_score: 0.0805 - val_loss: 0.3409 - val_precision: 0.6816 - val_recall: 0.5381
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 334ms/step - accuracy: 0.4365 - binary_accuracy: 0.8570 - binary_crossentropy: 0.3436 - f1_score: 0.0808 - loss: 0.3436 - precision: 0.6786 - recall: 0.5363 - val_accuracy: 0.4212 - val_binary_accuracy: 0.8583 - val_binary_crossentropy: 0.3408 - val_f1_score: 0.0804 - val_loss: 0.3408 - val_precision: 0.6807 - val_recall: 0.5404
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 494ms/step - accuracy: 0.4345 - binary_accuracy: 0.8569 - binary_crossentropy: 0.3428 - f1_score: 0.0813 - loss: 0.3428 - precision: 0.6792 - recall: 0.5344 - val_accuracy: 0.4056 - val_binary_accuracy: 0.8583 - val_binary_crossentropy: 0.3413 - val_f1_score: 0.0804 - val_loss: 0.3413 - val_precision: 0.6791 - val_recall: 0.5440
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step - accuracy: 0.4501 - binary_accuracy: 0.8572 - binary_crossentropy: 0.3422 - f1_score: 0.0809 - loss: 0.3422 - precision: 0.6801 - recall: 0.5356 - val_accuracy: 0.4038 - val_binary_accuracy: 0.8584 - val_binary_crossentropy: 0.3404 - val_f1_score: 0.0804 - val_loss: 0.3404 - val_precision: 0.6806 - val_recall: 0.5417
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 406ms/step - accuracy: 0.4344 - binary_accuracy: 0.8568 - binary_crossentropy: 0.3416 - f1_score: 0.0814 - loss: 0.3416 - precision: 0.6765 - recall: 0.5369 - val_accuracy: 0.4491 - val_binary_accuracy: 0.8586 - val_binary_crossentropy: 0.3406 - val_f1_score: 0.0807 - val_loss: 0.3406 - val_precision: 0.6864 - val_recall: 0.5312
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 553ms/step - accuracy: 0.4559 - binary_accuracy: 0.8572 - binary_crossentropy: 0.3422 - f1_score: 0.0815 - loss: 0.3422 - precision: 0.6821 - recall: 0.5331 - val_accuracy: 0.3916 - val_binary_accuracy: 0.8584 - val_binary_crossentropy: 0.3408 - val_f1_score: 0.0803 - val_loss: 0.3408 - val_precision: 0.6780 - val_recall: 0.5474
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 338ms/step - accuracy: 0.4328 - binary_accuracy: 0.8581 - binary_crossentropy: 0.3405 - f1_score: 0.0819 - loss: 0.3405 - precision: 0.6796 - recall: 0.5389 - val_accuracy: 0.4943 - val_binary_accuracy: 0.8582 - val_binary_crossentropy: 0.3392 - val_f1_score: 0.0805 - val_loss: 0.3392 - val_precision: 0.6858 - val_recall: 0.5286
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 588ms/step - accuracy: 0.4846 - binary_accuracy: 0.8578 - binary_crossentropy: 0.3407 - f1_score: 0.0818 - loss: 0.3407 - precision: 0.6855 - recall: 0.5280 - val_accuracy: 0.4395 - val_binary_accuracy: 0.8589 - val_binary_crossentropy: 0.3386 - val_f1_score: 0.0810 - val_loss: 0.3386 - val_precision: 0.6840 - val_recall: 0.5386
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 347ms/step - accuracy: 0.4549 - binary_accuracy: 0.8575 - binary_crossentropy: 0.3396 - f1_score: 0.0829 - loss: 0.3396 - precision: 0.6831 - recall: 0.5310 - val_accuracy: 0.4587 - val_binary_accuracy: 0.8592 - val_binary_crossentropy: 0.3379 - val_f1_score: 0.0812 - val_loss: 0.3379 - val_precision: 0.6861 - val_recall: 0.5371
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 537ms/step - accuracy: 0.4694 - binary_accuracy: 0.8575 - binary_crossentropy: 0.3375 - f1_score: 0.0823 - loss: 0.3375 - precision: 0.6799 - recall: 0.5254 - val_accuracy: 0.4534 - val_binary_accuracy: 0.8600 - val_binary_crossentropy: 0.3379 - val_f1_score: 0.0818 - val_loss: 0.3379 - val_precision: 0.6975 - val_recall: 0.5222
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.4630 - binary_accuracy: 0.8581 - binary_crossentropy: 0.3375 - f1_score: 0.0833 - loss: 0.3375 - precision: 0.6934 - recall: 0.5167 - val_accuracy: 0.4491 - val_binary_accuracy: 0.8606 - val_binary_crossentropy: 0.3369 - val_f1_score: 0.0821 - val_loss: 0.3369 - val_precision: 0.7014 - val_recall: 0.5198
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 396ms/step - accuracy: 0.4478 - binary_accuracy: 0.8587 - binary_crossentropy: 0.3354 - f1_score: 0.0841 - loss: 0.3354 - precision: 0.6984 - recall: 0.5080 - val_accuracy: 0.5144 - val_binary_accuracy: 0.8606 - val_binary_crossentropy: 0.3356 - val_f1_score: 0.0841 - val_loss: 0.3356 - val_precision: 0.7158 - val_recall: 0.4956
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 413ms/step - accuracy: 0.4971 - binary_accuracy: 0.8587 - binary_crossentropy: 0.3367 - f1_score: 0.0854 - loss: 0.3367 - precision: 0.7137 - recall: 0.4882 - val_accuracy: 0.5753 - val_binary_accuracy: 0.8609 - val_binary_crossentropy: 0.3346 - val_f1_score: 0.0840 - val_loss: 0.3346 - val_precision: 0.7120 - val_recall: 0.5039
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - accuracy: 0.5180 - binary_accuracy: 0.8616 - binary_crossentropy: 0.3328 - f1_score: 0.0859 - loss: 0.3328 - precision: 0.7125 - recall: 0.5075 - val_accuracy: 0.4952 - val_binary_accuracy: 0.8630 - val_binary_crossentropy: 0.3308 - val_f1_score: 0.0863 - val_loss: 0.3308 - val_precision: 0.7245 - val_recall: 0.5013
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 351ms/step - accuracy: 0.4995 - binary_accuracy: 0.8606 - binary_crossentropy: 0.3332 - f1_score: 0.0871 - loss: 0.3332 - precision: 0.7272 - recall: 0.4773 - val_accuracy: 0.5457 - val_binary_accuracy: 0.8626 - val_binary_crossentropy: 0.3292 - val_f1_score: 0.0879 - val_loss: 0.3292 - val_precision: 0.7434 - val_recall: 0.4717
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 578ms/step - accuracy: 0.5176 - binary_accuracy: 0.8626 - binary_crossentropy: 0.3313 - f1_score: 0.0894 - loss: 0.3313 - precision: 0.7386 - recall: 0.4801 - val_accuracy: 0.4578 - val_binary_accuracy: 0.8632 - val_binary_crossentropy: 0.3304 - val_f1_score: 0.0881 - val_loss: 0.3304 - val_precision: 0.7371 - val_recall: 0.4845
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 516ms/step - accuracy: 0.5018 - binary_accuracy: 0.8626 - binary_crossentropy: 0.3301 - f1_score: 0.0888 - loss: 0.3301 - precision: 0.7435 - recall: 0.4759 - val_accuracy: 0.6197 - val_binary_accuracy: 0.8611 - val_binary_crossentropy: 0.3326 - val_f1_score: 0.0833 - val_loss: 0.3326 - val_precision: 0.7324 - val_recall: 0.4745
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 323ms/step - accuracy: 0.5349 - binary_accuracy: 0.8618 - binary_crossentropy: 0.3327 - f1_score: 0.0867 - loss: 0.3327 - precision: 0.7457 - recall: 0.4673 - val_accuracy: 0.6205 - val_binary_accuracy: 0.8626 - val_binary_crossentropy: 0.3314 - val_f1_score: 0.0840 - val_loss: 0.3314 - val_precision: 0.7262 - val_recall: 0.4954
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 595ms/step - accuracy: 0.5286 - binary_accuracy: 0.8621 - binary_crossentropy: 0.3307 - f1_score: 0.0883 - loss: 0.3307 - precision: 0.7359 - recall: 0.4781 - val_accuracy: 0.5474 - val_binary_accuracy: 0.8662 - val_binary_crossentropy: 0.3268 - val_f1_score: 0.0894 - val_loss: 0.3268 - val_precision: 0.7310 - val_recall: 0.5167
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 350ms/step - accuracy: 0.5211 - binary_accuracy: 0.8650 - binary_crossentropy: 0.3266 - f1_score: 0.0901 - loss: 0.3266 - precision: 0.7311 - recall: 0.5083 - val_accuracy: 0.5535 - val_binary_accuracy: 0.8660 - val_binary_crossentropy: 0.3244 - val_f1_score: 0.0893 - val_loss: 0.3244 - val_precision: 0.7418 - val_recall: 0.4995
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 443ms/step - accuracy: 0.5335 - binary_accuracy: 0.8644 - binary_crossentropy: 0.3288 - f1_score: 0.0901 - loss: 0.3288 - precision: 0.7402 - recall: 0.4918 - val_accuracy: 0.5605 - val_binary_accuracy: 0.8649 - val_binary_crossentropy: 0.3253 - val_f1_score: 0.0893 - val_loss: 0.3253 - val_precision: 0.7597 - val_recall: 0.4683
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 340ms/step - accuracy: 0.5357 - binary_accuracy: 0.8657 - binary_crossentropy: 0.3271 - f1_score: 0.0900 - loss: 0.3271 - precision: 0.7489 - recall: 0.4917 - val_accuracy: 0.5100 - val_binary_accuracy: 0.8645 - val_binary_crossentropy: 0.3242 - val_f1_score: 0.0911 - val_loss: 0.3242 - val_precision: 0.7531 - val_recall: 0.4737
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - accuracy: 0.5164 - binary_accuracy: 0.8654 - binary_crossentropy: 0.3236 - f1_score: 0.0906 - loss: 0.3236 - precision: 0.7543 - recall: 0.4761 - val_accuracy: 0.4987 - val_binary_accuracy: 0.8637 - val_binary_crossentropy: 0.3234 - val_f1_score: 0.0907 - val_loss: 0.3234 - val_precision: 0.7563 - val_recall: 0.4637
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 441ms/step - accuracy: 0.5057 - binary_accuracy: 0.8646 - binary_crossentropy: 0.3265 - f1_score: 0.0902 - loss: 0.3265 - precision: 0.7484 - recall: 0.4824 - val_accuracy: 0.4830 - val_binary_accuracy: 0.8645 - val_binary_crossentropy: 0.3248 - val_f1_score: 0.0899 - val_loss: 0.3248 - val_precision: 0.7421 - val_recall: 0.4876
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 533ms/step - accuracy: 0.5073 - binary_accuracy: 0.8646 - binary_crossentropy: 0.3256 - f1_score: 0.0900 - loss: 0.3256 - precision: 0.7409 - recall: 0.4921 - val_accuracy: 0.5117 - val_binary_accuracy: 0.8645 - val_binary_crossentropy: 0.3228 - val_f1_score: 0.0916 - val_loss: 0.3228 - val_precision: 0.7574 - val_recall: 0.4681
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 329ms/step - accuracy: 0.5068 - binary_accuracy: 0.8670 - binary_crossentropy: 0.3208 - f1_score: 0.0913 - loss: 0.3208 - precision: 0.7581 - recall: 0.4804 - val_accuracy: 0.5840 - val_binary_accuracy: 0.8661 - val_binary_crossentropy: 0.3234 - val_f1_score: 0.0890 - val_loss: 0.3234 - val_precision: 0.7517 - val_recall: 0.4874
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - accuracy: 0.5263 - binary_accuracy: 0.8663 - binary_crossentropy: 0.3227 - f1_score: 0.0902 - loss: 0.3227 - precision: 0.7546 - recall: 0.4822 - val_accuracy: 0.5666 - val_binary_accuracy: 0.8664 - val_binary_crossentropy: 0.3215 - val_f1_score: 0.0904 - val_loss: 0.3215 - val_precision: 0.7529 - val_recall: 0.4882
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 597ms/step - accuracy: 0.5135 - binary_accuracy: 0.8653 - binary_crossentropy: 0.3240 - f1_score: 0.0907 - loss: 0.3240 - precision: 0.7462 - recall: 0.4865 - val_accuracy: 0.5953 - val_binary_accuracy: 0.8657 - val_binary_crossentropy: 0.3240 - val_f1_score: 0.0887 - val_loss: 0.3240 - val_precision: 0.7463 - val_recall: 0.4910
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 412ms/step - accuracy: 0.5222 - binary_accuracy: 0.8650 - binary_crossentropy: 0.3241 - f1_score: 0.0904 - loss: 0.3241 - precision: 0.7510 - recall: 0.4804 - val_accuracy: 0.5770 - val_binary_accuracy: 0.8662 - val_binary_crossentropy: 0.3212 - val_f1_score: 0.0894 - val_loss: 0.3212 - val_precision: 0.7527 - val_recall: 0.4869
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 354ms/step - accuracy: 0.5263 - binary_accuracy: 0.8655 - binary_crossentropy: 0.3234 - f1_score: 0.0911 - loss: 0.3234 - precision: 0.7514 - recall: 0.4870 - val_accuracy: 0.5509 - val_binary_accuracy: 0.8674 - val_binary_crossentropy: 0.3206 - val_f1_score: 0.0918 - val_loss: 0.3206 - val_precision: 0.7566 - val_recall: 0.4907
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 653ms/step - accuracy: 0.5261 - binary_accuracy: 0.8664 - binary_crossentropy: 0.3228 - f1_score: 0.0910 - loss: 0.3228 - precision: 0.7516 - recall: 0.4876 - val_accuracy: 0.4987 - val_binary_accuracy: 0.8658 - val_binary_crossentropy: 0.3238 - val_f1_score: 0.0915 - val_loss: 0.3238 - val_precision: 0.7723 - val_recall: 0.4603
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 340ms/step - accuracy: 0.5106 - binary_accuracy: 0.8656 - binary_crossentropy: 0.3224 - f1_score: 0.0912 - loss: 0.3224 - precision: 0.7641 - recall: 0.4665 - val_accuracy: 0.5527 - val_binary_accuracy: 0.8676 - val_binary_crossentropy: 0.3191 - val_f1_score: 0.0915 - val_loss: 0.3191 - val_precision: 0.7666 - val_recall: 0.4796
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 342ms/step - accuracy: 0.5273 - binary_accuracy: 0.8667 - binary_crossentropy: 0.3199 - f1_score: 0.0916 - loss: 0.3199 - precision: 0.7572 - recall: 0.4859 - val_accuracy: 0.5831 - val_binary_accuracy: 0.8666 - val_binary_crossentropy: 0.3205 - val_f1_score: 0.0897 - val_loss: 0.3205 - val_precision: 0.7571 - val_recall: 0.4840
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step

# %% [markdown]
# # Comparações

# %%
def compute_general_metrics(y_real,y_pred,i=None):

  if i is None:
    names = 'general'
    accur = metrics.accuracy_score(y_real, y_pred)
    f1 = metrics.f1_score(y_real, y_pred, average='weighted')
    prec = metrics.precision_score(y_real, y_pred, average='weighted')
    rec = metrics.recall_score(y_real, y_pred, average='weighted')
    jacc = float(metrics.jaccard_score(y_real, y_pred, average='weighted'))
    hamm = metrics.hamming_loss(y_real, y_pred)
    log_loss = metrics.log_loss(y_real, y_pred)

  elif i is not None:
    names = column_names[i]
    accur = metrics.accuracy_score(y_real.iloc[:, i], y_pred[:, i])
    f1 = metrics.f1_score(y_real.iloc[:, i], y_pred[:, i],zero_division=0)
    prec = metrics.precision_score(y_real.iloc[:, i], y_pred[:, i],zero_division=0)
    rec = metrics.recall_score(y_real.iloc[:, i], y_pred[:, i],zero_division=0)
    jacc = float(metrics.jaccard_score(y_real.iloc[:, i], y_pred[:, i]))
    hamm = metrics.hamming_loss(y_real.iloc[:, i], y_pred[:, i])
    log_loss = metrics.log_loss(y_real.iloc[:, i], y_pred[:, i])

  return [names, accur, f1, prec, rec, jacc, hamm, log_loss]

# %%
from sklearn import metrics

def compute_all_comparisons(func_model, data_model):
    model_prefix = f'lstm_{func_model}_{data_model}'
    if func_model == 'mean':
        model_suffix = f'_2025_04_26_call_True'
    else:
        model_suffix = f'_2025_04_25_call_True'
    model_name = model_prefix + model_suffix
    model_path = os.path.join(MODELS_DIR, f'{model_name}.keras')
    model = tf.keras.models.load_model(model_path)

    dataset_final = get_dataset(df_spectra_all, dataset_y, func_model)

    X = dataset_final[[col for col in dataset_final.columns if 'bin' in col]]
    X = X.apply(pd.to_numeric, errors='coerce').fillna(0)

    if data_model == 'encoder':
        X = encoder_model_load.predict(X)

    Y = dataset_final[column_names].apply(lambda x: x.astype(int))
    X_train, X_test_temp, Y_train, Y_test_temp = train_test_split(X, Y, test_size=0.25, random_state=42)

    X_validation, X_test, Y_validation, Y_test = train_test_split(X_test_temp, Y_test_temp, test_size=0.45, random_state=42)

    data_type = np.float32
    X_train = np.array(X_train, dtype=data_type).reshape((X_train.shape[0], X_train.shape[1], 1))
    X_validation = np.array(X_validation, dtype=data_type).reshape((X_validation.shape[0], X_validation.shape[1], 1))
    X_test = np.array(X_test, dtype=data_type).reshape((X_test.shape[0], X_test.shape[1], 1))
    X_test_temp = np.array(X_test_temp, dtype=data_type).reshape((X_test_temp.shape[0], X_test_temp.shape[1], 1))

    train_predict = (model.predict(X_train) > 0.5).astype(int)
    test_predict = (model.predict(X_test_temp) > 0.5).astype(int)

    metrics_list = ['accuracy', 'f1_score', 'precision', 'recall', 'jaccard', 'hamming', 'log_loss']

    train_metrics = [compute_general_metrics(Y_train, train_predict)] + [compute_general_metrics(Y_train, train_predict, x) for x in range(len(column_names))]
    test_metrics = [compute_general_metrics(Y_test_temp, test_predict)] + [compute_general_metrics(Y_test_temp, test_predict, x) for x in range(len(column_names))]

    full_metrics_df = pd.DataFrame(train_metrics)
    full_metrics_df.columns = ['metric'] + metrics_list
    full_metrics_df['data'] = 'train'

    test_metrics_df = pd.DataFrame(test_metrics)
    test_metrics_df.columns = ['metric'] + metrics_list
    test_metrics_df['data'] = 'test'

    merged_df = pd.concat([full_metrics_df, test_metrics_df], ignore_index=True)
    merged_df['model'] = model_prefix

    return merged_df

results_list = []
for func_model in ['min', 'max', 'mean']:
    for data_model in ['encoder', 'normal']:
        results_list.append(compute_all_comparisons(func_model, data_model))
# Out:
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 79s 406ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 25s 388ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 85s 437ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 26s 395ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 76s 392ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 26s 397ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(

# %%
all_metrics = pd.concat(results_list)
# all_metrics[(all_metrics['model'] == 'mlp_min_normal') & (all_metrics['data'] == 'test')][['metric','accuracy','f1_score','hamming','data']]
all_metrics[(all_metrics['data'] == 'test')].sort_values(by=['f1_score','hamming','model'], ascending = True)
# Out:
#               metric  accuracy  f1_score  precision    recall   jaccard  \
# 33      acyl halides  0.991232  0.000000   0.000000  0.000000  0.000000
# 33      acyl halides  0.991232  0.000000   0.000000  0.000000  0.000000
# 33      acyl halides  0.991232  0.000000   0.000000  0.000000  0.000000
# 33      acyl halides  0.991232  0.000000   0.000000  0.000000  0.000000
# 33      acyl halides  0.991232  0.000000   0.000000  0.000000  0.000000
# ..               ...       ...       ...        ...       ...       ...
# 31  carboxylic acids  0.977107  0.835088   0.826389  0.843972  0.716867
# 20            methyl  0.792012  0.842841   0.822557  0.864151  0.728372
# 28            esters  0.973697  0.877273   0.906103  0.850220  0.781377
# 19            alkane  0.839260  0.885337   0.881661  0.889044  0.794264
# 26         aromatics  0.910375  0.921502   0.924658  0.918367  0.854430
#
#      hamming  log_loss  data              model
# 33  0.008768  0.316018  test    lstm_max_normal
# 33  0.008768  0.316018  test  lstm_mean_encoder
# 33  0.008768  0.316018  test   lstm_mean_normal
# 33  0.008768  0.316018  test   lstm_min_encoder
# 33  0.008768  0.316018  test    lstm_min_normal
# ..       ...       ...   ...                ...
# 31  0.022893  0.825159  test   lstm_max_encoder
# 20  0.207988  7.496659  test   lstm_max_encoder
# 28  0.026303  0.948055  test   lstm_max_encoder
# 19  0.160740  5.793671  test   lstm_max_encoder
# 26  0.089625  3.230410  test   lstm_max_encoder
#
# [108 rows x 10 columns]

# %%
all_metrics[(all_metrics.model.isin(['lstm_min_encoder','lstm_min_normal'])) & (all_metrics['data'].isin(['test']))]
# Out:
#               metric  accuracy  f1_score  precision    recall   jaccard  \
# 18           general  0.030687  0.444695   0.365836  0.569073  0.365836
# 19            alkane  0.698003  0.822146   0.698003  1.000000  0.698003
# 20            methyl  0.645397  0.784488   0.645397  1.000000  0.645397
# 21            alkene  0.878714  0.000000   0.000000  0.000000  0.000000
# 22            alkyne  0.971749  0.000000   0.000000  0.000000  0.000000
# 23          alcohols  0.728690  0.000000   0.000000  0.000000  0.000000
# 24            amines  0.895762  0.000000   0.000000  0.000000  0.000000
# 25          nitriles  0.954213  0.000000   0.000000  0.000000  0.000000
# 26         aromatics  0.572820  0.728399   0.572820  1.000000  0.572820
# 27     alkyl halides  0.731125  0.000000   0.000000  0.000000  0.000000
# 28            esters  0.889430  0.000000   0.000000  0.000000  0.000000
# 29           ketones  0.910375  0.000000   0.000000  0.000000  0.000000
# 30         aldehydes  0.972236  0.000000   0.000000  0.000000  0.000000
# 31  carboxylic acids  0.931320  0.000000   0.000000  0.000000  0.000000
# 32             ether  0.755967  0.000000   0.000000  0.000000  0.000000
# 33      acyl halides  0.991232  0.000000   0.000000  0.000000  0.000000
# 34            amides  0.987336  0.000000   0.000000  0.000000  0.000000
# 35             nitro  0.950804  0.000000   0.000000  0.000000  0.000000
# 18           general  0.030687  0.444695   0.365836  0.569073  0.365836
# 19            alkane  0.698003  0.822146   0.698003  1.000000  0.698003
# 20            methyl  0.645397  0.784488   0.645397  1.000000  0.645397
# 21            alkene  0.878714  0.000000   0.000000  0.000000  0.000000
# 22            alkyne  0.971749  0.000000   0.000000  0.000000  0.000000
# 23          alcohols  0.728690  0.000000   0.000000  0.000000  0.000000
# 24            amines  0.895762  0.000000   0.000000  0.000000  0.000000
# 25          nitriles  0.954213  0.000000   0.000000  0.000000  0.000000
# 26         aromatics  0.572820  0.728399   0.572820  1.000000  0.572820
# 27     alkyl halides  0.731125  0.000000   0.000000  0.000000  0.000000
# 28            esters  0.889430  0.000000   0.000000  0.000000  0.000000
# 29           ketones  0.910375  0.000000   0.000000  0.000000  0.000000
# 30         aldehydes  0.972236  0.000000   0.000000  0.000000  0.000000
# 31  carboxylic acids  0.931320  0.000000   0.000000  0.000000  0.000000
# 32             ether  0.755967  0.000000   0.000000  0.000000  0.000000
# 33      acyl halides  0.991232  0.000000   0.000000  0.000000  0.000000
# 34            amides  0.987336  0.000000   0.000000  0.000000  0.000000
# 35             nitro  0.950804  0.000000   0.000000  0.000000  0.000000
#
#      hamming   log_loss  data             model
# 18  0.149107  52.301044  test  lstm_min_encoder
# 19  0.301997  10.885078  test  lstm_min_encoder
# 20  0.354603  12.781188  test  lstm_min_encoder
# 21  0.121286   4.371588  test  lstm_min_encoder
# 22  0.028251   1.018281  test  lstm_min_encoder
# 23  0.271310   9.779014  test  lstm_min_encoder
# 24  0.104238   3.757108  test  lstm_min_encoder
# 25  0.045787   1.650318  test  lstm_min_encoder
# 26  0.427180  15.397118  test  lstm_min_encoder
# 27  0.268875   9.691231  test  lstm_min_encoder
# 28  0.110570   3.985343  test  lstm_min_encoder
# 29  0.089625   3.230410  test  lstm_min_encoder
# 30  0.027764   1.000725  test  lstm_min_encoder
# 31  0.068680   2.475477  test  lstm_min_encoder
# 32  0.244033   8.795845  test  lstm_min_encoder
# 33  0.008768   0.316018  test  lstm_min_encoder
# 34  0.012664   0.456471  test  lstm_min_encoder
# 35  0.049196   1.773214  test  lstm_min_encoder
# 18  0.149107  52.301044  test   lstm_min_normal
# 19  0.301997  10.885078  test   lstm_min_normal
# 20  0.354603  12.781188  test   lstm_min_normal
# 21  0.121286   4.371588  test   lstm_min_normal
# 22  0.028251   1.018281  test   lstm_min_normal
# 23  0.271310   9.779014  test   lstm_min_normal
# 24  0.104238   3.757108  test   lstm_min_normal
# 25  0.045787   1.650318  test   lstm_min_normal
# 26  0.427180  15.397118  test   lstm_min_normal
# 27  0.268875   9.691231  test   lstm_min_normal
# 28  0.110570   3.985343  test   lstm_min_normal
# 29  0.089625   3.230410  test   lstm_min_normal
# 30  0.027764   1.000725  test   lstm_min_normal
# 31  0.068680   2.475477  test   lstm_min_normal
# 32  0.244033   8.795845  test   lstm_min_normal
# 33  0.008768   0.316018  test   lstm_min_normal
# 34  0.012664   0.456471  test   lstm_min_normal
# 35  0.049196   1.773214  test   lstm_min_normal

# %%
all_metrics.to_csv(os.path.join(RESULTS_DIR, 'all_metrics_lstm.csv'), index=False)
